# %% [markdown]
# # Protein embeddings improve phage-host interaction prediction
#
# **Mark Edward M. Gonzales<sup>1, 2</sup> & Anish M.S. Shrestha<sup>1, 2</sup>**
#
# <sup>1</sup> Department of Software Technology, College of Computer Studies, De La Salle University, Manila, Philippines <br>
# <sup>2</sup> Bioinformatics Laboratory, Advanced Research Institute for Informatics, Computing and Networking, De La Salle University, Manila, Philippines
#
# {mark_gonzales, anish.shrestha}@dlsu.edu.ph

# %% [markdown]
# <hr>

# %% [markdown]
# ## 📁 Output Files
# If you would like to skip running this notebook, you may download the
#
# Intermediate output files (i.e., those saved in `temp/preprocessing`) should have already been included when the repository was cloned.

# %% [markdown]
# <hr>

# %% [markdown]
# # Part I: Preliminaries

# %% [markdown]
# Import the necessary libraries and modules.

# %%
import os
import shutil
import pickle

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from ConstantsUtil import ConstantsUtil
from SequenceParsingUtil import SequenceParsingUtil

# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

pd.options.mode.chained_assignment = None

# %% [markdown]
# The parameter of `ConstantsUtil` corresponds to the download date of dataset.

# %%
constants = ConstantsUtil('16Sep2022')
util = SequenceParsingUtil(constants.DISPLAY_PROGRESS, constants.MISSPELLING_THRESHOLD, constants.MIN_LEN_KEYWORD)

# %% [markdown]
# To load this month's version of the dataset via INPHARED:
#
# 1. Clone the latest version of INPHARED from its official [repository](http://github.com/RyanCook94/inphared).
# 2. Download the PHROG HMMs (`all_phrogs.hmm`) from [Millard Lab](https://millardlab.org/2021/11/21/phage-annotation-with-phrogs/).
# 3. Run the following script to run the INPHARED pipeline (refer to the [documentation](https://github.com/RyanCook94/inphared#usage) for details): <br>
#     `perl inphared.pl -e exclusion_list.txt -P all_phrogs.hmm/all_phrogs.hmm -c 0`
# 4. Move the following files to the `inphared` directory: <br>
#     4.1. `<download_date>_data_excluding_refseq.tsv` <br>
#     4.2. `<download_date>_phages_downloaded_from_genbank.gb` <br>
#    Note: `<download_date>` should be the same as the argument passed to `ConstantsUtil` in the previous code block.

# %%
inphared_raw = pd.read_csv(f'{constants.INPHARED_TSV}', sep='\t')
inphared_raw = inphared_raw.drop_duplicates(ignore_index = True)
inphared_raw.head()
# Out:
#   Accession       Description                                  Classification  \
# 0  LR756511  uncultured phage  uncultured phage environmental samples Viruses
# 1  LR756508  uncultured phage  uncultured phage environmental samples Viruses
# 2  LR756504  uncultured phage  uncultured phage environmental samples Viruses
# 3  LR756503  uncultured phage  uncultured phage environmental samples Viruses
# 4  LR756502  uncultured phage  uncultured phage environmental samples Viruses
#
#    Genome Length (bp)  Jumbophage  molGC (%) Molecule Modification Date  \
# 0              595163        True     42.110      DNA       26-MAR-2020
# 1              484177        True     39.553      DNA       26-MAR-2020
# 2              636363        True     26.393      DNA       26-MAR-2020
# 3              735411        True     32.225      DNA       26-MAR-2020
# 4              642428        True     31.472      DNA       26-MAR-2020
#
#    Number CDS  Positive Strand (%)  Negative Strand (%)  Coding Capacity(%)  \
# 0        1080            20.648148            79.351852           93.248236
# 1         683            98.389458             1.610542           89.636022
# 2         920            51.956522            48.043478           92.786193
# 3        1014            30.276134            69.723866           93.113239
# 4         971            54.582904            45.417096           94.525145
#
#   Low Coding Capacity Warning  tRNAs         Host   Lowest Taxa         Genus  \
# 0                         NaN     62  Unspecified  Unclassified  Unclassified
# 1                         NaN     31  Unspecified  Unclassified  Unclassified
# 2                         NaN     34  Unspecified  Unclassified  Unclassified
# 3                         NaN     56  Unspecified  Unclassified  Unclassified
# 4                         NaN     45  Unspecified  Unclassified  Unclassified
#
#      Sub-family        Family         Order         Class        Phylum  \
# 0  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 1  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 2  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 3  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 4  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
#
#         Kingdom         Realm Baltimore Group Genbank Division  \
# 0  Unclassified  Unclassified    Unclassified              ENV
# 1  Unclassified  Unclassified    Unclassified              ENV
# 2  Unclassified  Unclassified    Unclassified              ENV
# 3  Unclassified  Unclassified    Unclassified              ENV
# 4  Unclassified  Unclassified    Unclassified              ENV
#
#   Isolation Host (beware inconsistent and nonsense values)
# 0                                        Unspecified
# 1                                        Unspecified
# 2                                        Unspecified
# 3                                        Unspecified
# 4                                        Unspecified

# %%
inphared_raw.shape
# Out:
# (18389, 27)

# %% [markdown]
# <hr>

# %% [markdown]
# # Part II: Preprocessing of Host Information

# %% [markdown]
# Fo entries with `Unspecified` host in INPHARED, obtain the isolation host information from GenBank, if it makes sense.

# %%
util.set_inphared_gb(constants.INPHARED_GB)

# %%
inphared_unspec_host = inphared_raw.loc[inphared_raw['Host'] == 'Unspecified']
inphared_unspec_host.reset_index(inplace = True, drop = True)
inphared_unspec_host.head()
# Out:
#   Accession       Description                                  Classification  \
# 0  LR756511  uncultured phage  uncultured phage environmental samples Viruses
# 1  LR756508  uncultured phage  uncultured phage environmental samples Viruses
# 2  LR756504  uncultured phage  uncultured phage environmental samples Viruses
# 3  LR756503  uncultured phage  uncultured phage environmental samples Viruses
# 4  LR756502  uncultured phage  uncultured phage environmental samples Viruses
#
#    Genome Length (bp)  Jumbophage  molGC (%) Molecule Modification Date  \
# 0              595163        True     42.110      DNA       26-MAR-2020
# 1              484177        True     39.553      DNA       26-MAR-2020
# 2              636363        True     26.393      DNA       26-MAR-2020
# 3              735411        True     32.225      DNA       26-MAR-2020
# 4              642428        True     31.472      DNA       26-MAR-2020
#
#    Number CDS  Positive Strand (%)  Negative Strand (%)  Coding Capacity(%)  \
# 0        1080            20.648148            79.351852           93.248236
# 1         683            98.389458             1.610542           89.636022
# 2         920            51.956522            48.043478           92.786193
# 3        1014            30.276134            69.723866           93.113239
# 4         971            54.582904            45.417096           94.525145
#
#   Low Coding Capacity Warning  tRNAs         Host   Lowest Taxa         Genus  \
# 0                         NaN     62  Unspecified  Unclassified  Unclassified
# 1                         NaN     31  Unspecified  Unclassified  Unclassified
# 2                         NaN     34  Unspecified  Unclassified  Unclassified
# 3                         NaN     56  Unspecified  Unclassified  Unclassified
# 4                         NaN     45  Unspecified  Unclassified  Unclassified
#
#      Sub-family        Family         Order         Class        Phylum  \
# 0  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 1  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 2  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 3  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 4  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
#
#         Kingdom         Realm Baltimore Group Genbank Division  \
# 0  Unclassified  Unclassified    Unclassified              ENV
# 1  Unclassified  Unclassified    Unclassified              ENV
# 2  Unclassified  Unclassified    Unclassified              ENV
# 3  Unclassified  Unclassified    Unclassified              ENV
# 4  Unclassified  Unclassified    Unclassified              ENV
#
#   Isolation Host (beware inconsistent and nonsense values)
# 0                                        Unspecified
# 1                                        Unspecified
# 2                                        Unspecified
# 3                                        Unspecified
# 4                                        Unspecified

# %%
phages_unspec_host = util.get_phages_unspec_host(inphared_unspec_host)
# Out:
# Processed 1000 records
# Processed 2000 records
# Processed 3000 records
# Processed 4000 records
# Processed 5000 records
# Processed 6000 records
# Processed 7000 records
# Processed 8000 records
# Processed 9000 records
# Processed 10000 records
# Processed 11000 records
# Processed 12000 records
# Processed 13000 records
# Processed 14000 records
# Processed 15000 records
# Processed 16000 records
# Processed 17000 records
# Processed 18000 records
# Processed 19000 records
# Processed 20000 records
# Processed 21000 records
# Processed 22000 records
# Processed 23000 records
# Processed 24000 records
# Processed 25000 records
# Processed 26000 records
# Processed 27000 records
# Processed 28000 records
# Processed 29000 records
# Processed 30000 records
# Processed 31000 records

# %%
unfiltered_hosts = util.get_unfiltered_hosts()
genus_typo = util.get_genus_typo(f'{constants.GENUS_TYPO}')
unfiltered_suspected_genera = util.get_unfiltered_suspected_genera(constants.CANDIDATE_REGEX)

excluded_hosts = util.get_excluded_hosts(constants.ARCHAEA, constants.BACTERIA_NOT_GENUS, constants.EXCLUDED_HOSTS)
valid_hosts = util.get_valid_hosts()

# %% [markdown]
# Add another layer of checking to identify typos in GenBank annotations, as well as oversights during manual filtering:
# - Recheck genera in `valid_hosts` that are not in INPHARED's `Host` column.
# - Identify entries with minimum edit distance &leq; 2 (likely misspellings).
# <br>
#
# Adjust the exclusion and typo correction files in the `preprocessing` directory accordingly, and rerun the previous cell, as needed.

# %%
inphared_hosts = set(inphared_raw['Host'].str.lower())
valid_hosts - inphared_hosts
# Out:
# {'silvanigrella'}

# %%
valid_hosts_list = list(valid_hosts)
for i in range(len(valid_hosts_list)):
    for j in range(i + 1, len(valid_hosts_list)):
        if util.is_possible_misspelling(valid_hosts_list[i], valid_hosts_list[j]):
            print(valid_hosts_list[i], valid_hosts_list[j])
# Out:
# microbacterium mycobacterium

# %% [markdown]
# Update `host` column based on the manually filtered info from GenBank.

# %%
inphared_augmented = inphared_raw.copy(deep = True)
util.update_host_column(constants.CANDIDATE_REGEX, inphared_unspec_host, inphared_augmented)

inphared_augmented['Host'] = inphared_augmented['Host'].str.lower()
inphared_augmented['Host'].value_counts()
# Out:
# Index: 424 | Name: ON970599 | Host: gordonia
# Processed 1000 records
# Processed 2000 records
# Index: 2105 | Name: MN940411 | Host: staphylococcus
# Processed 3000 records
# Index: 3471 | Name: AF125163 | Host: vibrio
# Index: 3477 | Name: AF063097 | Host: escherichia
# Processed 4000 records
# Index: 3576 | Name: OK499975 | Host: proteus
# Index: 3705 | Name: OK649958 | Host: haloferax
# Index: 3761 | Name: MW822148 | Host: mycobacterium
# Processed 5000 records
# Index: 4552 | Name: MH590600 | Host: microbacterium
# Index: 4628 | Name: MH271321 | Host: microbacterium
# Index: 4643 | Name: MH155873 | Host: microbacterium
# Index: 5392 | Name: LC625742 | Host: enterococcus
# Processed 6000 records
# Processed 7000 records
# Processed 8000 records
# Processed 9000 records
# Index: 5662 | Name: MT588083 | Host: salmonella
# Processed 10000 records
# Processed 11000 records
# Processed 12000 records
# Processed 13000 records
# Processed 14000 records
# Processed 15000 records
# Processed 16000 records
# Processed 17000 records
# Processed 18000 records
# Index: 8414 | Name: MN857473 | Host: caulobacter
# Index: 8837 | Name: MN746332 | Host: caulobacter
# Processed 19000 records
# Index: 9294 | Name: MN161573 | Host: salmonella
# Index: 9451 | Name: MN882550 | Host: butyrivibrio
# Processed 20000 records
# Index: 10400 | Name: MN153797 | Host: escherichia
# Index: 10581 | Name: LC487997 | Host: escherichia
# Index: 10582 | Name: LC487996 | Host: escherichia
# Index: 10616 | Name: MG747435 | Host: ralstonia
# Processed 21000 records
# Index: 11284 | Name: MK310183 | Host: escherichia
# Processed 22000 records
# Index: 11806 | Name: MK310184 | Host: escherichia
# Processed 23000 records
# Processed 24000 records
# Index: 13732 | Name: MF155889 | Host: vibrio
# Index: 13982 | Name: CP017837 | Host: silvanigrella
# Index: 13984 | Name: CP017838 | Host: silvanigrella
# Processed 25000 records
# Index: 14453 | Name: KT232076 | Host: escherichia
# Index: 14569 | Name: JX412914 | Host: escherichia
# Index: 15013 | Name: AP012540 | Host: escherichia
# Index: 15014 | Name: AP012539 | Host: escherichia
# Index: 15015 | Name: AP012538 | Host: escherichia
# Index: 15016 | Name: AP012537 | Host: escherichia
# Index: 15017 | Name: AP012536 | Host: escherichia
# Index: 15018 | Name: AP012535 | Host: escherichia
# Index: 15019 | Name: AP012534 | Host: escherichia
# Index: 15020 | Name: AP012533 | Host: escherichia
# Index: 15021 | Name: AP012532 | Host: escherichia
# Index: 15022 | Name: AP012531 | Host: escherichia
# Index: 15023 | Name: AP012530 | Host: escherichia
# Index: 15024 | Name: AP012529 | Host: escherichia
# Index: 15025 | Name: AB008550 | Host: pseudomonas
# Processed 26000 records
# Index: 15577 | Name: GU942563 | Host: vibrio
# Processed 27000 records
# Index: 16396 | Name: KT254133 | Host: escherichia | chryseobacterium | pseudomonas
# Index: 16397 | Name: KT254132 | Host: escherichia | chryseobacterium | pseudomonas
# Index: 16398 | Name: KT254131 | Host: escherichia | chryseobacterium | pseudomonas
# Index: 16399 | Name: KT254130 | Host: escherichia | chryseobacterium | pseudomonas
# Index: 16621 | Name: KP296794 | Host: paenibacillus
# Index: 16623 | Name: KP296792 | Host: paenibacillus
# Processed 28000 records
# Index: 16741 | Name: KM236244 | Host: salmonella
# Index: 16806 | Name: KM458633 | Host: salmonella
# Index: 16878 | Name: FR719956 | Host: roseovarius
# Index: 17036 | Name: KJ619459 | Host: vibrio
# Index: 17123 | Name: AB720063 | Host: xanthomonas
# Index: 17158 | Name: KF598865 | Host: phormidium | plectonema
# Index: 17221 | Name: KC677662 | Host: salmonella
# Index: 17242 | Name: KC117378 | Host: haloarcula
# Index: 17286 | Name: KC292029 | Host: haloarcula
# Index: 17287 | Name: KC292028 | Host: haloarcula
# Index: 17288 | Name: KC292027 | Host: haloarcula
# Index: 17290 | Name: KC292025 | Host: haloarcula
# Index: 17291 | Name: KC292024 | Host: haloarcula
# Processed 29000 records
# Index: 17390 | Name: KC117377 | Host: haloarcula
# Index: 17391 | Name: KC117376 | Host: halorubrum
# Index: 17689 | Name: HQ711985 | Host: pseudomonas
# Index: 17855 | Name: HQ406778 | Host: salmonella
# Index: 17892 | Name: AM910650 | Host: pseudomonas
# Index: 17898 | Name: AM156909 | Host: escherichia
# Index: 17921 | Name: Y13918 | Host: pseudomonas
# Index: 17924 | Name: X99260 | Host: bacillus
# Index: 17948 | Name: AF424783 | Host: staphylococcus
# Index: 17959 | Name: FJ539135 | Host: escherichia
# Index: 17960 | Name: FJ539134 | Host: escherichia
# Index: 17961 | Name: FJ539133 | Host: escherichia
# Index: 17962 | Name: FJ539132 | Host: escherichia
# Processed 30000 records
# Index: 18007 | Name: BL2CG | Host: mycoplasma
# Index: 18033 | Name: AB370205 | Host: staphylococcus
# Index: 18262 | Name: AB255436 | Host: escherichia
# Index: 18264 | Name: AP004402 | Host: escherichia
# Index: 18269 | Name: AP001553 | Host: staphylococcus
# Index: 18278 | Name: AB012573 | Host: vibrio
# Index: 18280 | Name: AB370268 | Host: staphylococcus
# Index: 18281 | Name: AP008954 | Host: staphylococcus
# Index: 18282 | Name: AP008953 | Host: staphylococcus
# Index: 18288 | Name: EU794049 | Host: hamiltonella
# Index: 18359 | Name: AJ567472 | Host: acidianus
# Processed 31000 records
# unspecified                                     2566
# mycobacterium                                   2189
# escherichia                                     1627
# vibrio                                           852
# pseudomonas                                      826
# salmonella                                       744
# streptococcus                                    730
# klebsiella                                       628
# gordonia                                         579
# staphylococcus                                   508
# enterobacteria                                   498
# microbacterium                                   459
# bacillus                                         377
# lactococcus                                      364
# synechococcus                                    362
# arthrobacter                                     340
# streptomyces                                     310
# flavobacterium                                   247
# acinetobacter                                    196
# enterococcus                                     185
# rhizobium                                        154
# aeromonas                                        140
# erwinia                                          137
# shigella                                         128
# propionibacterium                                125
# yersinia                                         120
# rheinheimera                                     110
# campylobacter                                     95
# pectobacterium                                    92
# xanthomonas                                       91
# lactobacillus                                     89
# sigmofec                                          88
# clostridium                                       83
# serratia                                          76
# ralstonia                                         76
# burkholderia                                      75
# sulfolobus                                        75
# paenibacillus                                     66
# listeria                                          62
# stenotrophomonas                                  61
# rhodococcus                                       60
# enterobacter                                      60
# peromfec                                          55
# rhodobacter                                       54
# cellulophaga                                      53
# prochlorococcus                                   51
# dipodfec                                          48
# proteus                                           48
# pelagibacter                                      47
# citrobacter                                       46
# halorubrum                                        45
# bacteroides                                       43
# dickeya                                           39
# cronobacter                                       39
# corynebacterium                                   38
# brucella                                          37
# helicobacter                                      37
# caulobacter                                       33
# pseudoalteromonas                                 33
# moraxella                                         32
# achromobacter                                     31
# haloarcula                                        30
# providencia                                       26
# pantoea                                           24
# leuconostoc                                       23
# roseobacter                                       21
# brevundimonas                                     20
# brevibacterium                                    19
# liberibacter                                      18
# polaribacter                                      18
# shewanella                                        18
# acidianus                                         18
# edwardsiella                                      17
# alteromonas                                       17
# cutibacterium                                     17
# thermus                                           17
# wolbachia                                         16
# clostridioides                                    15
# ruegeria                                          15
# prevotella                                        15
# mycoplasma                                        14
# microcystis                                       13
# sinorhizobium                                     13
# agrobacterium                                     13
# mannheimia                                        12
# bifidobacterium                                   11
# kosakonia                                         11
# bordetella                                        11
# hafnia                                            10
# brevibacillus                                     10
# salinibacter                                       9
# fusobacterium                                      9
# pasteurella                                        9
# xylella                                            9
# leptospira                                         9
# paracoccus                                         8
# faecalibacterium                                   8
# morganella                                         8
# spiroplasma                                        6
# nocardia                                           6
# maribacter                                         6
# oenococcus                                         6
# sphingomonas                                       6
# ruminococcus                                       6
# geobacillus                                        6
# nodularia                                          6
# dinoroseobacter                                    6
# sulfitobacter                                      6
# tenacibaculum                                      5
# tsukamurella                                       5
# marinomonas                                        5
# butyrivibrio                                       5
# curtobacterium                                     5
# chlamydia                                          5
# nitratiruptor                                      5
# nitrosopumilus                                     5
# haloferax                                          4
# riemerella                                         4
# escherichia | chryseobacterium | pseudomonas       4
# ochrobactrum                                       4
# elizabethkingia                                    4
# methanobacterium                                   4
# exiguobacterium                                    4
# brochothrix                                        4
# delftia                                            3
# nostoc                                             3
# psychrobacillus                                    3
# acidithiobacillus                                  3
# haemophilus                                        3
# natrinema                                          3
# raoultella                                         3
# lentibacter                                        3
# marinobacter                                       3
# weissella                                          3
# bdellovibrio                                       3
# psychrobacter                                      3
# glutamicibacter                                    3
# parabacteroides                                    3
# carnobacterium                                     3
# actinomyces                                        3
# acidovorax                                         3
# acetobacter                                        3
# komagataeibacter                                   3
# curvibacter                                        3
# halomonas                                          3
# hamiltonella                                       3
# aeropyrum                                          3
# alcaligenes                                        3
# metallosphaera                                     3
# sodalis                                            3
# leclercia                                          2
# mesorhizobium                                      2
# methanosarcina                                     2
# salinivibrio                                       2
# silvanigrella                                      2
# plectonema                                         2
# thermobifida                                       2
# rhodovulum                                         2
# pyrobaculum                                        2
# xenohaliotis                                       2
# marinitoga                                         2
# meiothermus                                        2
# natrialba                                          2
# croceibacter                                       2
# thermoproteus                                      2
# clavibacter                                        2
# erysipelothrix                                     2
# roseburia                                          2
# cylindrospermopsis                                 2
# halobacterium                                      2
# tetraselmis                                        2
# phormidium                                         2
# erythrobacter                                      2
# thermococcus                                       2
# citromicrobium                                     2
# oceanospirillum                                    2
# altiarchaeum                                       2
# myxococcus                                         2
# sphaerotilus                                       2
# anabaena                                           2
# octadecabacter                                     2
# paraglaciecola                                     2
# roseovarius                                        2
# nonlabens                                          2
# caldibacillus                                      1
# nitrososphaera                                     1
# plesiomonas                                        1
# rathayibacter                                      1
# planktothrix                                       1
# sphingobium                                        1
# dunaliella                                         1
# aphanizomenon                                      1
# tetrasphaera                                       1
# salisaeta                                          1
# lysinibacillus                                     1
# saccharomonospora                                  1
# azospirillum                                       1
# celeribacter                                       1
# peptoclostridium                                   1
# skermania                                          1
# methanothermobacter                                1
# aggregatibacter                                    1
# lelliottia                                         1
# aurantimonas                                       1
# rhodoferax                                         1
# acaryochloris                                      1
# thermoanaerobacterium                              1
# iodobacter                                         1
# stygiolobus                                        1
# nitrincola                                         1
# actinoplanes                                       1
# listonella                                         1
# thiobacimonas                                      1
# thalassomonas                                      1
# pelagibaca                                         1
# silicibacter                                       1
# phormidium | plectonema                            1
# colwellia                                          1
# puniceispirillum                                   1
# kluyvera                                           1
# halogranum                                         1
# loktanella                                         1
# hydrogenobaculum                                   1
# bradyrhizobium                                     1
# aquamicrobium                                      1
# akkermansia                                        1
# gluconobacter                                      1
# levilactobacillus                                  1
# desulfovibrio                                      1
# pseudoxanthomonas                                  1
# halogeometricum                                    1
# hydrogenophilus                                    1
# lentisphaerae                                      1
# rahnella                                           1
# parageobacillus                                    1
# pseudaeromonas                                     1
# pararheinheimera                                   1
# lokiarchaeota                                      1
# chryseobacterium                                   1
# lactiplantibacillus                                1
# kurthia                                            1
# stappia                                            1
# pseudarthrobacter                                  1
# luteibacter                                        1
# tetragenococcus                                    1
# cytobacillus                                       1
# eggerthella                                        1
# janthinobacterium                                  1
# mycolicibacterium                                  1
# cedecea                                            1
# muninn                                             1
# huginn                                             1
# verrucomicrobia                                    1
# stxxx                                              1
# solobacterium                                      1
# methanoculleus                                     1
# pontimonas                                         1
# saccharolobus                                      1
# anoxybacillus                                      1
# mastigocladus                                      1
# azobacteroides                                     1
# virgibacillus                                      1
# aerococcus                                         1
# rothia                                             1
# aeribacillus                                       1
# photobacterium                                     1
# pediococcus                                        1
# sporosarcina                                       1
# phaeobacter                                        1
# aminobacter                                        1
# pseudanabaena                                      1
# winogradskyella                                    1
# micromonospora                                     1
# buttiauxella                                       1
# haloterrigena                                      1
# methanocaldococcus                                 1
# arthronema                                         1
# protaetiibacter                                    1
# gardnerella                                        1
# arcanobacterium                                    1
# cellulosimicrobium                                 1
# thermocrinis                                       1
# sphingopyxis                                       1
# olleya                                             1
# pyrococcus                                         1
# Name: Host, dtype: int64

# %% [markdown]
# ### Polyvalent Phages

# %% [markdown]
# There are only few polyvalent (multi-host) phages in our database. Hence, for simplicity, we map each polyvalent phage only to its host with the highest number of interacting phages in the dataset.

# %%
multiple_hosts = set()

for host, count in dict(inphared_augmented['Host'].value_counts()).items():
    if '|' in host:
        multiple_hosts.add(host)
        print(host, ':', count)
# Out:
# escherichia | chryseobacterium | pseudomonas : 4
# phormidium | plectonema : 1

# %%
for host in multiple_hosts:
    # We have confirmed that the first host is the host with the highest number of interacting phages in the dataset.
    inphared_augmented.loc[inphared_augmented['Host'] == host, 'Host'] = host.split(' | ')[0]

# %%
inphared = inphared_augmented.loc[inphared_augmented['Host'] != 'unspecified']
inphared.reset_index(inplace = True, drop = True)
inphared.head()
# Out:
#   Accession              Description  \
# 0  MK250029  Prevotella phage Lak-C1
# 1  MK250028  Prevotella phage Lak-B9
# 2  MK250027  Prevotella phage Lak-B8
# 3  MK250026  Prevotella phage Lak-B7
# 4  MK250025  Prevotella phage Lak-B6
#
#                                       Classification  Genome Length (bp)  \
# 0  Prevotella phage Lak-C1 Myoviridae Caudovirice...              540217
# 1  Prevotella phage Lak-B9 Myoviridae Caudovirice...              550053
# 2  Prevotella phage Lak-B8 Myoviridae Caudovirice...              551627
# 3  Prevotella phage Lak-B7 Myoviridae Caudovirice...              550702
# 4  Prevotella phage Lak-B6 Myoviridae Caudovirice...              546689
#
#    Jumbophage  molGC (%) Molecule Modification Date  Number CDS  \
# 0        True     25.796      DNA       13-JAN-2019         830
# 1        True     26.012      DNA       13-JAN-2019         859
# 2        True     26.022      DNA       13-JAN-2019         860
# 3        True     26.020      DNA       13-JAN-2019         859
# 4        True     26.029      DNA       13-JAN-2019         847
#
#    Positive Strand (%)  Negative Strand (%)  Coding Capacity(%)  \
# 0            47.108434            52.891566           68.324951
# 1            52.270081            47.729919           69.188424
# 2            53.023256            46.976744           69.318761
# 3            53.201397            46.798603           69.363285
# 4            52.656434            47.343566           69.118274
#
#   Low Coding Capacity Warning  tRNAs        Host Lowest Taxa         Genus  \
# 0                         NaN     30  prevotella  Myoviridae  Unclassified
# 1                         NaN     29  prevotella  Myoviridae  Unclassified
# 2                         NaN     33  prevotella  Myoviridae  Unclassified
# 3                         NaN     33  prevotella  Myoviridae  Unclassified
# 4                         NaN     30  prevotella  Myoviridae  Unclassified
#
#      Sub-family      Family         Order           Class       Phylum  \
# 0  Unclassified  Myoviridae  Unclassified  Caudoviricetes  Uroviricota
# 1  Unclassified  Myoviridae  Unclassified  Caudoviricetes  Uroviricota
# 2  Unclassified  Myoviridae  Unclassified  Caudoviricetes  Uroviricota
# 3  Unclassified  Myoviridae  Unclassified  Caudoviricetes  Uroviricota
# 4  Unclassified  Myoviridae  Unclassified  Caudoviricetes  Uroviricota
#
#           Kingdom          Realm Baltimore Group Genbank Division  \
# 0  Heunggongvirae  Duplodnaviria         Group I              ENV
# 1  Heunggongvirae  Duplodnaviria         Group I              ENV
# 2  Heunggongvirae  Duplodnaviria         Group I              ENV
# 3  Heunggongvirae  Duplodnaviria         Group I              ENV
# 4  Heunggongvirae  Duplodnaviria         Group I              ENV
#
#   Isolation Host (beware inconsistent and nonsense values)
# 0                                     Prevotella sp.
# 1                                     Prevotella sp.
# 2                                     Prevotella sp.
# 3                                     Prevotella sp.
# 4                                     Prevotella sp.

# %% [markdown]
# Replace the genera of some hosts with standard NCBI Taxonomy nomenclature.

# %%
inphared['Host'].replace(util.get_ncbi_standard_nomenclature(constants.NCBI_STANDARD_NOMENCLATURE), inplace = True)
inphared['Host'].value_counts()
# Out:
# mycobacterium                2189
# escherichia                  1632
# vibrio                        852
# pseudomonas                   826
# salmonella                    744
# streptococcus                 730
# klebsiella                    628
# gordonia                      579
# enterobacter                  558
# staphylococcus                508
# microbacterium                459
# bacillus                      377
# lactococcus                   364
# synechococcus                 362
# arthrobacter                  340
# streptomyces                  310
# flavobacterium                247
# acinetobacter                 196
# enterococcus                  185
# rhizobium                     154
# aeromonas                     140
# erwinia                       137
# shigella                      128
# propionibacterium             125
# yersinia                      120
# rheinheimera                  110
# campylobacter                  95
# pectobacterium                 92
# xanthomonas                    91
# lactobacillus                  89
# sigmofec                       88
# clostridium                    83
# serratia                       76
# ralstonia                      76
# burkholderia                   75
# sulfolobus                     75
# paenibacillus                  66
# listeria                       62
# stenotrophomonas               61
# rhodococcus                    60
# peromfec                       55
# rhodobacter                    54
# cellulophaga                   53
# prochlorococcus                51
# dipodfec                       48
# proteus                        48
# pelagibacter                   47
# citrobacter                    46
# halorubrum                     45
# bacteroides                    43
# cronobacter                    39
# dickeya                        39
# corynebacterium                38
# helicobacter                   37
# brucella                       37
# pseudoalteromonas              33
# caulobacter                    33
# moraxella                      32
# achromobacter                  31
# haloarcula                     30
# providencia                    26
# pantoea                        24
# leuconostoc                    23
# roseobacter                    21
# brevundimonas                  20
# brevibacterium                 19
# acidianus                      18
# polaribacter                   18
# shewanella                     18
# liberibacter                   18
# edwardsiella                   17
# cutibacterium                  17
# alteromonas                    17
# thermus                        17
# wolbachia                      16
# prevotella                     15
# clostridioides                 15
# ruegeria                       15
# mycoplasma                     14
# agrobacterium                  13
# sinorhizobium                  13
# microcystis                    13
# mannheimia                     12
# bifidobacterium                11
# kosakonia                      11
# bordetella                     11
# brevibacillus                  10
# hafnia                         10
# leptospira                      9
# fusobacterium                   9
# pasteurella                     9
# salinibacter                    9
# xylella                         9
# faecalibacterium                8
# paracoccus                      8
# morganella                      8
# nodularia                       6
# dinoroseobacter                 6
# maribacter                      6
# spiroplasma                     6
# oenococcus                      6
# sphingomonas                    6
# nocardia                        6
# sulfitobacter                   6
# ruminococcus                    6
# geobacillus                     6
# butyrivibrio                    5
# chlamydia                       5
# curtobacterium                  5
# tenacibaculum                   5
# nitrosopumilus                  5
# tsukamurella                    5
# marinomonas                     5
# nitratiruptor                   5
# elizabethkingia                 4
# exiguobacterium                 4
# methanobacterium                4
# brochothrix                     4
# ochrobactrum                    4
# riemerella                      4
# haloferax                       4
# parabacteroides                 3
# glutamicibacter                 3
# metallosphaera                  3
# psychrobacter                   3
# delftia                         3
# halomonas                       3
# actinomyces                     3
# curvibacter                     3
# psychrobacillus                 3
# acidithiobacillus               3
# marinobacter                    3
# weissella                       3
# natrinema                       3
# aeropyrum                       3
# bdellovibrio                    3
# sodalis                         3
# carnobacterium                  3
# lentibacter                     3
# nostoc                          3
# hamiltonella                    3
# komagataeibacter                3
# acetobacter                     3
# haemophilus                     3
# acidovorax                      3
# raoultella                      3
# phormidium                      3
# alcaligenes                     3
# thermoproteus                   2
# marinitoga                      2
# mesorhizobium                   2
# halobacterium                   2
# sphaerotilus                    2
# plectonema                      2
# cylindrospermopsis              2
# methanosarcina                  2
# clavibacter                     2
# candidatus odinarchaeum         2
# paraglaciecola                  2
# pyrobaculum                     2
# croceibacter                    2
# rhodovulum                      2
# natrialba                       2
# meiothermus                     2
# erythrobacter                   2
# thermobifida                    2
# salinivibrio                    2
# xenohaliotis                    2
# silvanigrella                   2
# erysipelothrix                  2
# leclercia                       2
# oceanospirillum                 2
# roseovarius                     2
# thermococcus                    2
# tetraselmis                     2
# anabaena                        2
# roseburia                       2
# altiarchaeum                    2
# nonlabens                       2
# citromicrobium                  2
# octadecabacter                  2
# myxococcus                      2
# peptoclostridium                1
# sphingobium                     1
# nitrososphaera                  1
# azospirillum                    1
# methanothermobacter             1
# thalassomonas                   1
# parageobacillus                 1
# kluyvera                        1
# actinoplanes                    1
# thiobacimonas                   1
# pelagibaca                      1
# planktothrix                    1
# aquamicrobium                   1
# bradyrhizobium                  1
# listonella                      1
# rathayibacter                   1
# silicibacter                    1
# colwellia                       1
# rahnella                        1
# tetrasphaera                    1
# nitrincola                      1
# puniceispirillum                1
# halogranum                      1
# stygiolobus                     1
# loktanella                      1
# thermoanaerobacterium           1
# lysinibacillus                  1
# dunaliella                      1
# aurantimonas                    1
# saccharomonospora               1
# aggregatibacter                 1
# lelliottia                      1
# hydrogenobaculum                1
# pseudaeromonas                  1
# skermania                       1
# celeribacter                    1
# iodobacter                      1
# salisaeta                       1
# rhodoferax                      1
# acaryochloris                   1
# caldibacillus                   1
# pseudoxanthomonas               1
# aphanizomenon                   1
# gardnerella                     1
# micromonospora                  1
# cytobacillus                    1
# buttiauxella                    1
# tetragenococcus                 1
# haloterrigena                   1
# methanocaldococcus              1
# arthronema                      1
# protaetiibacter                 1
# luteibacter                     1
# pseudarthrobacter               1
# chryseobacterium                1
# arcanobacterium                 1
# pseudanabaena                   1
# cellulosimicrobium              1
# thermocrinis                    1
# sphingopyxis                    1
# lactiplantibacillus             1
# olleya                          1
# levilactobacillus               1
# winogradskyella                 1
# methanoculleus                  1
# stappia                         1
# solobacterium                   1
# kurthia                         1
# eggerthella                     1
# janthinobacterium               1
# plesiomonas                     1
# virgibacillus                   1
# lentisphaerae                   1
# gluconobacter                   1
# pontimonas                      1
# hydrogenophilus                 1
# anoxybacillus                   1
# halogeometricum                 1
# mastigocladus                   1
# candidatus azobacteroides       1
# pararheinheimera                1
# akkermansia                     1
# verrucomicrobia                 1
# aerococcus                      1
# saccharolobus                   1
# lokiarchaeota                   1
# rothia                          1
# aeribacillus                    1
# desulfovibrio                   1
# photobacterium                  1
# pediococcus                     1
# cedecea                         1
# sporosarcina                    1
# mycolicibacterium               1
# phaeobacter                     1
# aminobacter                     1
# pyrococcus                      1
# Name: Host, dtype: int64

# %% [markdown]
# Just verifying that all the entries are unique

# %%
inphared.shape[0] == inphared['Accession'].nunique()
# Out:
# True

# %% [markdown]
# ###  Some Statistics

# %% [markdown]
# Statistics on phages

# %%
print("Original INPHARED:\t\t", inphared_raw.shape[0])
print("With Specified Hosts:\t\t", inphared_raw.shape[0] - inphared_unspec_host.shape[0])
print("Plus Manually Filtered Hosts:\t", inphared.shape[0])
# Out:
# Original INPHARED:		 18389
# With Specified Hosts:		 15739
# Plus Manually Filtered Hosts:	 15823

# %% [markdown]
# Statistics on host genera

# %%
print("Num. of Unique Host Genera:\t", inphared['Host'].nunique())
# Out:
# Num. of Unique Host Genera:	 279

# %% [markdown]
# Save the entries with host information to a CSV file.

# %%
inphared.to_csv(os.path.join(constants.TEMP_PREPROCESSING, constants.INPHARED_WITH_HOSTS), index = False)

# %% [markdown]
# <hr>

# %% [markdown]
# # Part III: Selection of Annotated Receptor-Binding Proteins (RBPs)

# %% [markdown]
# Load only the phage entries with host data.

# %%
inphared = pd.read_csv(f'{constants.TEMP_PREPROCESSING}/{constants.INPHARED_WITH_HOSTS}')
util.set_inphared(inphared)

inphared.shape
# Out:
# (15823, 27)

# %% [markdown]
# Identify which phage entries have CDS information and which do not.

# %%
no_cds_annot = util.get_no_cds_annot()
# Out:
# Processed 1000 records
# Processed 2000 records
# Processed 3000 records
# Processed 4000 records
# Processed 5000 records
# Processed 6000 records
# Processed 7000 records
# Processed 8000 records
# Processed 9000 records
# Processed 10000 records
# Processed 11000 records
# Processed 12000 records
# Processed 13000 records
# Processed 14000 records
# Processed 15000 records
# Processed 16000 records
# Processed 17000 records
# Processed 18000 records
# Processed 19000 records
# Processed 20000 records
# Processed 21000 records
# Processed 22000 records
# Processed 23000 records
# Processed 24000 records
# Processed 25000 records
# Processed 26000 records
# Processed 27000 records
# Processed 28000 records
# Processed 29000 records
# Processed 30000 records
# Processed 31000 records

# %%
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.NO_CDS_ANNOT),'wb') as no_cds_annot_file:
    pickle.dump(no_cds_annot, no_cds_annot_file)

# %%
with open(f'{constants.TEMP_PREPROCESSING}/{constants.NO_CDS_ANNOT}','rb') as no_cds_annot_file:
    no_cds_annot = pickle.load(no_cds_annot_file)
    
util.set_no_cds_annot(no_cds_annot)

# %% [markdown]
# ### Some statistics

# %%
print("Without CDS info:\t", len(no_cds_annot))
print("With CDS info:\t\t", inphared.shape[0] - len(no_cds_annot))
# Out:
# Without CDS info:	 665
# With CDS info:		 15158

# %% [markdown]
# ## *A. Process entries with CDS information*

# %% [markdown]
# - Use regex from this [RBP prediction study](https://www.mdpi.com/1999-4915/14/6/1329) by Boeckaerts <i>et al.</i> (2022) to select the annotated RBPs
#    - We modify this regex to:
#      - Make more accommodating to typos (e.g., look for `bind` instead of `binding`)
#      - Allow multiple spaces between tokens
#    - For comparison:
#      - Original regex: `tail.?(?:spike|fib(?:er|re))|^recept(?:o|e)r.?(?:binding|recognizing).*(?:protein)?|^RBP`
#      - Modified regex: `tail?(.?|\s*)(?:spike?|fib(?:er|re))|recept(?:o|e)r(.?|\s*)(?:bind|recogn).*(?:protein)?|(?<!\w)RBP(?!a)`
#      - Annotations captured by modified regex but not by old regex:
#        - `receptor recognition protein`
#    - The same [study](https://www.mdpi.com/1999-4915/14/6/1329) has an exclusion list that covers proteins related to RBPs but are not RBPs themselves (e.g., assembly and portal proteins).
#        <br><br>
#
# - If product does not match regex for RBP, check if it is a hypothetical protein
#    - The same [study](https://www.mdpi.com/1999-4915/14/6/1329) has a list of keywords associated with hypothetical proteins
#       - We remove `putative`, `probable`, and `probably` since they are indicative of a product with a putative (rather than an unknown) function.
#    - Make more accommodating to typos by allowing keywords with minimum edit distance ≤ 2 (likely misspellings)
#    - Create a manual list to handle cases where the keyword `hypothetical` is present but the putative function is already given, as in the case of:
#        - `conserved hypothetical lipoprotein`
#        - `hypothetical host-like ribonucleoside diphosphate reductase`       <br><br>
#
# - Predict whether these hypothetical proteins are RBPs using the XGBoost model from the [RBP prediction study](https://www.mdpi.com/1999-4915/14/6/1329) by Boeckaerts <i>et al.</i> (2022).

# %%
util.set_token_delimiter(constants.TOKEN_DELIMITER)
util.construct_keyword_list(constants.HYPOTHETICAL_KEYWORDS, constants.RBP_RELATED_NOT_RBP, constants.PUTATIVE_FUNCTIONS)

# %%
annot_products = util.get_annot_products()
# Out:
# Processed 1000 records
# Processed 2000 records
# Processed 3000 records
# Processed 4000 records
# Processed 5000 records
# Processed 6000 records
# Processed 7000 records
# Processed 8000 records
# Processed 9000 records
# Processed 10000 records
# Processed 11000 records
# Processed 12000 records
# Processed 13000 records
# Processed 14000 records
# Processed 15000 records
# Processed 16000 records
# Processed 17000 records
# Processed 18000 records
# Processed 19000 records
# Processed 20000 records
# Processed 21000 records
# Processed 22000 records
# Processed 23000 records

# %%
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.ANNOT_PRODUCTS),'wb') as annot_products_file:
    pickle.dump(annot_products, annot_products_file)

# %%
with open(f'{constants.TEMP_PREPROCESSING}/{constants.ANNOT_PRODUCTS}','rb') as annot_products_file:
    annot_products = pickle.load(annot_products_file)
    
util.set_annot_products(annot_products)
for annot_product in sorted(list(annot_products)):
    print(annot_product)

# %%
rbp_products, hypothetical_proteins = util.get_rbp_hypothetical_proteins(constants.RBP_REGEX)

# %%
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.RBP_PRODUCTS),'wb') as rbp_products_file:
    pickle.dump(rbp_products, rbp_products_file)
    
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.HYPOTHETICAL_PRODUCTS),'wb') as hypothetical_proteins_file:
    pickle.dump(hypothetical_proteins, hypothetical_proteins_file)

# %%
with open(f'{constants.TEMP_PREPROCESSING}/{constants.RBP_PRODUCTS}','rb') as rbp_products_file:
    rbp_products = pickle.load(rbp_products_file)
    
util.set_rbp_products(rbp_products)
rbp_products

# %%
with open(f'{constants.TEMP_PREPROCESSING}/{constants.HYPOTHETICAL_PRODUCTS}','rb') as hypothetical_proteins_file:
    hypothetical_proteins = pickle.load(hypothetical_proteins_file)
    
util.set_hypothetical_proteins(hypothetical_proteins)
for protein in hypothetical_proteins:
    print(protein)

# %% [markdown]
# ### Get distribution of RBP lengths

# %% [markdown]
# This preliminary analysis of the distribution of the RBP lengths covers both the sequences with CDS information and those where the CDS information features are predicted via Prokka. We carry it now in order since we need the lower and upper bounds for RBP lengths to generate the FASTA files.

# %%
len_distribution = util.generate_rbp_len_distribution()
util.generate_rbp_len_distribution_prokka(len_distribution, constants.INPHARED_GENOME)

lengths = []
for length, freq in len_distribution.items():
    for _ in range(freq):
        lengths.append(length)

# %%
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.RBP_LENGTHS),'wb') as rbp_lengths_file:
    pickle.dump(lengths, rbp_lengths_file)

# %% [markdown]
# Statistically compute the lower and upper bounds for RBP lengths.

# %%
with open(f'{constants.TEMP_PREPROCESSING}/{constants.RBP_LENGTHS}','rb') as rbp_lengths_file:
    lengths = pickle.load(rbp_lengths_file)

Q1 = np.percentile(lengths, 25, interpolation = 'midpoint')
Q3 = np.percentile(lengths, 75, interpolation = 'midpoint')
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower bound:", lower_bound)
print("Upper bound:", upper_bound)

# %% [markdown]
# ### Generate FASTA for entries with CDS information

# %% [markdown]
# Generate FASTA files containing protein sequences of hypothetical proteins and RBPs

# %%
RBP_NEW_DIR = f'{constants.INPHARED}/{constants.FASTA}/{constants.RBP}/{constants.GENBANK}'
HYPOTHETICAL_NEW_DIR = f'{constants.INPHARED}/{constants.FASTA}/{constants.HYPOTHETICAL}/{constants.GENBANK}'

if not os.path.exists(RBP_NEW_DIR):
    os.mkdir(RBP_NEW_DIR)
    
if not os.path.exists(HYPOTHETICAL_NEW_DIR):
    os.mkdir(HYPOTHETICAL_NEW_DIR)

# %%
util.generate_rbp_hypothetical_fasta(RBP_NEW_DIR, HYPOTHETICAL_NEW_DIR, constants.LOWER_BOUND_RBP_LENGTH, 
                                     constants.UPPER_BOUND_RBP_LENGTH)

# %% [markdown]
# The FASTA files are stored in the `inphared/fasta` directory, specifically in the `genbank` subdirectories.

# %% [markdown]
# ## *B. Process entries without CDS information*

# %% [markdown]
# - Annotate genes using [Prokka](https://academic.oup.com/bioinformatics/article/30/14/2068/2390517), which calls [Prodigal](https://bmcbioinformatics.biomedcentral.com/articles/10.1186/1471-2105-11-119) to predict coordinates of ORFs.
# - Configure Prokka to perform functional annotation using [PHROGs](https://academic.oup.com/nargab/article/3/3/lqab067/6342220).
# - Process in the same manner as the entries with CDS information.

# %%
RBP_NEW_DIR = f'{constants.INPHARED}/{constants.FASTA}/{constants.RBP}/{constants.PROKKA}'
HYPOTHETICAL_NEW_DIR = f'{constants.INPHARED}/{constants.FASTA}/{constants.HYPOTHETICAL}/{constants.PROKKA}'

if not os.path.exists(RBP_NEW_DIR):
    os.mkdir(RBP_NEW_DIR)
    
if not os.path.exists(HYPOTHETICAL_NEW_DIR):
    os.mkdir(HYPOTHETICAL_NEW_DIR)

# %% [markdown]
# Analyze the gene product annotations returned by PHROG.

# %%
annot_products_prokka = util.get_annot_products_prokka(constants.INPHARED_GENOME)

# %%
x, y = util.get_rbp_hypothetical_proteins_prokka(constants.RBP_REGEX, annot_products_prokka)

# %% [markdown]
# Combine the keywords for RBPs and hypothetical proteins from GenBank (i.e., entries with CDS information) and PHROG annotations (i.e., entries without CDS information).

# %%
util.set_rbp_products(rbp_products.union(x))
util.set_hypothetical_proteins(hypothetical_proteins.union(y))

# %%
rbp_products = rbp_products.union(x)
hypothetical_proteins = hypothetical_proteins.union(y)

# %%
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.RBP_PRODUCTS),'wb') as rbp_products_file:
    pickle.dump(rbp_products, rbp_products_file)
    
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.HYPOTHETICAL_PRODUCTS),'wb') as hypothetical_proteins_file:
    pickle.dump(hypothetical_proteins, hypothetical_proteins_file)

# %% [markdown]
# ### Generate FASTA for entries without CDS information

# %% [markdown]
# Generate FASTA files containing protein sequences of hypothetical proteins and RBPs

# %%
util.generate_rbp_hypothetical_fasta_prokka(constants.INPHARED_GENOME, RBP_NEW_DIR, HYPOTHETICAL_NEW_DIR, 
                                            lower_bound, upper_bound)

# %% [markdown]
# The FASTA files are stored in the `inphared/fasta` directory, specifically in the `prokka` subdirectories.

# %% [markdown]
# ### C. *Generate FFN containing the genomes of RBPs and hypothetical proteins*

# %%
util.generate_rbp_hypothetical_nucleotide(f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.RBP}/{constants.GENBANK}',
                                          f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.HYPOTHETICAL}/{constants.GENBANK}', 
                                          lower_bound, upper_bound)

# %% [markdown]
# The FFN files are stored in the `inphared/fasta/nucleotide` directory, specifically in the `genbank` subdirectories.

# %%
util.generate_rbp_hypothetical_nucleotide_prokka(constants.INPHARED_GENOME,
                                                 f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.RBP}/{constants.PROKKA}',
                                                 f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.HYPOTHETICAL}/{constants.PROKKA}', 
                                                 lower_bound, upper_bound)

# %% [markdown]
# The FFN files are stored in the `inphared/fasta/nucleotide` directory, specifically in the `prokka` subdirectories.

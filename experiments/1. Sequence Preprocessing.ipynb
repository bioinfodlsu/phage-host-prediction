# %% [markdown]
# # Protein embeddings improve phage-host interaction prediction
#
# **Mark Edward M. Gonzales<sup>1, 2</sup>, Jennifer C. Ureta<sup>1, 2</sup> & Anish M.S. Shrestha<sup>1, 2</sup>**
#
# <sup>1</sup> Bioinformatics Laboratory, Advanced Research Institute for Informatics, Computing and Networking, De La Salle University, Manila, Philippines <br>
# <sup>2</sup> Department of Software Technology, College of Computer Studies, De La Salle University, Manila, Philippines
#
# {mark_gonzales, jennifer.ureta, anish.shrestha}@dlsu.edu.ph

# %% [markdown]
# <hr>

# %% [markdown]
# ## 💡 Dataset
#
# **To download the dataset via INPHARED:**
#
# 1. Clone the latest version of INPHARED from its official [repository](http://github.com/RyanCook94/inphared).
# 2. Download the PHROG HMMs (`all_phrogs.hmm`) from [Millard Lab](http://s3.climb.ac.uk/ADM_share/all_phrogs.hmm.gz) or from [Google Drive](https://drive.google.com/file/d/1oX-oOJzIynC6XKWWAvnd57CKqEV3t3kc/view?usp=sharing), and save it in the same folder as `inphared.pl`.
# 3. Download the GenomesDB directory of INPHARED from this [link](https://millardlab-inphared.s3.climb.ac.uk/GenomesDB_20201412.tar.gz), and save it inside the same folder as `inphared.pl`.
# 4. Run the following script to execute the INPHARED pipeline (refer to the [documentation](https://github.com/RyanCook94/inphared#usage) for details):
#    - `perl inphared.pl -e exclusion_list.txt -P all_phrogs.hmm -c 0`
#    - Notes:
#       - The goal of running the pipeline is to complete populating the `GenomesDB` directory. Note that this may take some time since genome annotation is performed.
#       - Note that running the INPHARED pipeline will load the most recent data. Our work uses the September data. For reproducibility, we have provided the following files to load the September data:
#         - `16Sep2022_data_excluding_refseq.tsv` (should have already been included when the repository was cloned) <br>
#         - `16Sep2022_phages_downloaded_from_genbank.gb` (can be downloaded from [Google Drive](https://drive.google.com/file/d/14LG1iGa1CqPbAjofZT1EY8VKnE8Iy45Q/view?usp=sharing)) <br>
#
# **After INPHARED finishes running:**
#
# 1. Save `16Sep2022_data_excluding_refseq.tsv` and `16Sep2022_phages_downloaded_from_genbank.gb` inside the `inphared` directory located in the same folder as this notebook. The folder structure should look like this:<br> <br>
#    `experiments` (parent folder of this notebook) <br>
#      ↳ `inphared` <br>
#      &nbsp; &nbsp; ↳ `16Sep2022_data_excluding_refseq.tsv` <br>
#      &nbsp; &nbsp; ↳ `16Sep2022_phages_downloaded_from_genbank.gb`  <br>
#      ↳ `1. Sequence Preprocessing.ipynb` (this notebook) <br> <br>
#
# 2. Create a directory named `datasets` in the **root** of this project.
#    - Transfer `GenomesDB` to `datasets/inphared/inphared`.
#    - The folder structure should look like this: <br> <br>
#         `root` <br>
#         ↳ `datasets` <br>
#         &nbsp; &nbsp; ↳ `inphared` <br>
#         &nbsp; &nbsp;&nbsp; &nbsp; ↳ `inphared`  <br>
#         &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `GenomesDB`  <br>
#         &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `AB002632`  <br>
#         &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ ... <br>
#         ↳ `experiments` <br>
#         &nbsp; &nbsp; ↳ `1. Sequence Preprocessing.ipynb` (this notebook)

# %% [markdown]
# <hr>

# %% [markdown]
# ## 📁 Output Files
# If you would like to skip running this notebook, you may download the output FASTA files from [Google Drive](https://drive.google.com/drive/folders/16ZBXZCpC0OmldtPPIy5sEBtS4EVohorT?usp=sharing). Save the results inside the `inphared` directory located in the same folder as this notebook. The folder structure should look like this:
#
# `experiments` (parent folder of this notebook) <br>
# ↳`inphared` <br>
# &nbsp; &nbsp;↳ `fasta` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `hypothetical` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `nucleotide` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp` <br>
# ↳ `1. Sequence Preprocessing.ipynb` (this notebook) <br>
#
# Intermediate output files (i.e., those saved in `temp/preprocessing`) should have already been included when the repository was cloned.

# %% [markdown]
# <hr>

# %% [markdown]
# # Part I: Preliminaries

# %% [markdown]
# Import the necessary libraries and modules.

# %%
import os
import shutil
import pickle

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from ConstantsUtil import ConstantsUtil
from SequenceParsingUtil import SequenceParsingUtil

# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

pd.options.mode.chained_assignment = None

# %% [markdown]
# The parameter of `ConstantsUtil` corresponds to the download date of the dataset.
#
# In particular, when [INPHARED](https://github.com/RyanCook94/inphared) is run, among the files generated are:
# - `<download_date>_data_excluding_refseq.tsv` <br>
# - `<download_date>_phages_downloaded_from_genbank.gb` <br>
#
# The download date of the dataset is `download_date`.

# %%
constants = ConstantsUtil('16Sep2022')
util = SequenceParsingUtil(constants.DISPLAY_PROGRESS, constants.MISSPELLING_THRESHOLD, constants.MIN_LEN_KEYWORD)

# %%
inphared_raw = pd.read_csv(f'{constants.INPHARED_TSV}', sep='\t')
inphared_raw = inphared_raw.drop_duplicates(ignore_index = True)
inphared_raw.head()
# Out:
#   Accession       Description                                  Classification  \
# 0  LR756511  uncultured phage  uncultured phage environmental samples Viruses
# 1  LR756508  uncultured phage  uncultured phage environmental samples Viruses
# 2  LR756504  uncultured phage  uncultured phage environmental samples Viruses
# 3  LR756503  uncultured phage  uncultured phage environmental samples Viruses
# 4  LR756502  uncultured phage  uncultured phage environmental samples Viruses
#
#    Genome Length (bp)  Jumbophage  molGC (%) Molecule Modification Date  \
# 0              595163        True     42.110      DNA       26-MAR-2020
# 1              484177        True     39.553      DNA       26-MAR-2020
# 2              636363        True     26.393      DNA       26-MAR-2020
# 3              735411        True     32.225      DNA       26-MAR-2020
# 4              642428        True     31.472      DNA       26-MAR-2020
#
#    Number CDS  Positive Strand (%)  Negative Strand (%)  Coding Capacity(%)  \
# 0        1080            20.648148            79.351852           93.248236
# 1         683            98.389458             1.610542           89.636022
# 2         920            51.956522            48.043478           92.786193
# 3        1014            30.276134            69.723866           93.113239
# 4         971            54.582904            45.417096           94.525145
#
#   Low Coding Capacity Warning  tRNAs         Host   Lowest Taxa         Genus  \
# 0                         NaN     62  Unspecified  Unclassified  Unclassified
# 1                         NaN     31  Unspecified  Unclassified  Unclassified
# 2                         NaN     34  Unspecified  Unclassified  Unclassified
# 3                         NaN     56  Unspecified  Unclassified  Unclassified
# 4                         NaN     45  Unspecified  Unclassified  Unclassified
#
#      Sub-family        Family         Order         Class        Phylum  \
# 0  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 1  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 2  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 3  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 4  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
#
#         Kingdom         Realm Baltimore Group Genbank Division  \
# 0  Unclassified  Unclassified    Unclassified              ENV
# 1  Unclassified  Unclassified    Unclassified              ENV
# 2  Unclassified  Unclassified    Unclassified              ENV
# 3  Unclassified  Unclassified    Unclassified              ENV
# 4  Unclassified  Unclassified    Unclassified              ENV
#
#   Isolation Host (beware inconsistent and nonsense values)
# 0                                        Unspecified
# 1                                        Unspecified
# 2                                        Unspecified
# 3                                        Unspecified
# 4                                        Unspecified

# %%
inphared_raw.shape
# Out:
# (18389, 27)

# %% [markdown]
# <hr>

# %% [markdown]
# # Part II: Preprocessing of Host Information

# %% [markdown]
# For entries with `Unspecified` host in INPHARED, obtain the isolation host information from GenBank, if it makes sense.

# %%
util.set_inphared_gb(constants.INPHARED_GB)

# %%
inphared_unspec_host = inphared_raw.loc[inphared_raw['Host'] == 'Unspecified']
inphared_unspec_host.reset_index(inplace = True, drop = True)
inphared_unspec_host.head()
# Out:
#   Accession       Description                                  Classification  \
# 0  LR756511  uncultured phage  uncultured phage environmental samples Viruses
# 1  LR756508  uncultured phage  uncultured phage environmental samples Viruses
# 2  LR756504  uncultured phage  uncultured phage environmental samples Viruses
# 3  LR756503  uncultured phage  uncultured phage environmental samples Viruses
# 4  LR756502  uncultured phage  uncultured phage environmental samples Viruses
#
#    Genome Length (bp)  Jumbophage  molGC (%) Molecule Modification Date  \
# 0              595163        True     42.110      DNA       26-MAR-2020
# 1              484177        True     39.553      DNA       26-MAR-2020
# 2              636363        True     26.393      DNA       26-MAR-2020
# 3              735411        True     32.225      DNA       26-MAR-2020
# 4              642428        True     31.472      DNA       26-MAR-2020
#
#    Number CDS  Positive Strand (%)  Negative Strand (%)  Coding Capacity(%)  \
# 0        1080            20.648148            79.351852           93.248236
# 1         683            98.389458             1.610542           89.636022
# 2         920            51.956522            48.043478           92.786193
# 3        1014            30.276134            69.723866           93.113239
# 4         971            54.582904            45.417096           94.525145
#
#   Low Coding Capacity Warning  tRNAs         Host   Lowest Taxa         Genus  \
# 0                         NaN     62  Unspecified  Unclassified  Unclassified
# 1                         NaN     31  Unspecified  Unclassified  Unclassified
# 2                         NaN     34  Unspecified  Unclassified  Unclassified
# 3                         NaN     56  Unspecified  Unclassified  Unclassified
# 4                         NaN     45  Unspecified  Unclassified  Unclassified
#
#      Sub-family        Family         Order         Class        Phylum  \
# 0  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 1  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 2  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 3  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
# 4  Unclassified  Unclassified  Unclassified  Unclassified  Unclassified
#
#         Kingdom         Realm Baltimore Group Genbank Division  \
# 0  Unclassified  Unclassified    Unclassified              ENV
# 1  Unclassified  Unclassified    Unclassified              ENV
# 2  Unclassified  Unclassified    Unclassified              ENV
# 3  Unclassified  Unclassified    Unclassified              ENV
# 4  Unclassified  Unclassified    Unclassified              ENV
#
#   Isolation Host (beware inconsistent and nonsense values)
# 0                                        Unspecified
# 1                                        Unspecified
# 2                                        Unspecified
# 3                                        Unspecified
# 4                                        Unspecified

# %%
phages_unspec_host = util.get_phages_unspec_host(inphared_unspec_host)
# Out:
# Processed 1000 records
# Processed 2000 records
# Processed 3000 records
# Processed 4000 records
# Processed 5000 records
# Processed 6000 records
# Processed 7000 records
# Processed 8000 records
# Processed 9000 records
# Processed 10000 records
# Processed 11000 records
# Processed 12000 records
# Processed 13000 records
# Processed 14000 records
# Processed 15000 records
# Processed 16000 records
# Processed 17000 records
# Processed 18000 records
# Processed 19000 records
# Processed 20000 records
# Processed 21000 records
# Processed 22000 records
# Processed 23000 records
# Processed 24000 records
# Processed 25000 records
# Processed 26000 records
# Processed 27000 records
# Processed 28000 records
# Processed 29000 records
# Processed 30000 records
# Processed 31000 records

# %%
unfiltered_hosts = util.get_unfiltered_hosts()
genus_typo = util.get_genus_typo(f'{constants.GENUS_TYPO}')
unfiltered_suspected_genera = util.get_unfiltered_suspected_genera(constants.CANDIDATE_REGEX)

excluded_hosts = util.get_excluded_hosts(constants.ARCHAEA, constants.BACTERIA_NOT_GENUS, constants.EXCLUDED_HOSTS)
valid_hosts = util.get_valid_hosts()

# %% [markdown]
# Add another layer of checking to identify typos in GenBank annotations, as well as oversights during manual filtering:
# - Recheck genera in `valid_hosts` that are not in INPHARED's `Host` column.
# - Identify entries with minimum edit distance &leq; 2 (likely misspellings).
# <br>
#
# Adjust the exclusion and typo correction files in the `preprocessing` directory accordingly, and rerun the previous cell, as needed.

# %%
inphared_hosts = set(inphared_raw['Host'].str.lower())
valid_hosts - inphared_hosts
# Out:
# {'silvanigrella'}

# %%
valid_hosts_list = list(valid_hosts)
for i in range(len(valid_hosts_list)):
    for j in range(i + 1, len(valid_hosts_list)):
        if util.is_possible_misspelling(valid_hosts_list[i], valid_hosts_list[j]):
            print(valid_hosts_list[i], valid_hosts_list[j])
# Out:
# microbacterium mycobacterium

# %% [markdown]
# Update `host` column based on the manually filtered info from GenBank.

# %%
inphared_augmented = inphared_raw.copy(deep = True)
util.update_host_column(constants.CANDIDATE_REGEX, inphared_unspec_host, inphared_augmented)

inphared_augmented['Host'] = inphared_augmented['Host'].str.lower()
inphared_augmented['Host'].value_counts()
# Out:
# Index: 424 | Name: ON970599 | Host: gordonia
# Processed 1000 records
# Processed 2000 records
# Index: 2105 | Name: MN940411 | Host: staphylococcus
# Processed 3000 records
# Index: 3471 | Name: AF125163 | Host: vibrio
# Index: 3477 | Name: AF063097 | Host: escherichia
# Processed 4000 records
# Index: 3576 | Name: OK499975 | Host: proteus
# Index: 3705 | Name: OK649958 | Host: haloferax
# Index: 3761 | Name: MW822148 | Host: mycobacterium
# Processed 5000 records
# Index: 4552 | Name: MH590600 | Host: microbacterium
# Index: 4628 | Name: MH271321 | Host: microbacterium
# Index: 4643 | Name: MH155873 | Host: microbacterium
# Index: 5392 | Name: LC625742 | Host: enterococcus
# Processed 6000 records
# Processed 7000 records
# Processed 8000 records
# Processed 9000 records
# Index: 5662 | Name: MT588083 | Host: salmonella
# Processed 10000 records
# Processed 11000 records
# Processed 12000 records
# Processed 13000 records
# Processed 14000 records
# Processed 15000 records
# Processed 16000 records
# Processed 17000 records
# Processed 18000 records
# Index: 8414 | Name: MN857473 | Host: caulobacter
# Index: 8837 | Name: MN746332 | Host: caulobacter
# Processed 19000 records
# Index: 9294 | Name: MN161573 | Host: salmonella
# Index: 9451 | Name: MN882550 | Host: butyrivibrio
# Processed 20000 records
# Index: 10400 | Name: MN153797 | Host: escherichia
# Index: 10581 | Name: LC487997 | Host: escherichia
# Index: 10582 | Name: LC487996 | Host: escherichia
# Index: 10616 | Name: MG747435 | Host: ralstonia
# Processed 21000 records
# Index: 11284 | Name: MK310183 | Host: escherichia
# Processed 22000 records
# Index: 11806 | Name: MK310184 | Host: escherichia
# Processed 23000 records
# Processed 24000 records
# Index: 13732 | Name: MF155889 | Host: vibrio
# Index: 13982 | Name: CP017837 | Host: silvanigrella
# Index: 13984 | Name: CP017838 | Host: silvanigrella
# Processed 25000 records
# Index: 14453 | Name: KT232076 | Host: escherichia
# Index: 14569 | Name: JX412914 | Host: escherichia
# Index: 15013 | Name: AP012540 | Host: escherichia
# Index: 15014 | Name: AP012539 | Host: escherichia
# Index: 15015 | Name: AP012538 | Host: escherichia
# Index: 15016 | Name: AP012537 | Host: escherichia
# Index: 15017 | Name: AP012536 | Host: escherichia
# Index: 15018 | Name: AP012535 | Host: escherichia
# Index: 15019 | Name: AP012534 | Host: escherichia
# Index: 15020 | Name: AP012533 | Host: escherichia
# Index: 15021 | Name: AP012532 | Host: escherichia
# Index: 15022 | Name: AP012531 | Host: escherichia
# Index: 15023 | Name: AP012530 | Host: escherichia
# Index: 15024 | Name: AP012529 | Host: escherichia
# Index: 15025 | Name: AB008550 | Host: pseudomonas
# Processed 26000 records
# Index: 15577 | Name: GU942563 | Host: vibrio
# Processed 27000 records
# Index: 16396 | Name: KT254133 | Host: escherichia | chryseobacterium | pseudomonas
# Index: 16397 | Name: KT254132 | Host: escherichia | chryseobacterium | pseudomonas
# Index: 16398 | Name: KT254131 | Host: escherichia | chryseobacterium | pseudomonas
# Index: 16399 | Name: KT254130 | Host: escherichia | chryseobacterium | pseudomonas
# Index: 16621 | Name: KP296794 | Host: paenibacillus
# Index: 16623 | Name: KP296792 | Host: paenibacillus
# Processed 28000 records
# Index: 16741 | Name: KM236244 | Host: salmonella
# Index: 16806 | Name: KM458633 | Host: salmonella
# Index: 16878 | Name: FR719956 | Host: roseovarius
# Index: 17036 | Name: KJ619459 | Host: vibrio
# Index: 17123 | Name: AB720063 | Host: xanthomonas
# Index: 17158 | Name: KF598865 | Host: phormidium | plectonema
# Index: 17221 | Name: KC677662 | Host: salmonella
# Index: 17242 | Name: KC117378 | Host: haloarcula
# Index: 17286 | Name: KC292029 | Host: haloarcula
# Index: 17287 | Name: KC292028 | Host: haloarcula
# Index: 17288 | Name: KC292027 | Host: haloarcula
# Index: 17290 | Name: KC292025 | Host: haloarcula
# Index: 17291 | Name: KC292024 | Host: haloarcula
# Processed 29000 records
# Index: 17390 | Name: KC117377 | Host: haloarcula
# Index: 17391 | Name: KC117376 | Host: halorubrum
# Index: 17689 | Name: HQ711985 | Host: pseudomonas
# Index: 17855 | Name: HQ406778 | Host: salmonella
# Index: 17892 | Name: AM910650 | Host: pseudomonas
# Index: 17898 | Name: AM156909 | Host: escherichia
# Index: 17921 | Name: Y13918 | Host: pseudomonas
# Index: 17924 | Name: X99260 | Host: bacillus
# Index: 17948 | Name: AF424783 | Host: staphylococcus
# Index: 17959 | Name: FJ539135 | Host: escherichia
# Index: 17960 | Name: FJ539134 | Host: escherichia
# Index: 17961 | Name: FJ539133 | Host: escherichia
# Index: 17962 | Name: FJ539132 | Host: escherichia
# Processed 30000 records
# Index: 18007 | Name: BL2CG | Host: mycoplasma
# Index: 18033 | Name: AB370205 | Host: staphylococcus
# Index: 18262 | Name: AB255436 | Host: escherichia
# Index: 18264 | Name: AP004402 | Host: escherichia
# Index: 18269 | Name: AP001553 | Host: staphylococcus
# Index: 18278 | Name: AB012573 | Host: vibrio
# Index: 18280 | Name: AB370268 | Host: staphylococcus
# Index: 18281 | Name: AP008954 | Host: staphylococcus
# Index: 18282 | Name: AP008953 | Host: staphylococcus
# Index: 18288 | Name: EU794049 | Host: hamiltonella
# Index: 18359 | Name: AJ567472 | Host: acidianus
# Processed 31000 records
# unspecified                                     2566
# mycobacterium                                   2189
# escherichia                                     1627
# vibrio                                           852
# pseudomonas                                      826
# salmonella                                       744
# streptococcus                                    730
# klebsiella                                       628
# gordonia                                         579
# staphylococcus                                   508
# enterobacteria                                   498
# microbacterium                                   459
# bacillus                                         377
# lactococcus                                      364
# synechococcus                                    362
# arthrobacter                                     340
# streptomyces                                     310
# flavobacterium                                   247
# acinetobacter                                    196
# enterococcus                                     185
# rhizobium                                        154
# aeromonas                                        140
# erwinia                                          137
# shigella                                         128
# propionibacterium                                125
# yersinia                                         120
# rheinheimera                                     110
# campylobacter                                     95
# pectobacterium                                    92
# xanthomonas                                       91
# lactobacillus                                     89
# sigmofec                                          88
# clostridium                                       83
# serratia                                          76
# ralstonia                                         76
# burkholderia                                      75
# sulfolobus                                        75
# paenibacillus                                     66
# listeria                                          62
# stenotrophomonas                                  61
# rhodococcus                                       60
# enterobacter                                      60
# peromfec                                          55
# rhodobacter                                       54
# cellulophaga                                      53
# prochlorococcus                                   51
# dipodfec                                          48
# proteus                                           48
# pelagibacter                                      47
# citrobacter                                       46
# halorubrum                                        45
# bacteroides                                       43
# dickeya                                           39
# cronobacter                                       39
# corynebacterium                                   38
# brucella                                          37
# helicobacter                                      37
# caulobacter                                       33
# pseudoalteromonas                                 33
# moraxella                                         32
# achromobacter                                     31
# haloarcula                                        30
# providencia                                       26
# pantoea                                           24
# leuconostoc                                       23
# roseobacter                                       21
# brevundimonas                                     20
# brevibacterium                                    19
# liberibacter                                      18
# polaribacter                                      18
# shewanella                                        18
# acidianus                                         18
# edwardsiella                                      17
# alteromonas                                       17
# cutibacterium                                     17
# thermus                                           17
# wolbachia                                         16
# clostridioides                                    15
# ruegeria                                          15
# prevotella                                        15
# mycoplasma                                        14
# microcystis                                       13
# sinorhizobium                                     13
# agrobacterium                                     13
# mannheimia                                        12
# bifidobacterium                                   11
# kosakonia                                         11
# bordetella                                        11
# hafnia                                            10
# brevibacillus                                     10
# salinibacter                                       9
# fusobacterium                                      9
# pasteurella                                        9
# xylella                                            9
# leptospira                                         9
# paracoccus                                         8
# faecalibacterium                                   8
# morganella                                         8
# spiroplasma                                        6
# nocardia                                           6
# maribacter                                         6
# oenococcus                                         6
# sphingomonas                                       6
# ruminococcus                                       6
# geobacillus                                        6
# nodularia                                          6
# dinoroseobacter                                    6
# sulfitobacter                                      6
# tenacibaculum                                      5
# tsukamurella                                       5
# marinomonas                                        5
# butyrivibrio                                       5
# curtobacterium                                     5
# chlamydia                                          5
# nitratiruptor                                      5
# nitrosopumilus                                     5
# haloferax                                          4
# riemerella                                         4
# escherichia | chryseobacterium | pseudomonas       4
# ochrobactrum                                       4
# elizabethkingia                                    4
# methanobacterium                                   4
# exiguobacterium                                    4
# brochothrix                                        4
# delftia                                            3
# nostoc                                             3
# psychrobacillus                                    3
# acidithiobacillus                                  3
# haemophilus                                        3
# natrinema                                          3
# raoultella                                         3
# lentibacter                                        3
# marinobacter                                       3
# weissella                                          3
# bdellovibrio                                       3
# psychrobacter                                      3
# glutamicibacter                                    3
# parabacteroides                                    3
# carnobacterium                                     3
# actinomyces                                        3
# acidovorax                                         3
# acetobacter                                        3
# komagataeibacter                                   3
# curvibacter                                        3
# halomonas                                          3
# hamiltonella                                       3
# aeropyrum                                          3
# alcaligenes                                        3
# metallosphaera                                     3
# sodalis                                            3
# leclercia                                          2
# mesorhizobium                                      2
# methanosarcina                                     2
# salinivibrio                                       2
# silvanigrella                                      2
# plectonema                                         2
# thermobifida                                       2
# rhodovulum                                         2
# pyrobaculum                                        2
# xenohaliotis                                       2
# marinitoga                                         2
# meiothermus                                        2
# natrialba                                          2
# croceibacter                                       2
# thermoproteus                                      2
# clavibacter                                        2
# erysipelothrix                                     2
# roseburia                                          2
# cylindrospermopsis                                 2
# halobacterium                                      2
# tetraselmis                                        2
# phormidium                                         2
# erythrobacter                                      2
# thermococcus                                       2
# citromicrobium                                     2
# oceanospirillum                                    2
# altiarchaeum                                       2
# myxococcus                                         2
# sphaerotilus                                       2
# anabaena                                           2
# octadecabacter                                     2
# paraglaciecola                                     2
# roseovarius                                        2
# nonlabens                                          2
# caldibacillus                                      1
# nitrososphaera                                     1
# plesiomonas                                        1
# rathayibacter                                      1
# planktothrix                                       1
# sphingobium                                        1
# dunaliella                                         1
# aphanizomenon                                      1
# tetrasphaera                                       1
# salisaeta                                          1
# lysinibacillus                                     1
# saccharomonospora                                  1
# azospirillum                                       1
# celeribacter                                       1
# peptoclostridium                                   1
# skermania                                          1
# methanothermobacter                                1
# aggregatibacter                                    1
# lelliottia                                         1
# aurantimonas                                       1
# rhodoferax                                         1
# acaryochloris                                      1
# thermoanaerobacterium                              1
# iodobacter                                         1
# stygiolobus                                        1
# nitrincola                                         1
# actinoplanes                                       1
# listonella                                         1
# thiobacimonas                                      1
# thalassomonas                                      1
# pelagibaca                                         1
# silicibacter                                       1
# phormidium | plectonema                            1
# colwellia                                          1
# puniceispirillum                                   1
# kluyvera                                           1
# halogranum                                         1
# loktanella                                         1
# hydrogenobaculum                                   1
# bradyrhizobium                                     1
# aquamicrobium                                      1
# akkermansia                                        1
# gluconobacter                                      1
# levilactobacillus                                  1
# desulfovibrio                                      1
# pseudoxanthomonas                                  1
# halogeometricum                                    1
# hydrogenophilus                                    1
# lentisphaerae                                      1
# rahnella                                           1
# parageobacillus                                    1
# pseudaeromonas                                     1
# pararheinheimera                                   1
# lokiarchaeota                                      1
# chryseobacterium                                   1
# lactiplantibacillus                                1
# kurthia                                            1
# stappia                                            1
# pseudarthrobacter                                  1
# luteibacter                                        1
# tetragenococcus                                    1
# cytobacillus                                       1
# eggerthella                                        1
# janthinobacterium                                  1
# mycolicibacterium                                  1
# cedecea                                            1
# muninn                                             1
# huginn                                             1
# verrucomicrobia                                    1
# stxxx                                              1
# solobacterium                                      1
# methanoculleus                                     1
# pontimonas                                         1
# saccharolobus                                      1
# anoxybacillus                                      1
# mastigocladus                                      1
# azobacteroides                                     1
# virgibacillus                                      1
# aerococcus                                         1
# rothia                                             1
# aeribacillus                                       1
# photobacterium                                     1
# pediococcus                                        1
# sporosarcina                                       1
# phaeobacter                                        1
# aminobacter                                        1
# pseudanabaena                                      1
# winogradskyella                                    1
# micromonospora                                     1
# buttiauxella                                       1
# haloterrigena                                      1
# methanocaldococcus                                 1
# arthronema                                         1
# protaetiibacter                                    1
# gardnerella                                        1
# arcanobacterium                                    1
# cellulosimicrobium                                 1
# thermocrinis                                       1
# sphingopyxis                                       1
# olleya                                             1
# pyrococcus                                         1
# Name: Host, dtype: int64

# %% [markdown]
# ### Polyvalent Phages

# %% [markdown]
# There are only few polyvalent (multi-host) phages in our database. Hence, for simplicity, we map each polyvalent phage only to its host with the highest number of interacting phages in the dataset.

# %%
multiple_hosts = set()

for host, count in dict(inphared_augmented['Host'].value_counts()).items():
    if '|' in host:
        multiple_hosts.add(host)
        print(host, ':', count)
# Out:
# escherichia | chryseobacterium | pseudomonas : 4
# phormidium | plectonema : 1

# %%
for host in multiple_hosts:
    # We have confirmed that the first host is the host with the highest number of interacting phages in the dataset.
    inphared_augmented.loc[inphared_augmented['Host'] == host, 'Host'] = host.split(' | ')[0]

# %%
inphared = inphared_augmented.loc[inphared_augmented['Host'] != 'unspecified']
inphared.reset_index(inplace = True, drop = True)
inphared.head()
# Out:
#   Accession              Description  \
# 0  MK250029  Prevotella phage Lak-C1
# 1  MK250028  Prevotella phage Lak-B9
# 2  MK250027  Prevotella phage Lak-B8
# 3  MK250026  Prevotella phage Lak-B7
# 4  MK250025  Prevotella phage Lak-B6
#
#                                       Classification  Genome Length (bp)  \
# 0  Prevotella phage Lak-C1 Myoviridae Caudovirice...              540217
# 1  Prevotella phage Lak-B9 Myoviridae Caudovirice...              550053
# 2  Prevotella phage Lak-B8 Myoviridae Caudovirice...              551627
# 3  Prevotella phage Lak-B7 Myoviridae Caudovirice...              550702
# 4  Prevotella phage Lak-B6 Myoviridae Caudovirice...              546689
#
#    Jumbophage  molGC (%) Molecule Modification Date  Number CDS  \
# 0        True     25.796      DNA       13-JAN-2019         830
# 1        True     26.012      DNA       13-JAN-2019         859
# 2        True     26.022      DNA       13-JAN-2019         860
# 3        True     26.020      DNA       13-JAN-2019         859
# 4        True     26.029      DNA       13-JAN-2019         847
#
#    Positive Strand (%)  Negative Strand (%)  Coding Capacity(%)  \
# 0            47.108434            52.891566           68.324951
# 1            52.270081            47.729919           69.188424
# 2            53.023256            46.976744           69.318761
# 3            53.201397            46.798603           69.363285
# 4            52.656434            47.343566           69.118274
#
#   Low Coding Capacity Warning  tRNAs        Host Lowest Taxa         Genus  \
# 0                         NaN     30  prevotella  Myoviridae  Unclassified
# 1                         NaN     29  prevotella  Myoviridae  Unclassified
# 2                         NaN     33  prevotella  Myoviridae  Unclassified
# 3                         NaN     33  prevotella  Myoviridae  Unclassified
# 4                         NaN     30  prevotella  Myoviridae  Unclassified
#
#      Sub-family      Family         Order           Class       Phylum  \
# 0  Unclassified  Myoviridae  Unclassified  Caudoviricetes  Uroviricota
# 1  Unclassified  Myoviridae  Unclassified  Caudoviricetes  Uroviricota
# 2  Unclassified  Myoviridae  Unclassified  Caudoviricetes  Uroviricota
# 3  Unclassified  Myoviridae  Unclassified  Caudoviricetes  Uroviricota
# 4  Unclassified  Myoviridae  Unclassified  Caudoviricetes  Uroviricota
#
#           Kingdom          Realm Baltimore Group Genbank Division  \
# 0  Heunggongvirae  Duplodnaviria         Group I              ENV
# 1  Heunggongvirae  Duplodnaviria         Group I              ENV
# 2  Heunggongvirae  Duplodnaviria         Group I              ENV
# 3  Heunggongvirae  Duplodnaviria         Group I              ENV
# 4  Heunggongvirae  Duplodnaviria         Group I              ENV
#
#   Isolation Host (beware inconsistent and nonsense values)
# 0                                     Prevotella sp.
# 1                                     Prevotella sp.
# 2                                     Prevotella sp.
# 3                                     Prevotella sp.
# 4                                     Prevotella sp.

# %% [markdown]
# Replace the genera of some hosts with standard NCBI Taxonomy nomenclature.

# %%
inphared['Host'].replace(util.get_ncbi_standard_nomenclature(constants.NCBI_STANDARD_NOMENCLATURE), inplace = True)
inphared['Host'].value_counts()
# Out:
# mycobacterium                2189
# escherichia                  1632
# vibrio                        852
# pseudomonas                   826
# salmonella                    744
# streptococcus                 730
# klebsiella                    628
# gordonia                      579
# enterobacter                  558
# staphylococcus                508
# microbacterium                459
# bacillus                      377
# lactococcus                   364
# synechococcus                 362
# arthrobacter                  340
# streptomyces                  310
# flavobacterium                247
# acinetobacter                 196
# enterococcus                  185
# rhizobium                     154
# aeromonas                     140
# erwinia                       137
# shigella                      128
# propionibacterium             125
# yersinia                      120
# rheinheimera                  110
# campylobacter                  95
# pectobacterium                 92
# xanthomonas                    91
# lactobacillus                  89
# sigmofec                       88
# clostridium                    83
# serratia                       76
# ralstonia                      76
# burkholderia                   75
# sulfolobus                     75
# paenibacillus                  66
# listeria                       62
# stenotrophomonas               61
# rhodococcus                    60
# peromfec                       55
# rhodobacter                    54
# cellulophaga                   53
# prochlorococcus                51
# dipodfec                       48
# proteus                        48
# pelagibacter                   47
# citrobacter                    46
# halorubrum                     45
# bacteroides                    43
# cronobacter                    39
# dickeya                        39
# corynebacterium                38
# helicobacter                   37
# brucella                       37
# pseudoalteromonas              33
# caulobacter                    33
# moraxella                      32
# achromobacter                  31
# haloarcula                     30
# providencia                    26
# pantoea                        24
# leuconostoc                    23
# roseobacter                    21
# brevundimonas                  20
# brevibacterium                 19
# acidianus                      18
# polaribacter                   18
# shewanella                     18
# liberibacter                   18
# edwardsiella                   17
# cutibacterium                  17
# alteromonas                    17
# thermus                        17
# wolbachia                      16
# prevotella                     15
# clostridioides                 15
# ruegeria                       15
# mycoplasma                     14
# agrobacterium                  13
# sinorhizobium                  13
# microcystis                    13
# mannheimia                     12
# bifidobacterium                11
# kosakonia                      11
# bordetella                     11
# brevibacillus                  10
# hafnia                         10
# leptospira                      9
# fusobacterium                   9
# pasteurella                     9
# salinibacter                    9
# xylella                         9
# faecalibacterium                8
# paracoccus                      8
# morganella                      8
# nodularia                       6
# dinoroseobacter                 6
# maribacter                      6
# spiroplasma                     6
# oenococcus                      6
# sphingomonas                    6
# nocardia                        6
# sulfitobacter                   6
# ruminococcus                    6
# geobacillus                     6
# butyrivibrio                    5
# chlamydia                       5
# curtobacterium                  5
# tenacibaculum                   5
# nitrosopumilus                  5
# tsukamurella                    5
# marinomonas                     5
# nitratiruptor                   5
# elizabethkingia                 4
# exiguobacterium                 4
# methanobacterium                4
# brochothrix                     4
# ochrobactrum                    4
# riemerella                      4
# haloferax                       4
# parabacteroides                 3
# glutamicibacter                 3
# metallosphaera                  3
# psychrobacter                   3
# delftia                         3
# halomonas                       3
# actinomyces                     3
# curvibacter                     3
# psychrobacillus                 3
# acidithiobacillus               3
# marinobacter                    3
# weissella                       3
# natrinema                       3
# aeropyrum                       3
# bdellovibrio                    3
# sodalis                         3
# carnobacterium                  3
# lentibacter                     3
# nostoc                          3
# hamiltonella                    3
# komagataeibacter                3
# acetobacter                     3
# haemophilus                     3
# acidovorax                      3
# raoultella                      3
# phormidium                      3
# alcaligenes                     3
# thermoproteus                   2
# marinitoga                      2
# mesorhizobium                   2
# halobacterium                   2
# sphaerotilus                    2
# plectonema                      2
# cylindrospermopsis              2
# methanosarcina                  2
# clavibacter                     2
# candidatus odinarchaeum         2
# paraglaciecola                  2
# pyrobaculum                     2
# croceibacter                    2
# rhodovulum                      2
# natrialba                       2
# meiothermus                     2
# erythrobacter                   2
# thermobifida                    2
# salinivibrio                    2
# xenohaliotis                    2
# silvanigrella                   2
# erysipelothrix                  2
# leclercia                       2
# oceanospirillum                 2
# roseovarius                     2
# thermococcus                    2
# tetraselmis                     2
# anabaena                        2
# roseburia                       2
# altiarchaeum                    2
# nonlabens                       2
# citromicrobium                  2
# octadecabacter                  2
# myxococcus                      2
# peptoclostridium                1
# sphingobium                     1
# nitrososphaera                  1
# azospirillum                    1
# methanothermobacter             1
# thalassomonas                   1
# parageobacillus                 1
# kluyvera                        1
# actinoplanes                    1
# thiobacimonas                   1
# pelagibaca                      1
# planktothrix                    1
# aquamicrobium                   1
# bradyrhizobium                  1
# listonella                      1
# rathayibacter                   1
# silicibacter                    1
# colwellia                       1
# rahnella                        1
# tetrasphaera                    1
# nitrincola                      1
# puniceispirillum                1
# halogranum                      1
# stygiolobus                     1
# loktanella                      1
# thermoanaerobacterium           1
# lysinibacillus                  1
# dunaliella                      1
# aurantimonas                    1
# saccharomonospora               1
# aggregatibacter                 1
# lelliottia                      1
# hydrogenobaculum                1
# pseudaeromonas                  1
# skermania                       1
# celeribacter                    1
# iodobacter                      1
# salisaeta                       1
# rhodoferax                      1
# acaryochloris                   1
# caldibacillus                   1
# pseudoxanthomonas               1
# aphanizomenon                   1
# gardnerella                     1
# micromonospora                  1
# cytobacillus                    1
# buttiauxella                    1
# tetragenococcus                 1
# haloterrigena                   1
# methanocaldococcus              1
# arthronema                      1
# protaetiibacter                 1
# luteibacter                     1
# pseudarthrobacter               1
# chryseobacterium                1
# arcanobacterium                 1
# pseudanabaena                   1
# cellulosimicrobium              1
# thermocrinis                    1
# sphingopyxis                    1
# lactiplantibacillus             1
# olleya                          1
# levilactobacillus               1
# winogradskyella                 1
# methanoculleus                  1
# stappia                         1
# solobacterium                   1
# kurthia                         1
# eggerthella                     1
# janthinobacterium               1
# plesiomonas                     1
# virgibacillus                   1
# lentisphaerae                   1
# gluconobacter                   1
# pontimonas                      1
# hydrogenophilus                 1
# anoxybacillus                   1
# halogeometricum                 1
# mastigocladus                   1
# candidatus azobacteroides       1
# pararheinheimera                1
# akkermansia                     1
# verrucomicrobia                 1
# aerococcus                      1
# saccharolobus                   1
# lokiarchaeota                   1
# rothia                          1
# aeribacillus                    1
# desulfovibrio                   1
# photobacterium                  1
# pediococcus                     1
# cedecea                         1
# sporosarcina                    1
# mycolicibacterium               1
# phaeobacter                     1
# aminobacter                     1
# pyrococcus                      1
# Name: Host, dtype: int64

# %% [markdown]
# Just verifying that all the entries are unique

# %%
inphared.shape[0] == inphared['Accession'].nunique()
# Out:
# True

# %% [markdown]
# ###  Some Statistics

# %% [markdown]
# Statistics on phages

# %%
print("Original INPHARED:\t\t", inphared_raw.shape[0])
print("With Specified Hosts:\t\t", inphared_raw.shape[0] - inphared_unspec_host.shape[0])
print("Plus Manually Filtered Hosts:\t", inphared.shape[0])
# Out:
# Original INPHARED:		 18389
# With Specified Hosts:		 15739
# Plus Manually Filtered Hosts:	 15823

# %% [markdown]
# Statistics on host genera

# %%
print("Num. of Unique Host Genera:\t", inphared['Host'].nunique())
# Out:
# Num. of Unique Host Genera:	 279

# %% [markdown]
# Save the entries with host information to a CSV file.

# %%
inphared.to_csv(os.path.join(constants.TEMP_PREPROCESSING, constants.INPHARED_WITH_HOSTS), index = False)

# %% [markdown]
# <hr>

# %% [markdown]
# # Part III: Selection of Annotated Receptor-Binding Proteins (RBPs)

# %% [markdown]
# Load only the phage entries with host data.

# %%
inphared = pd.read_csv(f'{constants.TEMP_PREPROCESSING}/{constants.INPHARED_WITH_HOSTS}')
util.set_inphared(inphared)

inphared.shape
# Out:
# (15823, 27)

# %% [markdown]
# Identify which phage entries have CDS information and which do not.

# %%
no_cds_annot = util.get_no_cds_annot()
# Out:
# Processed 1000 records
# Processed 2000 records
# Processed 3000 records
# Processed 4000 records
# Processed 5000 records
# Processed 6000 records
# Processed 7000 records
# Processed 8000 records
# Processed 9000 records
# Processed 10000 records
# Processed 11000 records
# Processed 12000 records
# Processed 13000 records
# Processed 14000 records
# Processed 15000 records
# Processed 16000 records
# Processed 17000 records
# Processed 18000 records
# Processed 19000 records
# Processed 20000 records
# Processed 21000 records
# Processed 22000 records
# Processed 23000 records
# Processed 24000 records
# Processed 25000 records
# Processed 26000 records
# Processed 27000 records
# Processed 28000 records
# Processed 29000 records
# Processed 30000 records
# Processed 31000 records

# %%
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.NO_CDS_ANNOT),'wb') as no_cds_annot_file:
    pickle.dump(no_cds_annot, no_cds_annot_file)

# %%
with open(f'{constants.TEMP_PREPROCESSING}/{constants.NO_CDS_ANNOT}','rb') as no_cds_annot_file:
    no_cds_annot = pickle.load(no_cds_annot_file)
    
util.set_no_cds_annot(no_cds_annot)

# %% [markdown]
# ### Some statistics

# %%
print("Without CDS info:\t", len(no_cds_annot))
print("With CDS info:\t\t", inphared.shape[0] - len(no_cds_annot))
# Out:
# Without CDS info:	 665
# With CDS info:		 15158

# %% [markdown]
# ## *A. Process entries with CDS information*

# %% [markdown]
# - Use regex from this [RBP prediction study](https://www.mdpi.com/1999-4915/14/6/1329) by Boeckaerts <i>et al.</i> (2022) to select the annotated RBPs
#    - We modify this regex to:
#      - Make more accommodating to typos (e.g., look for `bind` instead of `binding`)
#      - Allow multiple spaces between tokens
#    - For comparison:
#      - Original regex: `tail.?(?:spike|fib(?:er|re))|^recept(?:o|e)r.?(?:binding|recognizing).*(?:protein)?|^RBP`
#      - Modified regex: `tail?(.?|\s*)(?:spike?|fib(?:er|re))|recept(?:o|e)r(.?|\s*)(?:bind|recogn).*(?:protein)?|(?<!\w)RBP(?!a)`
#      - Annotations captured by modified regex but not by old regex:
#        - `receptor recognition protein`
#    - The same [study](https://www.mdpi.com/1999-4915/14/6/1329) has an exclusion list that covers proteins related to RBPs but are not RBPs themselves (e.g., assembly and portal proteins).
#        <br><br>
#
# - If product does not match regex for RBP, check if it is a hypothetical protein
#    - The same [study](https://www.mdpi.com/1999-4915/14/6/1329) has a list of keywords associated with hypothetical proteins
#       - We remove `putative`, `probable`, and `probably` since they are indicative of a product with a putative (rather than an unknown) function.
#    - Make more accommodating to typos by allowing keywords with minimum edit distance ≤ 2 (likely misspellings)
#    - Create a manual list to handle cases where the keyword `hypothetical` is present but the putative function is already given, as in the case of:
#        - `conserved hypothetical lipoprotein`
#        - `hypothetical host-like ribonucleoside diphosphate reductase`       <br><br>
#
# - Predict whether these hypothetical proteins are RBPs using the XGBoost model from the [RBP prediction study](https://www.mdpi.com/1999-4915/14/6/1329) by Boeckaerts <i>et al.</i> (2022).

# %%
util.set_token_delimiter(constants.TOKEN_DELIMITER)
util.construct_keyword_list(constants.HYPOTHETICAL_KEYWORDS, constants.RBP_RELATED_NOT_RBP, constants.PUTATIVE_FUNCTIONS)

# %%
annot_products = util.get_annot_products()
# Out:
# Processed 1000 records
# Processed 2000 records
# Processed 3000 records
# Processed 4000 records
# Processed 5000 records
# Processed 6000 records
# Processed 7000 records
# Processed 8000 records
# Processed 9000 records
# Processed 10000 records
# Processed 11000 records
# Processed 12000 records
# Processed 13000 records
# Processed 14000 records
# Processed 15000 records
# Processed 16000 records
# Processed 17000 records
# Processed 18000 records
# Processed 19000 records
# Processed 20000 records
# Processed 21000 records
# Processed 22000 records
# Processed 23000 records
# Processed 24000 records
# Processed 25000 records
# Processed 26000 records
# Processed 27000 records
# Processed 28000 records
# Processed 29000 records
# Processed 30000 records
# Processed 31000 records

# %%
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.ANNOT_PRODUCTS),'wb') as annot_products_file:
    pickle.dump(annot_products, annot_products_file)

# %%
with open(f'{constants.TEMP_PREPROCESSING}/{constants.ANNOT_PRODUCTS}','rb') as annot_products_file:
    annot_products = pickle.load(annot_products_file)
    
util.set_annot_products(annot_products)
for annot_product in sorted(list(annot_products)):
    print(annot_product)
# Out:
# (2Fe-2S)-binding protein
# (E)-4-hydroxy-3-methylbut-2-enyl-diphosphate synthase
# (NAD(+)) DNA ligase
# (R,S)-reticuline 7-O-methyltransferase-like isoform X1
# (RecA-like) recombination and repair protein
# (p)ppGpp synthase/hydrolase
# (p)ppGpp synthetase, RelA/SpoT family
# (pyro)phosphatase or 5'(3')-deoxyribonucleotidase
# (thymidylate) synthase
# 0.2
# 0.3 protein
# 0.3B protein
# 0.4 protein
# 0.6
# 0.6A protein
# 0.6B protein
# 1
# 1, 4-beta-N-acetylmuramidase
# 1,4-alpha-glucan (glycogen) branching enzyme
# 1,4-alpha-glucan (glycogen) branching enzyme, GH-13-type
# 1,4-alpha-glucan (glycogen) branching enzyme, GH-13-type (EC
# 1,4-beta-N-acetylmuramidase
# 1,4-beta-N-acetylmuramidase or lysozyme
# 1,4-dihydroxy-6-naphthoate synthase
# 1,6-anhydro-N-acetylmuramyl-L-alanine amidase
# 1-(5-phosphoribosyl)-5-amino-4-imidazole- carboxylate carboxylase
# 1-(5-phosphoribosyl)-5-amino-4-imidazole- carboxylatecarboxylase
# 1-acyl-sn-glycerol-3-phosphate acyltransferase
# 1-aminocyclopropane-1-carboxylate deaminase
# 1-deoxy-D-xylulose-5-phosphate synthase
# 1-phosphofructokinase
# 1.05 protein
# 1.1 protein
# 1.45-like protein
# 1.5 protein
# 1.6 protein
# 1.7 protein
# 1.8 protein
# 10
# 10 kDa anti-sigma factor
# 10 kDa chaperonin
# 10.5
# 100 KDa protein
# 10R
# 11
# 11L protein
# 11R
# 12
# 12R
# 13
# 13' protein holin inhibitor
# 13.5
# 13.88 kDa late protein
# 13R
# 14
# 14-alpha-glucan (glycogen) branching enzyme GH-13-type
# 14R
# 15
# 15 kDa RNA polymerase-binding protein
# 15.5
# 15R
# 15kDa minor tail protein
# 16
# 16 kDa heat shock protein A
# 16.5 kDa protein
# 16.7 protein homologue (phi29)
# 160 kDa protein
# 16R
# 16S rRNA (guanine(527)-N(7))-methyltransferase
# 16S rRNA G1207 methylase
# 17
# 17 domain protein
# 17 kDa prohead core protein
# 17R
# 18
# 18.7 protein
# 188aa long conserved hypothetical protein
# 18R
# 19
# 19.2 protein
# 19.3 protein
# 19.5 protein
# 19R
# 1R
# 2
# 2 OG Fe(II) oxygenase
# 2'-5' RNA ligase
# 2'-5' RNA ligase superfamily protein
# 2'-deoxycytidine 5'-triphosphate deaminase
# 2-C-methyl-D-erythritol 4-phosphate cytidylyltransferase
# 2-amino-3-ketobutyrate coenzyme A ligase
# 2-deoxyribosyltransferase
# 2-deoxyuridine 5-triphosphate nucleotidohydrolase
# 2-diacylglycerol, 3-glucosyltransferase
# 2-isopropylmalate synthase
# 2-keto-3-deoxy-D-arabino-heptulosonate-7- phosphat e synthase I alpha
# 2-keto-3-deoxy-D-arabino-heptulosonate-7- phosphate synthase I
# 2-keto-3-deoxy-D-arabino-heptulosonate-7- phosphate synthase I alpha
# 2-ketobutyrate formate-lyase
# 2-ketobutyrate formate-lyase/ pyruvate formate-lyase
# 2-octaprenyl-3-methyl-6-methoxy-1,4-benzoquinol hydroxylase
# 2-oxoglutarate/Fe(II)-dependent oxygenase
# 2-polyprenylphenol hydrolase
# 2-polyprenylphenol hydrolase related flavodoxin oxidoreductase
# 2-polyprenylphenol hydrolase related flavoxin oxidoreductase
# 2-polyprenylphenol hydroxylase related flavodoxin oxidoreductase
# 2-succinylbenzoate-CoA ligase
# 2.8 protein
# 20
# 20R
# 20S proteasome A and B subunits
# 21
# 21R
# 22
# 22R
# 23
# 23R
# 23S rRNA (adenine(2058)-N(6))-dimethyltransferase
# 23S rRNA (adenine(2503)-C(2))-methyltransferase
# 23S rRNA (uracil(1939)-C(5))-methyltransferase
# 23S rRNA (uracil-5-)-methyltransferase
# 23S rRNA(uracil-5-)-methyltransferase RumA
# 23S rRNA-intervening sequence protein
# 24
# 24R
# 25
# 25L
# 26
# 26R
# 27
# 27R
# 28
# 28R
# 29
# 29R
# 2Fe-2S ferredoxin
# 2Fe-2S ferredoxin-like protein
# 2OG-Fe(II) oxygenase
# 2OG-Fe(II) oxygenase family enzyme
# 2OG-Fe(II) oxygenase family like protein
# 2OG-Fe(II) oxygenase family oxidoreductase
# 2OG-Fe(II) oxygenase family protein
# 2OG-Fe(II) oxygenase protein
# 2OG-Fe(II) oxygenase superfamily
# 2OG-Fe(II) oxygenase superfamily domain containing protein
# 2OG-Fe(II) oxygenase superfamily domain protein
# 2OG-Fe(II) oxygenase superfamily like protein
# 2OG-Fe(II) oxygenase superfamily protein
# 2OG-Fe(II) oxygenase superfamily-like protein
# 2R
# 3
# 3' exoribonuclease
# 3' exoribonuclease RNase T-like protein
# 3' exoribonuclease family protein
# 3' phosphatase
# 3' phosphatase and 5' polynucleotide kinase
# 3' to 5' DNA exonuclease
# 3' to 5' exonuclease
# 3''-phosphoadenosine 5''-phosphosulfate sulfotransferase/FAD synthetase-related enzyme
# 3',5'-cyclic AMP phosphodiesterase protein
# 3',5'-cyclic adenosine monophosphate phosphodiesterase
# 3'-5' exonuclease
# 3'-5' exonuclease and polymerase domains containing DNA polymerase I
# 3'-5' exonuclease and polymerase domains containing uracil DNA glycosylase family 4
# 3'-5' exonuclease domain protein
# 3'-5' exonuclease family protein
# 3'-5' exonuclease pol-B
# 3'-5' exonuclease related to the exonuclease domain of PolB
# 3'-5' exoribonuclease
# 3'-5' polynucleotide kinase
# 3'-5' proof-reading exoribonuclease
# 3'-5'-exonuclease
# 3'-5'exonuclease and polymerase domain protein
# 3'-exoribonuclease
# 3'-phosphatase
# 3'-phosphatase 5'-polynucleotide kinase
# 3'-phosphatase and 5'-polynucleotide kinase
# 3'-phosphatase, 5'-polynucleotide kinase
# 3'-phosphatase, 5'-polynucleotide kinase, phage-associated
# 3'-phosphatase, 5'-polynucleotide kinase,phage-associated
# 3'-phosphatase,5'-polynucleotide kinase
# 3'-phosphate, 5'-polynucleotide kinase
# 3'-phosphoadenosine 5'-phosphosulfate sulfotransferase (PAPS reductase)/FAD synthetase
# 3'-to-5' oligoribonuclease A
# 3'phosphatase 5'polynucleotide kinase
# 3'phosphatase, 5'polynucleotide kinase
# 3,4-dihydroxy-2-butanone 4-phosphate synthase
# 3--5'exoribonuclease
# 3-5 exonuclease
# 3-beta hydroxysteroid dehydrogenase
# 3-dehydroquinate dehydratase I
# 3-dehydroquinate synthase
# 3-deoxy-7-phosphoheptulonate synthase
# 3-helical bundle, B-form DNA mimic
# 3-ketoacyl-CoA thiolase
# 3-methyl-2-oxobutanoate hydroxymethyltransferase
# 3-oxoacyl-(acyl-carrier-protein) reductase
# 3-oxoacyl-[acyl-carrier protein] reductase
# 3-phosphatase, 5-polynucleotide kinase
# 3-polyprenyl-4-hydroxybenzoate carboxy-lyase
# 3.7 protein
# 3.8 protein
# 30
# 30 kDa protein
# 30L
# 30S ribosomal protein
# 30S ribosomal protein S21
# 30S ribosomal protein S3
# 30S ribosomal protein S4
# 30S ribosomal protein S8
# 30S ribosomal protein subunit S22 family
# 30S ribosomal subunit-like protein
# 31
# 31L
# 32
# 32 kDa protein
# 32 kDa protein [Escherichia phage N4]
# 32 kDa structural protein
# 32L
# 33
# 33.8 kDa early protein
# 33L
# 33aL
# 34
# 34L
# 35
# 35L
# 36
# 36K type signal peptide peptidase SppA
# 36L
# 37
# 37 kD pre-early protein
# 37-kD nucleoid-associated family protein
# 37L
# 38
# 38 kDa minor structural protein
# 38L
# 39
# 39L
# 3D (Asp-Asp-Asp) domain-containing protein
# 3D domain containing protein
# 3D domain family protein
# 3D domain protein
# 3D domain-containing protein
# 3D-domain containing protein
# 3R
# 4
# 4'-P-pantetheinyl transferase
# 4-hydroxy-3-methylbut-2-enyl-diphosphate synthase
# 4-hydroxy-3-polyprenylbenzoate decarboxylase
# 4-hydroxyphenylacetate 3-monooxygenase
# 4.2 protein
# 4.3 protein
# 4.5 protein
# 4.7 protein
# 40
# 40L
# 41
# 41 helicase
# 41L
# 42
# 42.3
# 42L
# 43
# 43 kDa tail protein
# 43L
# 44
# 44 kDa structural protein
# 44L
# 45
# 45L
# 46.1 gene product
# 46L
# 47
# 47L
# 48
# 48L
# 49
# 49L
# 4B
# 4Fe-4S ferredoxin
# 4Fe-4S single cluster domain protein
# 4Fe-4S single cluster domain-containing protein
# 4R
# 5
# 5 -3 exonuclease
# 5 -polynucleotide kinase/3 -phosphatase
# 5' - 3' exonuclease
# 5' nucleotidase
# 5' nucleotidase deoxy (pyrimidine) cytosolic type C protein
# 5' nucleotidase, deoxy (Pyrimidine), cytosolic type C protein
# 5' nucleotidase, deoxy (Pyrimidine), cytosolic type C protein (NT5C)
# 5' nucleotidase, deoxy family protein
# 5' to 3' DNA helicase-like protein
# 5' to 3' exonuclease
# 5' to 3' exonuclease-like protein
# 5'(3') deoxyribonucleotidase
# 5'(3')-deoxyribonucleotidase
# 5'(3')-deoxyribonucleotidase, cytosolic type
# 5'-3' DNA helicase-like protein
# 5'-3' and 3'-5' helicase
# 5'-3' deoxyribonucleotidase
# 5'-3' exonuclease
# 5'-3' exonuclease protein
# 5'-3' exonuclease-like protein
# 5'-3' specific dsDNA exonuclease RecE
# 5'-3'-exonuclease
# 5'-3'exonuclease
# 5'-deoxynucleotidase
# 5'-deoxynucleotidase protein
# 5'-deoxyribonucleotidase
# 5'-deoxyribonucleotide monophosphatase
# 5'-exonuclease
# 5'-nucleotidase
# 5'-nucleotidase protein
# 5'3' exonuclease
# 5'3' exonuclease-like protein
# 5'polynucleotide kinase
# 5'polynucleotide kinase-3'phosphatase
# 5,5-phosphoribosylformylglycinamide amidotransferase
# 5-amino-6-(5-phospho-D-ribitylamino)uracil phosphatase
# 5-amino-6-(5-phosphoribosylamino)uracil reductase
# 5-aminoimidazole-4-carboxamide ribonucleotide formyltransferase/IMP cyclohydrolase
# 5-formyltetrahydrofolate cyclo-ligase
# 5-methylcytosine specific restriction system component McrB
# 5-methylcytosine specific restriction system component McrC
# 5-methylcytosine-specific restriction endonuclease
# 5-methylcytosine-specific restriction enzyme A
# 5-phosphoribosylformylglycinamide amidotransferase
# 5-prime nucleotidase
# 5.3 protein
# 5.7 protein
# 5.9 protein
# 50
# 50-kDa virion protein
# 50L
# 50S ribosomal protein L13
# 50S ribosomal protein L20
# 50S ribosomal protein L29P
# 50S ribosomal protein L31
# 50S ribosome-binding GTPase
# 50s ribosomal protein l2
# 51
# 51.5 kDa protein
# 51L
# 52
# 52L
# 53 ORF 49-like protein
# 53L
# 54
# 54L
# 55
# 55 kDa structural protein
# 55.4 gene product [Enterobacteria phage IME08]
# 55L
# 56
# 56L
# 57A chaperone for long tail fiber formation
# 57B conserved hypothetical protein
# 57R
# 58
# 58R
# 59 protein
# 59R
# 5B protein
# 5R
# 5\'-3\' exonuclease-like protein
# 6
# 6 kDa early secretory antigenic target ESAT-6
# 6,7-dimethyl-8-ribityllumazine synthase
# 6-carboxy-5,6,7,8-tetrahydropterin synthase
# 6-carboxy-5,6,7,8-tetrahydropterin synthase [Enterobacteria phage 9g]
# 6-carboxy-5678-tetrahydropterin synthase
# 6-carboxytetrahydropterin synthase
# 6-carboxytetrahydrpterin synthase
# 6-fold neck region protein
# 6-phosphofructokinase
# 6-phosphogluconate dehydrogenase
# 6-phosphogluconate dehydrogenase decarboxylating gnd
# 6-phosphogluconate dehydrogenase protein
# 6-phosphogluconate dehydrogenase, decarboxylating
# 6-phosphogluconate dehyrogenase
# 6-pyruvoyl tetrahydrobiopterin synthase
# 6-pyruvoyl tetrahydropterin synthase
# 6-pyruvoyl tetrahydropterin synthase / queuosine biosynthesis protein
# 6-pyruvoyl tetrahydropterin synthase QueD
# 6-pyruvoyl tetrahydropterin synthase protein
# 6-pyruvoyl tetrahydropterin synthase-like protein
# 6-pyruvoyl tetrahydropterin synthase/QueD family protein
# 6-pyruvoyl-tetrahydropterin synthase
# 6-pyruvoyltetrahydropterin synthase
# 6.3 protein
# 6.5 protein
# 6.7 protein
# 60 kDa chaperonin
# 60 kDa chaperonin 5
# 60 kDa protein
# 60S ribosomal-like protein L2-A
# 62 kDa structural protein
# 62KDa structural protein
# 62kDa structural protein
# 66 kDa protein
# 6N-adenine methylase
# 6R
# 7
# 7 kDa DNA binding protein
# 7,8-diaminopelargonic acid synthase, PLP-dependent
# 7-carboxy-7-deazaguanine (CDG) synthase / queuosine biosynthesis protein
# 7-carboxy-7-deazaguanine synthase
# 7-carboxy-7-deazaguanine synthase QueE
# 7-carboxy-7-deazaguanine synthase-like protein
# 7-cyano-7-deazaguanine reductase
# 7-cyano-7-deazaguanine synthase
# 7-cyano-7-deazaguanosine synthase
# 7-cyano-7-deazagunaine synthase
# 7-deazaguanosine inserting enzyme
# 7.7 protein
# 70S ribosomal subunit-like protein
# 7R
# 8
# 8-amino-7-oxononanoate synthase
# 8-oxo-dGTP diphosphatase
# 8.4 kDa cro protein
# 8R
# 9
# 9-O-acetyl-N-acetylneuraminic acid deacetylase
# 94 kDa protein
# 9R
# A
# A protein
# A transposase
# A*
# A* protein
# A-family DNA polymerase
# A-gt
# A-kinase anchor protein 5
# A-protein
# A/G-specific adenine glycosylase
# A1
# A1 DNA transfer protein
# A1 protein
# A1 protein precursor
# A1 read-through protein
# A1-like protein
# A1-protein
# A111
# A138
# A169
# A2
# A2 DNA-binding protein
# A2 maturation protein
# A2 protein
# A2-A3 protein
# A49
# A74
# A81
# A814
# A83
# A89
# A; DNA packaging;641
# AAA + ATPase
# AAA ATPase
# AAA ATPase domain-containing protein
# AAA Family ATPase
# AAA and cbbQ type domains containing protein
# AAA domain ATPase
# AAA domain containing protein
# AAA domain family protein
# AAA domain protein
# AAA domain-containing protein
# AAA family ATPase
# AAA family ATPase [Escherichia phage FFH2]
# AAA family ATPase domain-containing protein
# AAA family ATPase protein
# AAA protein
# AAA superfamily ATPase
# AAA superfamily ATPase_gp183
# AAA+ ATPase
# AAA+ ATPase domain protein
# AAA+ ATPase protein
# AAA+ ATPase-domain protein
# AAA+ family ATPase
# AAA+ superfamily ATPase
# AAA+ATPase
# AAA-ATPase
# AAA-ATPase DNA transposition protein
# AAA-ATPase domain protein
# AAA-binding protein
# AAA-like domain protein
# AAA-type ATPase
# AAA_18 domain-containing protein
# AAA_24 domain protein
# AAA_24 domain-containing protein
# AAA_25 domain-containing protein
# AAA_28 domain-containing protein
# AAA_5 domain containing protein
# AAA_5 domain-containing protein
# AB1gp01
# AB1gp02
# AB1gp03
# AB1gp04
# AB1gp05
# AB1gp06
# AB1gp07
# AB1gp08
# AB1gp09
# AB1gp10
# AB1gp11
# AB1gp12
# AB1gp13
# AB1gp14
# AB1gp15
# AB1gp16
# AB1gp17
# AB1gp18
# AB1gp19
# AB1gp20
# AB1gp21
# AB1gp22
# AB1gp23
# AB1gp24
# AB1gp25
# AB1gp26
# AB1gp27
# AB1gp28
# AB1gp29
# AB1gp30
# AB1gp31
# AB1gp32
# AB1gp33
# AB1gp34
# AB1gp35
# AB1gp36
# AB1gp37
# AB1gp38
# AB1gp39
# AB1gp40
# AB1gp41
# AB1gp42
# AB1gp43
# AB1gp44
# AB1gp45
# AB1gp46
# AB1gp47
# AB1gp48
# AB1gp49
# AB1gp50
# AB1gp51
# AB1gp52
# AB1gp53
# AB1gp54
# AB1gp55
# AB1gp56
# AB1gp57
# AB1gp58
# AB1gp59
# AB1gp60
# AB1gp61
# AB1gp62
# AB1gp63
# AB1gp64
# AB1gp65
# AB1gp66
# AB1gp67
# AB1gp68
# AB1gp69
# AB1gp70
# AB1gp71
# AB1gp72
# AB1gp73
# AB1gp74
# AB1gp75
# AB1gp76
# AB1gp77
# AB1gp78
# AB1gp79
# AB1gp80
# AB1gp81
# AB1gp82
# AB1gp83
# AB1gp84
# AB1gp85
# ABC Transporter
# ABC amino acid transporter substrate-binding protein
# ABC transport-like domain protein
# ABC transporter
# ABC transporter ATP-binding
# ABC transporter ATP-binding protein
# ABC transporter ATPase
# ABC transporter G family protein
# ABC transporter permease
# ABC transporter permease subunit
# ABC transporter permease/ATP-binding protein
# ABC transporter substrate-binding protein
# ABC transporter, ATP-binding protein
# ABC transporter, ATP-binding protein-related protein
# ABC transporter, permease protein
# ABC transporter, substrate binding protein, phosphate
# ABC transporter, substrate-binding protein
# ABC transporter-like protein
# ABC-ATPase
# ABC-F type ribosomal protection protein
# ABC-type ATPase fused to a predicted acyltransferase domain
# ABC-type cobalt transporter
# ABC-type dipeptide/oligopeptide/nickel transport system, permease component
# ABC-type histidine transport system, ATPase component
# ABC-type oligopeptide transport system
# ABC-type phosphate transport system
# ABC-type phosphate transport system, substrate binder
# ABC-type polar amino acid transport system
# ABC-type polar amino acid transport system, ATPase component
# ABC-type proline/glycine betaine transport system, ATPase component
# ABC-type transport system, ATP-binding protein
# AC4 protein
# ACE protein
# ACSH domain containing protein
# ADDz_ATRX-domain containing protein
# ADP ribose binding protein
# ADP ribose-1-P processing protein
# ADP ribosylase
# ADP ribosylglycohydrolase
# ADP ribosyltransferase
# ADP-L-glycero-D-manno-heptose-6-epimerase
# ADP-L-glycero-D-mannoheptose-6-epimerase
# ADP-glyceromanno-heptose 6-epimerase
# ADP-heptose synthase
# ADP-heptose synthase / D-glycero-beta-D-manno-heptose 7-phosphate kinase
# ADP-ribose 1''-phosphate phophatase related protein
# ADP-ribose 1-phosphate phophatase related protein
# ADP-ribose 1-phosphate phophatase-related protein
# ADP-ribose 1-phosphate phosphatase
# ADP-ribose binding module protein
# ADP-ribose binding protein
# ADP-ribose polymerase
# ADP-ribose pyrophosphatase
# ADP-ribose-binding protein
# ADP-ribosyl glycohydrolase
# ADP-ribosyl transferase
# ADP-ribosyl-(dinitrogen reductase) hydrolase
# ADP-ribosyl-[dinitrogen reductase] glycohydrolase
# ADP-ribosylarginine hydrolase
# ADP-ribosylase
# ADP-ribosylase [Escherichia phage wV7]
# ADP-ribosylation
# ADP-ribosylglycohydrolase
# ADP-ribosylglycohydrolase family protein
# ADP-ribosyltransferase
# ADP-ribosyltransferase domain and MuF-like fusion protein
# ADP-ribosyltransferase enzymatic component
# ADP-ribosyltransferase exoenzyme
# ADP-ribosyltransferase subunit
# ADP-ribosyltrnsferase
# ADP-rybosylase
# AI-2E family transporter
# AIG2-like gamma-glutamyl cyclotransferase
# AIPR protein
# AIPR superfamily protein
# ALP protein
# ALT
# AMP-binding enzyme family protein-like protein
# AMP-dependent synthetase
# ANK_REP_REGION domain-containing protein
# ANR family transcriptional regulator
# ANT-domain containing protein
# ANTAR domain protein
# AP endonuclease
# AP2 domain
# AP2 domain protein
# AP2 domain-containing protein
# AP2/ERF domain protein
# APC amino acid-polyamine-organocation transporter
# APH-like putative serine/threonine kinase
# ARC repressor
# ASC RNA binding protein
# ASC-1 homology domain protein
# ASC-1 transciption coactivator
# ASC-1 transcription coactivator
# ASC-1 transcriptional coactivator
# ASC-1-like domain protein
# ASC-1-like protein
# ASCH RNA-binding domain containing protein
# ASCH domain containing protein
# ASCH domain protein
# ASCH domain-containing protein
# ASCH domain-containing/PUA-like superfamily protein
# ATP GTP binding protein
# ATP binding cassette transporter
# ATP binding cassette-like protein
# ATP binding domain TrwB-like protein
# ATP binding domain containing protein
# ATP binding domain protein
# ATP binding protein
# ATP cone domain protein
# ATP dependent Clp protease
# ATP dependent DNA helicase
# ATP dependent DNA ligase
# ATP dependent DNA ligase domain protein
# ATP dependent DNA lygase
# ATP dependent RNA helicase
# ATP dependent helicase
# ATP dependent protease ATP-binding subunit
# ATP synthase
# ATP synthase F0 sector subunit b
# ATP synthase subunit
# ATP synthase subunit A
# ATP synthase subunit alpha
# ATP synthase subunit b protein
# ATP synthase-related protein
# ATP-GRAPS enzyme
# ATP-binding cassette domain-containing protein
# ATP-binding cassette sub-family C member 8 isoform 2
# ATP-binding cassette transporter nucleotide-binding domain containing protein
# ATP-binding domain protein
# ATP-binding domain-containing protein
# ATP-binding phage protein
# ATP-binding protein
# ATP-binding sugar transporter
# ATP-binding sugar transporter family protein
# ATP-binding sugar transporter protein
# ATP-binding tail sheath protein
# ATP-binding/permease protein
# ATP-depedent RecD-like DNA helicase
# ATP-dependent 23S rRNA helicase
# ATP-dependent CIp protease
# ATP-dependent CLP protease
# ATP-dependent Caseinolytic protease
# ATP-dependent Clp endopeptidase
# ATP-dependent Clp endopeptidase proteolytic subunit
# ATP-dependent Clp endopeptidase, proteolytic subunit
# ATP-dependent Clp protease
# ATP-dependent Clp protease ATP-binding subunit
# ATP-dependent Clp protease ATP-binding subunit ClpA
# ATP-dependent Clp protease ATP-binding subunit ClpX
# ATP-dependent Clp protease ATP-binding subunit clpA
# ATP-dependent Clp protease adapter protein
# ATP-dependent Clp protease adapter protein ClpS
# ATP-dependent Clp protease adaptor protein
# ATP-dependent Clp protease proetolytic subunit
# ATP-dependent Clp protease proteolytic subunit
# ATP-dependent Clp protease proteolytic subunit (EC
# ATP-dependent Clp protease proteolytic subunit 1
# ATP-dependent Clp protease proteolytic subunit 2
# ATP-dependent Clp protease proteolytic subunit ClpP
# ATP-dependent Clp protease proteolytic subunit_gp034
# ATP-dependent Clp protease, proteolytic subunit
# ATP-dependent Clp proteolytic subunit
# ATP-dependent ClpP protease
# ATP-dependent DNA Helicase
# ATP-dependent DNA helicase
# ATP-dependent DNA helicase RecQ
# ATP-dependent DNA helicase RecQ-like protein
# ATP-dependent DNA helicase UvsW
# ATP-dependent DNA helicase UvsW domain-containing protein
# ATP-dependent DNA helicase protein
# ATP-dependent DNA helicase uvsW
# ATP-dependent DNA ligase
# ATP-dependent DNA ligase [Aeromonas phagePZL-Ah8]
# ATP-dependent DNA ligase [Enterobacteria phage 9g]
# ATP-dependent DNA ligase [Escherichia phage vB_EcoM-ECP32]
# ATP-dependent DNA ligase [Escherichia phage vB_EcoM_FFH2]
# ATP-dependent DNA ligase protein
# ATP-dependent DNA ligase, phage-associated
# ATP-dependent DNA ligase-like protein
# ATP-dependent DNA or RNA helicase
# ATP-dependent DNA repair recombination helicase
# ATP-dependent DNA/RNA helicase
# ATP-dependent RNA helicase
# ATP-dependent RNA-DNA and DNA-DNA helicase
# ATP-dependent RNA-DNA and DNA-DNA helicase protein
# ATP-dependent RecD-like DNA helicase
# ATP-dependent RecD-like DNA helicase protein
# ATP-dependent chaperone
# ATP-dependent clp protease
# ATP-dependent dethiobiotin synthetase
# ATP-dependent endonuclease
# ATP-dependent endopeptidase
# ATP-dependent endopeptidase clp proteolytic subunit
# ATP-dependent endopeptidase clp proteolytic subunit clpP
# ATP-dependent exonuclease
# ATP-dependent exonuclease V
# ATP-dependent exonuclease-like protein
# ATP-dependent helicase
# ATP-dependent helicase 41
# ATP-dependent helicase protein
# ATP-dependent helicase/nuclease
# ATP-dependent ligase
# ATP-dependent metalloprotease
# ATP-dependent molecular chaperone
# ATP-dependent protease
# ATP-dependent protease ATP-binding subunit
# ATP-dependent protease La type I
# ATP-dependent protease protein subunit
# ATP-dependent protease proteolytic subunit
# ATP-dependent protease subunit
# ATP-dependent protease subunit HslV
# ATP-dependent protease, peptidase subunit
# ATP-dependent serine Clp protease
# ATP-dependent serine endopeptidase
# ATP-dependent serine protease
# ATP-dependent zinc metalloprotease
# ATP-dependent zinc metalloprotease FtsH
# ATP-dependent+helicase+HepA,DNA+methylase, SNF2+family+N-terminal+domain
# ATP-grasp domain containing protein
# ATP-grasp domain-containing protein
# ATP-grasp enzyme
# ATP-grasp fold subdomain 2 protein
# ATP/GTP binding protein
# ATP/GTP-binding protein
# ATP:guanido phosphotransferase catalytic domain protein
# ATPase
# ATPase 8
# ATPase AAA
# ATPase DNA encapsidation protein
# ATPase DNA helicase
# ATPase FtsK/SpoIIIE
# ATPase [Enterobacteria phage 9g]
# ATPase aaa family
# ATPase associated protein
# ATPase associated with various cellular activities family protein
# ATPase component
# ATPase component of ABC transporter
# ATPase component of the ABC-type cobalamin/Fe3+-siderophores transport system
# ATPase containing protein
# ATPase domain containing protein
# ATPase domain protein
# ATPase domain-containing protein
# ATPase encapsidation protein
# ATPase family protein
# ATPase proteolipid family protein
# ATPase related to the helicase subunit of the Holliday junction resolvase
# ATPase subunit of terminase family protein
# ATPase, AAA family
# ATPase, ATP-binding subunit
# ATPase, DNA encapsidation protein
# ATPase, kinase
# ATPase-like protein
# Abc1
# Abc1 protein
# Abc2
# Abc2 protein
# Abc2; anti-RecBCD
# Abi family protein
# Abi-like protein
# AbiF-like protein
# AbrB family transcriptional regulator
# AbrB family transcriptional regulator-like protein
# AbrB/MazE/SpoVT family DNA-binding domain-containing protein
# Ac acridine resistance protein
# Ace
# Acetyl-CoA acetyltransferase
# Acetyltransferase
# Acetyltransferase (EC
# Acetyltransferase (GNAT) family protein
# Acr-like protein
# AcrIIA5
# AcrIIA6
# Acridine resistance
# Acriflavin resistance protein
# Activator of middle period transcription
# Acyl carrier protein
# Acyl-CoA N-acyltransferase
# Ad1 Head-tail adaptor protein
# Ad1 adapter protein
# Ad1 adaptor protein
# Ad1,neck-tail adaptor protein
# Ada-like Zn-binding domain protein
# Adaptive-response sensory-kinase SasA
# Adaptor
# Adaptor protein Ad1
# AddA-like dsDNA break-binding protein
# Adenine methyltransferase
# Adenine-specific DNA methylase
# Adenine-specific methyltransferase
# Adenosine monophosphate-protein transferase VbhT
# Adenylylsulfate kinase
# AdoMet-MTase
# Aerobic NDP reducatse, small subunit
# Aerobic NDP reductase small subunit
# Aerobic NDP reductase, large subunit
# Aerobic NDP reductase, small subunit
# Aggregation promoting factor
# Ail/PagC/OmpX porin
# AimP
# AimR family lysis-lysogeny pheromone receptor
# Alc
# Alc inhibitor of host transcription
# Alc protein
# Alc-like inhibitor of host transcription
# Alc-like transcription inhibitor
# AlpA
# AlpA family phage regulatory protein
# AlpA family regulatory protein
# AlpA family transcriptional regulator
# AlpA regulatory protein
# AlpA-like DNA binding protein
# AlpA-like protein
# AlpA-like regulatory protein
# AlpA-like transcriptional activator
# AlpA-like transcriptional regulator
# Alpha-glutamyl/putrescinyl thymine pyrophosphorylase clade 1
# Alpha-glutamyl/putrescinyl thymine pyrophosphorylase clade 2
# Alpha/Beta hydrolase
# Alt
# Alt RNA polymerase ADP-ribosylase
# Alt-like ADP-ribosyltransferase
# Alt-like RNA polymerase ADP-ribosyltransferase
# Alt.-1 hypothetical protein
# Alt.-2 hypothetical protein
# Alt.-3 conserved hypothetical protein
# Alt.1 conserved hypothetical protein
# AmdI, N-acetylmuramoyl-L-alanine-amidase
# Amidase
# Amidoligase
# Aminidotransferase
# Amino cyclopropane -1- carboxylate deaminase
# Anaerobic NTP reductase large subunit
# Anaerobic NTP reductase small subunit
# Anaerobic dimethyl sulfoxide reductase subunit B
# Anaerobic nucleoside diphosphate reductase
# Anaerobic ribonucleoside-triphosphate reductase
# Anaerobic ribonucleoside-triphosphate reductase-activating protein
# Ant
# Ant protein
# Ant-like antirepressor protein
# Ant-like transcriptional antiterminator
# Ant1
# Ant2
# AntA domain protein
# AntA/AntB antirepressor
# AntA/AntB antirepressor domain-containing protein
# Anti-RecBCD protein 1
# Anti-Sigma Factor A
# Anti-sigma 70 protein
# Anti-sigma factor
# Antilisterial bacteriocin subtilosin biosynthesis protein AlbA
# Antirepressor protein
# Antirepressor protein Ant1
# Antirestriction protein
# Antitermination protein
# Antitermination protein Q
# Antitoxin Phd
# Apaf-1 related killer DARK
# Apaf-1 related killer DARK late transcriptional regulator
# Apaf-1 related killer dark
# Apl
# Appendage
# Appr-1-P processing domain-containing protein
# Appr-1-p processing domain protein
# Appr-1-p processing enzyme
# Appr-1-p processing enzyme family
# Appr-1-p processing enzyme family protein
# Appr-1-p processing protein
# Appr-1-p processing-like protein
# Appr-1-processing protein
# AprU family transcriptional regulator
# AprU late transcriptional regulator
# AprU transcriptional regulator
# AraC family transcriptional regulator
# AraC-type DNA-binding protein
# Arabinose 5-phosphate isomerase KpsF
# Arc
# Arc family DNA binding protein
# Arc family DNA-binding protein
# Arc protein
# Arc repressor
# Arc transcriptional repressor protein
# Arc type transcriptional repressor
# Arc-family DNA-binding protein
# Arc-family transcriptional repressor
# Arc-like DNA binding domain
# Arc-like DNA binding domain containing protein
# Arc-like DNA binding domain protein
# Arc-like DNA-binding domain-containing protein
# Arc-like DNA-binding protein
# Arc-like repressor
# Arc-like transcriptional regulator
# Arc/Mnt/CopG DNA-binding domain-containing protein
# Arc; transcriptional repressor
# Archaeal-type Holliday junction resolvase
# ArdA-like antirestriction protein
# ArdA-like antrestriction protein
# Arf
# Arf protein
# Arm DNA-binding domain protein
# Arn
# Arn inhibitor of MrcBC restriction endonuclease (anti-restriction nuclease)
# Arn.1 conserved hypothetical protein
# Arn.2 conserved hypothetical protein
# Arn.3 conserved hypothetical protein
# Arn.4 conserved hypothetical protein
# AroG
# ArpR
# ArpR DNA binding protein
# ArpR DNA-binding protein
# ArpU family phage encoded transcriptional regulator
# ArpU family phage transcriptional regulator
# ArpU family transcriptional regulator
# ArpU family transcriptional regulator protein
# ArpU late transcriptional regulator
# ArpU-like protein
# ArpU-like transcriptional regulator
# ArsR family transcriptional regulator
# ArsR family transcriptional regulator protein
# ArsR-like helix-turn-helix domain-containing protein
# Asf
# Ash family protein
# AsiA
# AsiA anti-sigma 70 protein
# AsiA anti-sigma70 protein
# AsiA-like anti-sigma 70 protein
# AsiA-like anti-sigma protein
# AsiA.1 hypothetical protein
# Asp-rich protein
# Asp23/Gls24 family envelope stress response protein
# Aspartyl protease Retroviral aspartyl protease
# Autolysin
# Autonomous glycyl radical cofactor
# Avd
# Avd-like four helix bundle protein
# Avd-like protein
# B
# B (capsid component;533)
# B protein
# B transposition protein
# B-cell receptor associated protein-related protein
# B-family DNA polymerase
# B-family DNA polymerase, catalytic domain
# B-family DNA-polymerase
# B-family DNA-polymerase catalytic subunit
# B-form DNA mimic
# B104
# B12-dependent ribonucleotide reductase
# B150
# B205
# B298
# B65
# B94
# BACON domain-containing protein
# BAH domain protein
# BAH domain-containing protein
# BC10 family protein
# BIG2 domain-containing protein
# BLAST Hypothetical protein
# BLAST to AXY86382 hypothetical protein Meda_122
# BLAST-P NR database RNA polymerase binding protein A [Escherichia phage RB49]
# BNR repeat domain protein
# BNR repeat-containing protein
# BPP
# BPP-1 major tropism-determinant-like protein
# BPP-1-like major tropism determinant protein
# BR0599 family protein
# BRCT domain protein
# BRO N-terminal domain protein
# BRO N-terminal domain regulatory protein
# BRO N-terminal domain-containing protein
# BRO domain-containing protein
# BRO family antirepressor
# BRO family antirepressor protein
# BRO family protein
# BRO family, N- domain protein
# BRO family, N-terminal domain protein
# BRO family, N-terminal domain-contaning protein
# BTLCP-like protein
# Bac_DnaA_C domain-containing protein
# Bacterial DNA-binding protein
# Bacterial Ig-like domain (group 2)
# Bacterial+Ig-like+domain+(group+1)
# Bacteriophage
# Bacteriophage FRD2 protein
# Bacteriophage FRD3 protein
# Bacteriophage Gp15 protein
# Bacteriophage Mu Gam like protein
# Bacteriophage T holin
# Bacteriophage T4 MotA, C-terminal
# Bacteriophage T4 gp9/10-like protein
# Bacteriophage T4, Gp8
# Bacteriophage T4-like capsid assembly protein (Gp20)
# Bacteriophage T7 virion assembly protein
# Bacteriophage head to tail connecting protein
# Bacteriophage holin HP1 family protein
# Bacteriophage lambda tail assembly protein I
# Bacteriophage lysis protein
# Bacteriophage protein GP30.3
# Bacteriophage protein GP46
# Bacteriophage protein gp37
# Bacteriophage replication gene A protein (GPA)
# Bacteriophage replication protein O
# Bacteriophage tail assembly protein
# Bacteriophage translational regulator
# Bacteriophage+tail+assembly+protein, Phage+terminase+large+subunit+(GpA)
# Bactoprenol glucosyl transferase
# Bactoprenol-linked glucose translocase (flippase)
# Ban
# Band 7 protein
# Base plate hub subunit
# Base plate hub subunit, tail length determinator
# Base plate wedge protein 53
# Baseplate J family protein
# Baseplate J-like protein
# Baseplate assembly protein
# Baseplate central spike
# Baseplate hub + tail lysozyme
# Baseplate hub assembly catalyst
# Baseplate hub assembly protein
# Baseplate hub distal subunit
# Baseplate hub subunit
# Baseplate hub subunit, tail length determinator
# Baseplate protein
# Baseplate structural protein BplA
# Baseplate structural protein, domain 1
# Baseplate subunit
# Baseplate tail tube cap
# Baseplate wedge initiator
# Baseplate wedge protein
# Baseplate wedge subunit
# Baseplate wedge subunit and tail pin
# Baseplate wedge tail fiber connector
# Bbp1
# Bbp10
# Bbp11
# Bbp12
# Bbp13
# Bbp14
# Bbp15
# Bbp16
# Bbp17
# Bbp18
# Bbp19
# Bbp2
# Bbp20
# Bbp21
# Bbp22
# Bbp23
# Bbp24
# Bbp25
# Bbp26
# Bbp27
# Bbp28
# Bbp29
# Bbp3
# Bbp31
# Bbp33
# Bbp34
# Bbp35
# Bbp36
# Bbp37
# Bbp38
# Bbp39
# Bbp4
# Bbp40
# Bbp41
# Bbp42
# Bbp43
# Bbp44
# Bbp45
# Bbp46
# Bbp47
# Bbp48
# Bbp49
# Bbp50
# Bbp7
# Bbp9
# BcepGomrgp01
# BcepGomrgp02
# BcepGomrgp03
# BcepGomrgp04
# BcepGomrgp05
# BcepGomrgp06
# BcepGomrgp07
# BcepGomrgp08
# BcepGomrgp09
# BcepGomrgp10
# BcepGomrgp11
# BcepGomrgp12
# BcepGomrgp13
# BcepGomrgp14
# BcepGomrgp15
# BcepGomrgp16
# BcepGomrgp17
# BcepGomrgp18
# BcepGomrgp19
# BcepGomrgp20
# BcepGomrgp21
# BcepGomrgp22
# BcepGomrgp23
# BcepGomrgp24
# BcepGomrgp25
# BcepGomrgp26
# BcepGomrgp27
# BcepGomrgp28
# BcepGomrgp29
# BcepGomrgp30
# BcepGomrgp31
# BcepGomrgp32
# BcepGomrgp33
# BcepGomrgp34
# BcepGomrgp35
# BcepGomrgp35 [Burkholderia phage BcepGomr]
# BcepGomrgp36
# BcepGomrgp37
# BcepGomrgp38
# BcepGomrgp39
# BcepGomrgp40
# BcepGomrgp41
# BcepGomrgp42
# BcepGomrgp43
# BcepGomrgp44
# BcepGomrgp45
# BcepGomrgp46
# BcepGomrgp47
# BcepGomrgp48
# BcepGomrgp49
# BcepGomrgp50
# BcepGomrgp51
# BcepGomrgp52
# BcepGomrgp53
# BcepGomrgp54
# BcepGomrgp55
# BcepGomrgp56
# BcepGomrgp57
# BcepGomrgp58
# BcepGomrgp59
# BcepGomrgp60
# BcepGomrgp61
# BcepGomrgp62
# BcepGomrgp63
# BcepGomrgp64
# BcepGomrgp65
# BcepGomrgp66
# BcepGomrgp67
# BcepGomrgp68
# BcepGomrgp69
# BcepGomrgp70
# BcepGomrgp71
# BcepGomrgp72
# BcepGomrgp73
# BcepGomrgp74
# BcepGomrgp75
# BcepMu gp16 family phage-associated protein
# BcepNY3gp01
# BcepNY3gp02
# BcepNY3gp03
# BcepNY3gp04
# BcepNY3gp05
# BcepNY3gp06
# BcepNY3gp07
# BcepNY3gp08
# BcepNY3gp10
# BcepNY3gp14
# BcepNY3gp18
# BcepNY3gp19
# BcepNY3gp20
# BcepNY3gp22
# BcepNY3gp25
# BcepNY3gp27
# BcepNY3gp29
# BcepNY3gp31
# BcepNY3gp32
# BcepNY3gp33
# BcepNY3gp34
# BcepNY3gp35
# BcepNY3gp37
# BcepNY3gp38
# BcepNY3gp39
# BcepNY3gp40
# BcepNY3gp41
# BcepNY3gp42
# BcepNY3gp43
# BcepNY3gp45
# BcepNY3gp46
# BcepNY3gp47
# BcepNY3gp48
# BcepNY3gp49
# BcepNY3gp51
# BcepNY3gp52
# BcepNY3gp54
# BcepNY3gp55
# BcepNY3gp56
# BcepNY3gp57
# BcepNY3gp58
# BcepNY3gp60
# BcepNY3gp61
# BcepNY3gp63
# BcepNY3gp64
# BcepNY3gp66
# BcepNY3gp67
# BcepNY3gp68
# BcepNY3gp69
# Bet
# Bet family recombination protein
# Bet protein
# Bet recombination protein
# Bet recombination protein (Red beta)
# Bet-like ssDNA annealase
# BetR domain DNA binding protein
# BetR domain DNA-binding protein
# Beta glucosyl transferase
# Beta-lactamase SHV-2
# BhlA
# Bifunctional DNA primase/polymerase
# Bifunctional DNA primase/polymerase, N-terminal
# Bifunctional NMN adenylyltransferase/Nudix hydrolase
# Big-1 domain-containing protein
# Bis(5'-nucleosyl)-tetraphosphatase PrpE
# Bla
# BlaI/MecI/CopY family transcriptional regulator
# BmpA
# BmpB
# BmpC
# BofL
# BofR
# Bor
# Bor lipoprotein
# Bor protein
# Bor protein precursor
# BplA
# BplB
# BppU domain protein
# BppU family baseplate upper protein
# BppU family phage baseplate upper protein
# BppU-like baseplate protein
# BppU_N domain-containing protein
# BrnA-like antitoxin
# BrnT family toxin
# BrnT-like antitoxin
# BrnT-like toxin
# Bro family antirepressor
# Bro family toxin component
# Bro-N domain protein
# Bro-N family protein
# Bro-N/ORF6C domain-containing antirepressor
# BroN DNA binding protein
# BspA family leucine rich repeat surface protein
# BspA family leucine-rich repeat surface protein
# BsuMI modification methylase subunit
# BtrN protein
# BtuR/CobO ATP:corrinoid adenosyltransferase
# C
# C (capsid component;439)
# C protein
# C repressor
# C repressor protein
# C-4 type zinc finger protein
# C-4 type zinc finger protein,TraR family
# C-5 cytosine DNA methylase
# C-5 cytosine specific DNA methylase
# C-5 cytosine-specific DNA methylase
# C-5 cytosine-specific DNA methylase I
# C-5 cytosine-specific DNA methylase II
# C-5 cytosine-specific DNA methylase family protein
# C-5 cytosine-specific DNA methyltransferase
# C-5-cytosine methyltransferase
# C-C motif chemokine 25-like protein
# C-N hydrolase superfamily protein
# C-terminal associated domain of TOPRIM
# C-terminal effector signal transduction response regulator-like superfamily protein
# C-terminal part of the MCM2-like helicase
# C-terminus of phage terminase large subunit
# C1
# C1 inactivator protein Coi
# C1 protein
# C1 repressor
# C1 repressor inactivator
# C1 temperature sensitive variant
# C1-like repressor
# C1-type lambda-like repressor
# C1.100
# C102
# C117
# C123
# C129
# C1q domain-containing protein
# C2
# C2 protein
# C250
# C281
# C2H2 Zn finger protein
# C2H2-finger transcriptional regulator
# C2H2-type zinc finger protein
# C2H2-zinc finger protein
# C3
# C3 protein
# C3-like protein
# C39 family peptidase
# C4 DksA/TraR-type zinc finger protein
# C4 Zn finger protein
# C4 zinc finger domain
# C4-type domain-containing protein
# C4-type domain-containing protein/TraR regulator
# C4-type zinc finger
# C4-type zinc finger domain-containing protein
# C4-type zinc finger protein
# C4-type zinc finger protein, DksA/TraR family
# C40 family peptidase
# C5 cytosine methyltransferase
# C5 cytosine-specific DNA methylase
# C5 methyltransferase alpha subunit
# C5 methyltransferase beta subunit
# C5-cytosine methyltransferase
# C59
# C64
# C8
# C81
# C95
# CAAX family membrane-bound protease
# CAAX protease
# CAMP-dependent protein kinase catalytic subunit
# CBM containing tail protein
# CBM_5_12 domain protein
# CBS domain-containing protein
# CBS family protein
# CCA tRNA nucleotidyl transferase
# CCA tRNA nucleotidyltransferase
# CCA-adding enzyme
# CCA-adding protein
# CCA-tRNA nucleotidyl transferase
# CCA-tRNA nucleotidyltransferase
# CCA-tRNA nucleotidyltransferase protein
# CCHC zinc finger protein
# CDC45-like protein
# CDP-4-dehydro-6-deoxy-D-glucose 3-dehydratase
# CDP-glycerol:poly(glycerophosphate) glycerophosphotransferase
# CDP/dCDP deaminase, zinc-binding
# CDP/dCDP deaminase,zinc-binding
# CDS.0.1598_0.019798620802782718
# CHAP domain protein
# CHAP domain-containing lysin
# CHAP domain-containing phage lysin
# CHAP domain-containing protein
# CHAP-domain tail tip cell wall hydrolase
# CHAT domain-containing protein
# CHC2 zinc finger family protein
# CHC2 zinc finger protein
# CHC2-type zinc finger protein
# CHIPS
# CI
# CI activator of prophage repressor gene transcription protein
# CI like protein
# CI phage repressor
# CI phage repressor protein
# CI protein
# CI repressor
# CI repressor protein
# CI transcriptional regulator
# CI transcriptional repressor protein
# CI-like protein
# CI-like repressor
# CI-like repressor protein
# CII
# CII Protein
# CII decision making protein
# CII family protein
# CII family transcriptional regulator
# CII prophage repressor protein
# CII protein
# CII regulatory protein
# CII transcriptional activator protein
# CII-like protein
# CII-like repressor protein
# CII-like transcriptional activator
# CIII protein
# CIII regulatory protein
# CIII-like protease inhibitor
# CIII-like protein
# CIpA-like protein
# CLIP-associating protein 1
# CLP protease
# CLP protease putative ATP-dependent Clp protease
# CMD domain-containing protein
# CMP N-glycosidase-like protein
# CMP deaminase
# CMP glycosidase
# CMP hydrolase
# CMP/dCMP deaminase
# CMP/dCMP deaminase zinc-binding protein
# CMP/dCMP deaminase, zinc-binding
# CMP/hydroxymethyl hydrolase
# COG1209: dTDP-glucose pyrophosphorylase
# COG1683: Uncharacterized conserved protein / FIG143828: Hypothetical protein YbgA
# COG2932: Predicted transcriptional regulator
# COG3236 protein
# COG3728 phage terminase small subunit
# COG4385: Bacteriophage P2-related tail formation protein
# COG5283: Phage-related tail protein
# COOH NH2 ligase
# COOH-NH2 ligase-type 2
# COOH.NH2 ligase
# CP12
# CP12 carbon metabolic regulator
# CP12 protein
# CP83-like domain protein
# CR-type zinc finger domain protein
# CRISPR associated protein
# CRISPR associated protein Cas1
# CRISPR-associated endonuclease
# CRISPR-associated endonuclease Cas3-HD
# CRISPR-associated endoribonuclease
# CRISPR-associated endoribonuclease Cas2
# CRISPR-associated exonuclease
# CRISPR-associated exonuclease, Cas4 family
# CRISPR-associated helicase
# CRISPR-associated protein
# CRISPR-associated protein Csy1
# CRISPR-associated protein Csy2
# CRISPR-associated protein, Csy3 family
# CRISPR-like protein
# CRISPR/Cas system associated protein
# CRISPR/Cas system-associated protein
# CRISPR/Cas system-associated transcriptional regulator CasRa
# CRISPR/Cas4 system-associated protein
# CRO antirepressor
# CRO protein
# CRO repressor
# CRO-like repressor
# CRO/C1-family transcriptional regulator
# CRO/CI family transcriptional regulator
# CTP synthetase
# CYTH domain protein
# CYTH domain-containing protein
# CYTH-like phosphatase domain protein
# Ca2+ ion binding domain containing hemolysin-type protein
# Cadherin-like beta sandwich domain protein
# CalX-like domain containing protein
# CalX-like domain protein
# CalX-like domain superfamily protein
# Calcineurin-like phosphoesterase
# Calcineurin-like phosphoesterase superfamily domain protein
# Capsid protein
# Cas system-associated protein
# Cas1
# Cas3
# Cas4 family endonuclease
# Cas4 family exonuclease
# Cas4 family nuclease
# Cas4 family putative nuclease
# Cas4 like protein
# Cas4 nuclease
# Cas4 nuclease superfamily protein
# Cas4-like exonuclease
# Cas4-like protein
# Cas9-type HNH domain protein
# Caspid assembly protein
# Caudovirales tail fiber assembly protein
# Caudovirus prohead protease
# CcmD-family protein
# CcrM-like DNA methyltransferase
# Cd
# Cd allosteric enzyme
# Cd dCMP deaminase
# Cd.1 conserved hypothetical protein
# Cd.1 hypothetical protein
# Cd.2 conserved hypothetical protein
# Cd.3 conserved hypothetical protein
# Cd.4 conserved hypothetical protein
# Cd.5 hypothetical protein
# Cdc27 C terminal domain containing protein
# Cef
# Cef modifier of suppressor tRNAs
# Cef-like tRNA modification protein
# Cell Wall Hydrolase
# Cell division protein FtsH
# Cell surface protein N-acetylmuramoyl-L-alanine amidase LytC precursor
# Cell wall hydrolase
# Cell wall hydrolyses involved in spore germination
# Cell wall-associated hydrolases (invasion-associated proteins)
# Cell wall-binding endopeptidase
# Cep
# CepT like protein
# CepT-like protein
# ChW-repeats and cell-adhesion domain containing protein
# Chain A, Endolysin
# Chaperone for long tail fiber formation
# Chaperone for tail fiber formation
# Chaperone protein DnaJ
# Chaperonin 10 Kd subunit
# Chitinase, putative endolysin
# ChoK-like putative serine/threonine kinase
# Chromosome partition protein Smc
# Chromosome segregation ATPase
# Ci-like repressor
# Cin
# CinA
# Cl protein
# Cl repressor
# Cl-like repressor
# Clamp loader small subunit
# Clamp loader small subunit, DNA polymerase accessory protein
# Clamp loader subunit, DNA polymerase accessory protein
# Clp
# Clp ATP-dependent protease subunit
# Clp family protein, ATPase domain
# Clp peptidase
# Clp protease
# Clp protease ClpP
# Clp protease protein
# Clp protease proteolytic subunit /translocation-enhancing protein TepA
# Clp protease proteolytic subunit ClpP
# Clp protease subunit
# Clp protease-like protein
# Clp protease-like scafolding protein
# Clp protease/major capsid protein
# Clp protein
# Clp proteolytic subunit-like protein
# Clp serine protease subunit
# Clp-like protease
# ClpA-like protein
# ClpB protein
# ClpP
# ClpP ATP-dependent protease subunit
# ClpP protease
# ClpP-like protease
# ClpP-like protein
# ClpP/crotonase-like domain protein
# ClpX superfamily protein
# ClpXP protease specificity-enhancing factor
# Cma
# Co-chaperone GroES
# CoA ester lyase
# CoA ligase
# Coat protein
# CobQ/CobB/MinD/ParA nucleotide binding domain protein
# CobS
# CobS porphyrin biosynthetic protein
# CobS subunit of cobaltochelatase
# CobS-like protein
# CobT subunit of cobaltochelatase
# CobT-like cobalamin biosynthesis protein
# Cof hydrolase
# Cof-like hydrolase
# Coi
# Cold shock protein CspB
# Cold shock protein CspF
# Cold shock protein CspG
# Cold shock-like protein CspB
# Cold shock-like protein CspI
# Com
# Com protein
# Com translational regulator
# Com, translational modulator of Mom
# ComE operon protein 2
# ComF family protein
# Component of class III ribonucleotide reductase
# ConA-like lectin/glucanase
# Connector
# Connector protein, Neck Ne1
# Connector protein, adaptor Ad1
# Connector protein, head-closure Hc1
# Conserved archaeal viral membrane protein, acyltransferase family
# Conserved hypothetical phage protein
# Conserved hypothetical protein
# Conserved hypothetical protein; putative recombination protein
# Conserved odinarchaeal virus protein
# Conserved protein
# Conserved protein of unknown function ISaA (product of IS1 associated gene) (fragment)
# Contractile injection system protein
# CopG family protein
# CopG family ribbon-helix-helix protein
# CopG family transcriptional regulator
# CopG transcriptional regulator
# CopG-like RHH protein
# CopG-like domain-containing protein DNA-binding protein
# CopG-like ribbon-helix-helix domain protein
# CopG/Arc/MetJ DNA-binding domain-containing protein
# CopY transcritpional regulator
# Cor
# Cor protein
# Cox
# Cox family DNA-binding protein
# Cox protein
# Cox transcriptional regulator
# CpXC protein
# CpeT
# CpeT antenna protein
# CpeT-like protein
# Cps
# Cra
# Cre
# Cre-associated protein
# CreA protein
# Cro
# Cro (control of repressor's operator)
# Cro DNA-binding transcriptional regulator
# Cro antirepressor
# Cro family repressor
# Cro family transcriptional regulator
# Cro family transcriptional repressor
# Cro protein
# Cro receptor
# Cro repressor
# Cro repressor protein
# Cro transcriptional regulator
# Cro transcriptional repressor protein
# Cro-like DNA-binding protein
# Cro-like XRE-transcriptional regulator
# Cro-like lytic repressor
# Cro-like phage repressor
# Cro-like phage transcriptional repressor protein
# Cro-like protein
# Cro-like protein phage associated
# Cro-like receptor
# Cro-like regulator
# Cro-like represor protein
# Cro-like repressor
# Cro-like repressor protein
# Cro-like transcriptional regulator
# Cro-like transcriptional repressor protein
# Cro-repressor
# Cro-type lambda-like repressor
# Cro-type transcriptional regulator
# Cro/C1-like transcriptional repressor
# Cro/C1-type HTH DNA-binding domain protein
# Cro/C1-type HTH DNA-binding protein
# Cro/C1-type domain protein
# Cro/C1-type helix-turn-helix domain protein
# Cro/C1-type helix-turn-helix domain-containing protein
# Cro/C1-type helix-turn-helix transcriptional regulator like protein
# Cro/C1-type protein
# Cro/C1-type repressor
# Cro/C1-type transcriptional regulator
# Cro/C1-type-helix-turn-helix domain protein
# Cro/C1-type-helix-turn-helix domain-containing protein
# Cro/CI family XRE family transcriptional regulator
# Cro/CI family transcription regulator
# Cro/CI family transcriptional regulator
# Cro/CI family transcriptional regulator protein
# Cro/CI repressor
# Cro/CI-like repressor
# Cro/Cl family transcriptional regulator
# Cro/Cl protein
# Cro/Cl repressor
# Cro/Cl repressor protein
# Cro/Cl-like repressor
# Cro/Cl-type repressor
# Crossover junction endodeoxyribonuclease RusA
# Crossover junction endodeoxyribonuclease RuvC
# Crossover junction endodeoxyribonuclease rusA
# Csp
# CsrA-like regulator
# CsrA-like regulator protein
# CsrA-like transcriptional regulator
# CsrA-like transcriptional regulator protein
# Csy1
# Csy2
# Csy3
# Csy4
# CtxA
# CtxB
# CxxC domain protein
# CxxC motif protein
# CxxC_CXXC_SSSS domain-containing protein
# Cyanophage-encoded cytidylyltransferase #T4 GC0190
# Cyanothece histidine kinase
# Cyclic pyranopterin monophosphate synthase
# CynX family MFS transporter
# Cys-rich domain protein
# Cys-tRNA(Pro) deacylase
# Cys-tRNA(Pro)/Cys-tRNA(Cys) deacylase
# Cys_rich_CPCC family protein
# Cysteine desulfurase, SufS subfamily
# Cytitidyltransferase
# Cytolethal distending toxin A subunit
# Cytolethal distending toxin B subunit
# Cytolethal distending toxin C subunit
# Cytoplasmic chaperone, TorD family
# Cytosine methylase, similar to N4-cytosine methylase
# Cytosine methylase, similar to PspGI methylase
# Cytosine specific DNA methyltransferase
# Cytosine-specific DNA methyltransferase
# CzcR-like response regulator
# D
# D (head-DNA stabilization;110)
# D alanyl-D-alanine carboxypeptidase
# D protein
# D replication protein DC
# D tail protein
# D,D-heptose 7-phosphate kinase
# D-3-phosphoglycerate dehydrogenase
# D-Ala D-Ala carboxypeptidase
# D-Ala-D-Ala carboxypeptidase
# D-ala D-ala carboxypeptidase
# D-ala-D-ala carboxypeptidase
# D-ala-D-ala-carboxypeptidase
# D-ala-D-ala-decarboxylase
# D-alanine--D-alanine ligase
# D-alanine--D-alanine ligase (EC 6.3.2.4)
# D-alanine-D-alanine ligase
# D-alanyl D-alanine carboxypeptidase
# D-alanyl-D-alanine carboxypeptidase
# D-alanyl-D-alanine carboxypeptidase family protein
# D-alanyl-D-alanine dipeptidase
# D-alanyl-D-alanine-carboxypeptidase
# D-aminoacyl-tRNA deacylase
# D-arabinose 5-phosphate isomerase
# D-arabinose-5-phosphate isomerase
# D-glucuronyl C5-epimerase
# D-ribose pyranase
# D/B-b-hydroxylase DiO
# D1
# D10 protein
# D108-specific protein
# D11 protein
# D11-like protein
# D12 class N6 adenine-specific DNA methyltransferase
# D12 class N6 adenine-specific DNA methyltransferase family protein
# D12 class N6 adenine-specific DNAmethyltransferase
# D13; putative exonuclease SbcCD, C subunit (ACLAME 108)
# D14 Protein
# D14 protein
# D14 protein/putative Holiday junction resolvase (ACLAME 1108)
# D14 protein/putative holiday junction resolvase
# D14 protein/putative holiday junction resolvase (ACLAME 1108)
# D14 protein/putative resolvase
# D14-like protein
# D152
# D154
# D2
# D2 protein
# D3 protein
# D3-like protein
# D383
# D5 protein
# D5 protein/DNA-binding protein
# D5 transcription factor
# D5-like protein
# D6 protein
# D60
# DAN primase/helicase
# DBP
# DCM methylase
# DCMP deaminase
# DCTP deaminase
# DCTP pyrophosphatase
# DD-transpeptidase
# DDE endonuclease
# DDE superendonuclease family protein
# DDE transposase
# DDE-type integrase/transposase
# DDE-type integrase/transposase/recombinase
# DEAD box family helicase
# DEAD box helicase
# DEAD domain helicase
# DEAD domain protein
# DEAD type helicase
# DEAD-DEAH box helicase
# DEAD-DEAHbox helicase
# DEAD-box helicase
# DEAD-family helicase
# DEAD-like helicase
# DEAD-like helicase superfamily domain containing protein
# DEAD-like helicase superfamily protein
# DEAD/DEAH box DNA helicase
# DEAD/DEAH box helicase
# DEAD/DEAH box helicase and SNF2 domain-containing protein
# DEAD/DEAH box helicase family protein
# DEAD/DEAH box helicase-like protein
# DEAD/DEAH box helicase_gp015
# DEAD/DEAH box helicase_gp017
# DEDDH exonuclease
# DEDDh 3'-5' exonuclease
# DEDDh exonuclease
# DEXH-box RNA or DNA helicase
# DGQHR domain protein
# DGQHR domain-containing protein
# DHFR domain-containing protein
# DHH family phosphoesterase
# DHH family phosphohydrolase/phosphoesterase
# DHH family protein
# DHH phosphoesterase
# DHH phosphoesterase superfamily protein
# DHH-type phosphodiesterase
# DM13 domain-containing protein
# DMP kinase
# DMSO reductase anchor subunit C
# DNA (cytosine-5)-methylotransferase
# DNA (cytosine-5)-methyltransferase
# DNA (cytosine-5)-methyltransferase 1
# DNA (cytosine-5-)-methyltransferase
# DNA (cytosine-5-)-methyltransferase [Weissellaphage PWc]
# DNA (cytosine-5-)-methyltransferase protein
# DNA 5'-3' exonuclease
# DNA 5'-3'exonuclease
# DNA A-C-terminal domain containing protein
# DNA B-like helicase
# DNA C-5-cytosine methyltransferase
# DNA FtsK/SpoIIIE translocase
# DNA Helicase
# DNA Helicase loader Lammda_P
# DNA Ligase
# DNA N-4 cytosine methyltransferase
# DNA N-6 adenine methyltransferase
# ...
# type I restriction-modification system, specificity subunit S
# type I secretion C-terminal target domain protein
# type I secretion protein
# type I secretion system permease/ATPase
# type I secretion target domain-containing protein
# type I site-specific deoxyribonuclease, HsdR family
# type I tail fiber
# type I toxin/antitoxin system, Fst family
# type I-E anti-CRISPR protein
# type I-F CRISPR-associated protein
# type I-F anti-CRISPR protein
# type IC restriction inhibitor
# type II 3-dehydroquinate dehydratase
# type II 5-methyl-cytosine DNA methyltransferase
# type II DNA modification methyltransferase
# type II N-methyl DNA methyltransferase
# type II N-methyl DNA methyltransferase (group alpha)
# type II N-methyl DNA methyltransferase group alpha
# type II N4M-methylcytosine DNA methyltransferase
# type II adenine-specific methyltransferase
# type II antitoxin
# type II heat-labile enterotoxin ADP-ribosyltransferase catalytic subunit
# type II heat-labile enterotoxin binding subunit
# type II holin
# type II restriction endonuclease
# type II restriction enzyme BsuBI
# type II restriction enzyme, methylase subunit
# type II restriction enzyme/endonuclease
# type II restriction m6 adenine DNA methyltransferase, Alw26I/Eco31I/Esp3I family
# type II restriction-modification system methylation subunit
# type II restriction-modification system modification protein
# type II restriction-modification system restriction protein
# type II restriction-modification system restriction subunit
# type II secretion system protein
# type II site-specific deoxyribonuclease
# type II tail fiber/depolymerase
# type II topoisomerase large subunit
# type II topoisomerase medium subunit
# type II toxin
# type II toxin-antitoxin HicA family toxin
# type II toxin-antitoxin HicB family antitoxin
# type II toxin-antitoxin HipB-like antitoxin
# type II toxin-antitoxin RelE-family toxin
# type II toxin-antitoxin system
# type II toxin-antitoxin system HicB family antitoxin
# type II toxin-antitoxin system HigB family toxin
# type II toxin-antitoxin system HipA family toxin
# type II toxin-antitoxin system PemK/MazF family protein
# type II toxin-antitoxin system Phd/YefM family antitoxin
# type II toxin-antitoxin system RelE/ParE family toxin
# type II toxin-antitoxin system antitoxin
# type II toxin-antitoxin system death-on-curing family toxin
# type II toxin-antitoxin system toxin ribonuclease
# type II, 5-methyl-cytosine DNA methyltransferase
# type II, N-methyl DNA methyltransferase
# type II, N-methyl DNA methyltransferase (group alpha)
# type II, N4M-methylcytosine DNA methyltransferase (group beta)
# type II, N4M-methylcytosine DNA methyltransferase group beta
# type II, N6M-methyladenine DNA methyltransferase
# type II, N6M-methyladenine DNA methyltransferase (group beta)
# type IIA DNA topoisomerase subunit B
# type IIA topoisomerase
# type IIG restriction modification enzyme
# type III RNAP sigma factor
# type III helicase restriction enzyme
# type III polyketide synthase
# type III restriction endonuclease
# type III restriction endonuclease subunit R
# type III restriction enzyme
# type III restriction enzyme res subunit
# type III restriction enzyme, res subunit
# type III restriction helicase
# type III restriction protein
# type III restriction protein res subunit
# type III restriction-modification system enzyme
# type III restriction-modification system methylation subunit
# type III restriction-modification system restriction subunit
# type III restriction/modification enzyme methylation subunit
# type IIs restriction endonuclease
# type IV conjugative transfer system coupling protein
# type IV pilus assembly protein
# type IV pilus biogenesis protein
# type IV secretion protein
# type IV secretory pathway VirD4 component-like protein
# type IV secretory pathway VirD4 components-like protein
# type IV secretory system conjugative DNA transfer family protein
# type V secretory pathway adhesin
# type VI secretion immunity protein
# type VI secretion protein
# type VI secretion system PAAR protein
# type VI secretion system Vgr family protein
# type VI secretion system lysozyme-like protein
# type VI secretion system tube protein
# type VII integral membrane protein
# type VII secretion integral membrane protein EccD
# type measure protein
# type-2 restriction enzyme
# tyrosine 2,3-aminomutase
# tyrosine Integrase
# tyrosine family integrase
# tyrosine homologous recombinase
# tyrosine integrase
# tyrosine integrase/recombinase
# tyrosine phosphatase
# tyrosine phosphatase domain-containing protein
# tyrosine phosphatase family protein
# tyrosine recombinase
# tyrosine recombinase XerC
# tyrosine recombinase XerD
# tyrosine recombinase XerD-like protein
# tyrosine recombinase family integrase
# tyrosine recombinase-like protein
# tyrosine recombinase/ integrase
# tyrosine site-specific recombinase
# tyrosine-protein kinase EpsD
# tyrosine-protein kinase transmembrane modulator
# tyrosine-type recombinase
# tyrosine-type recombinase/integrase
# tyrosyl-tRNA synthetase
# u-spanin
# u-spannin
# ubiquinol-cytochrome C reductase
# ubiquinone/menaquinone biosynthesis
# ubiquinone/menaquinone biosynthesis methyltransferase
# ubiquitin-binding domain-containing protein
# ubiquitin-conjugating enzyme H
# ubiquitin-conjugating enzyme e2
# ubiquitin-like protein
# ubiquitin-like proteins
# ulcer associated adenine specific DNA
# ulcer associated adenine specific DNA methyltransferase
# uncharacterized 11.1 kDa protein
# uncharacterized 14.8 kDa protein in frd-Gp32 intergenic region
# uncharacterized 17.7 kDa protein
# uncharacterized 8.8 kDa protein
# uncharacterized conserved protein
# uncharacterized phage protein
# uncharacterized phage-encoded protein
# uncharacterized protein
# uncharacterized protein ORF43.1
# uncharacterized protein YbcO
# uncharacterized protein family UPF0027
# unclassified head protein
# unclassified head-tail protein
# unclassified maturation protein
# unclassified tail protein
# undecaprenyl-diphosphatase
# undecaprenyl-diphosphate phosphatase
# unimolecular spanin
# unimolecular spanin protein
# universal stress protein F
# universal stress protein G
# unknown
# unknown early protein
# unknown function protein
# unknown phi protein
# unknown product
# unknown protein
# unknown protein encoded by prophage CP-933O
# unknown protein encoded in ISEc8
# unknown structural protein
# unnamed protein product
# unnamed protein product [EnterobacteriaphageIME08]
# upf54.2
# upper base plate protein
# upper baseplate protein
# upper collar
# upper collar connector
# upper collar connector protein
# upper collar protein
# upper head-tail connector protein
# upper tail fiber protein
# uracil DNA glycosylase
# uracil transport protein
# uracil-DNA glycosylase
# uracil-DNA glycosylase inhibitor
# uracil-DNA glycosylase protein
# uracil-DNA-glycosylase inhibitor
# uracyl DNA glycosylase
# uridine kinase
# uridylyltransferase
# uroporphyrinogen III decarboxylase
# utative ribonucleotide reductase of class Ib (aerobic) subunit beta
# uvsW
# uvsW.1 conserved hypothetical protein
# uvsW.1 hypothetical protein
# uvsY.-1 hypothetical protein
# uvsY.-2 hypothetical protein
# uvsY.2
# vRNAP
# vRNAP protein
# vWA-like domain-containing protein
# vWFA domain containing protein
# vWFA protein
# valine--tRNA ligase
# valine-glycine repeat protein G1
# valyl tRNA synthetase modifier
# valyl tRNA-synthase
# valyl--tRNA ligase modifier
# valyl-tRNA ligase modifier
# valyl-tRNA synthetase
# valyl-tRNA synthetase modifier
# valyl-tRNA synthetase modifier [Escherichia phage e11/2]
# valyl-tRNA synthetase modifier [Escherichia phage wV7]
# valyl-tRNA synthetase modifier protein
# variable tail fiber protein
# variable tail fiber protein H
# vascular endothelial growth factor receptor 1 isoform 1 precursor
# vertex head subunit
# vertex portal protein of the head
# vertex protein
# vertex protein of head
# very large surface anchored protein
# very short patch repair endonuclease
# very short patch repeat endonuclease
# very-short-patch-repair endonuclease
# vimentin
# viral RNA ligase 2
# viral RNA polymerase
# viral RNA polymerase beta subunit
# viral RNA polymerase beta-prime subunit
# viral capsid protein
# viral envelope fusion with host membrane
# viral envelope protein
# viral fiber protein
# viral host transcription inhibitor
# viral integrase
# viral integrase family 1
# viral integrase family 4
# viral portal protein
# viral protein
# viral recombinase
# viral recombinase family protein
# viral structural protein
# viral structural protein VP12
# viral structural protein VP13
# viral tegument-like protein
# virion
# virion DNA-directed RNA polymerase
# virion RNA polymerase
# virion RNA polymerase protein
# virion RNA polymerase subunit
# virion assembly protein
# virion associated RNA polymerase
# virion associated hydrolase
# virion associated protein
# virion assoviated RNA polymerase
# virion component
# virion component tail fiber
# virion component, putative tail fiber
# virion decoration protein
# virion encapsidated RNAP
# virion encapsulated RNA polymerase protein
# virion morphogenesis
# virion morphogenesis compnent
# virion morphogenesis family like protein
# virion morphogenesis family protein
# virion morphogenesis protein
# virion morphogenesis/head component
# virion morphogenesis/head protein
# virion morphogensis protein
# virion protein
# virion protein 3
# virion protein 4
# virion protein 5
# virion protein 6
# virion protein and lysozyme murein
# virion protein ejected into cell
# virion protein, putative tail protein
# virion protein, putative tape measure protein
# virion scaffolding protein
# virion stability factor
# virion stability factor/head assembly protein
# virion stability protein
# virion structrual protein
# virion structural / tail sheath protein
# virion structural component
# virion structural protei
# virion structural protein
# virion structural protein and packaging
# virion structural protein_gp067
# virion structural protein_gp069
# virion structural protein_gp070
# virion structural protein_gp071
# virion structural protein_gp079
# virion structural protein_gp081
# virion structural protein_gp082
# virion structural protein_gp083
# virion structural protein_gp084
# virion structural protein_gp085
# virion structural protein_gp094
# virion structural protein_gp095
# virion structural protein_gp096
# virion structural protein_gp100
# virion structural protein_gp101
# virion structural protein_gp106
# virion structural protein_gp208
# virion structural protein_gp211
# virion structure protein
# virion-associated DNA-directed RNA polymerase subunit alpha
# virion-associated DNA-directed RNA polymerase subunit beta
# virion-associated RNA polymerase
# virion-associated component
# virion-associated head protein
# virion-associated peptidase
# virion-associated phage protein
# virion-associated protein
# virion-encapsulated RNA polymerase
# viron protein
# viron structural protein
# viron structure and assembly
# viron-associated protein
# viron-encapsulated RNA polymerase
# viroplasmin family protein
# virulance associated protein E, VirE
# virulance-associated protein E / DNA primase
# virulence RhuM family protein
# virulence associated E family protein
# virulence associated factor E
# virulence associated protein
# virulence associated protein E
# virulence associated protein VrlC
# virulence determinant
# virulence plasmid 65kDa B domain protein
# virulence protein
# virulence protein E
# virulence protein MsgA
# virulence-associated E domain-containing protein
# virulence-associated E family protein
# virulence-associated VriC protein
# virulence-associated cell-wall-anchored protein
# virulence-associated protein
# virulence-associated protein E
# virulence-associated protein E /helicase/ primase
# virulence-associated structural protein
# virulence-related protein
# virus coat protein VP1
# virus coat protein VP2
# virus coat protein VP3
# virus life cycle regulation protein
# virus neck family protein
# virus neck protein
# vitamin B12-dependent ribonucleotide reductase
# von Willebrand domain A (VWA)-containing cochaperone protein
# von Willebrand factor A-like domain protein
# von Willebrand factor domain protein
# von Willebrand factor type A
# von Willebrand factor type A domain containing protein
# von Willebrand factor type A domain protein
# von Willebrand factor type A-like domain containing protein
# von Willebrand like protein
# von willebrand factor type A domain protein
# vrlC protein
# vrr-nuc domain protein
# vs.1 hypothetical protein
# vs.3 hypothetical protein
# vs.4 hypothetical protein
# vs.5 hypothetical protein
# vs.6
# vs.6 hypothetical protein
# vs.7 hypothetical protein
# vs.8 hypothetical protein
# wac
# wac fibritin neck whisker
# wac fibritin neck whiskers
# wac-like collar fiber
# wac-like neck fiber
# wall-associated receptor kinase
# wall-associated receptor kinase-like 20-like protein
# wall-associated receptor kinase-like protein
# wedge subunit tail pin
# whisker fibers at base of head
# whisker neck fibers protein
# whisker protein
# whiskers
# whiskers protein
# winged HTH
# winged HTH domain-containing protein
# winged HTH transcriptional regulator
# winged helix
# winged helix DNA-binding domain protein
# winged helix domain protein
# winged helix-like DNA-binding domain protein
# winged helix-like DNA-binding protein
# winged helix-turn-helix
# winged helix-turn-helix DNA binding domain protein
# winged helix-turn-helix DNA-binding domain protein
# winged helix-turn-helix DNA-binding domain-containing protein
# winged helix-turn-helix DNA-binding domainprotein
# winged helix-turn-helix DNA-binding protein
# winged helix-turn-helix domain containing
# winged helix-turn-helix domain containing protein
# winged helix-turn-helix domain-containing protein
# winged helix-turn-helix protein
# winged helix-turn-helix transcriptional regulator
# winged-helix DNA-binding domain protein
# winged-helix domain protein
# xanthine dehydrogenase
# xanthine phosphoribosyltransferase
# xanthine-guanine phosphoribosyltransferase
# xis
# xis (excision;72)
# xkdK-like tail sheath protein
# xkdM-like portal protein
# xkdN-like protein
# xkdP protein
# xkdP-like LysM domain-containing protein
# xkdP-like protein
# xkdQ protein
# xkdR-like protein
# xkdS protein
# xkdS-like protein
# xkdU-like tail protein
# xkdX protein
# xre family toxin-antitoxin system
# xyloglucosyl transferase activity protein
# xylose isomerase-like protein
# xylulokinase
# y4mF family transcriptional regulator
# ycfA-like family protein, putative toxin component
# yopX family protein
# yopX-like domain protein
# zeta toxin
# zeta toxin and ParB nuclease domain protein
# zeta toxin domain protein
# zf-TFIIB domain-containing protein
# zf-ribbon-3 domain protein
# zinc D-Ala-D-Ala carboxypeptidase precursor
# zinc DNA binding domain protein
# zinc binding CMP, dCMP deaminase
# zinc binding domain protein
# zinc binding protein
# zinc carboxypeptidase
# zinc carboxypeptidase-like protein
# zinc finger CHC2-family protein
# zinc finger DNA binding protein
# zinc finger binding domain protein
# zinc finger containing protein
# zinc finger domain containing protein
# zinc finger domain protein
# zinc finger domain-containing protein
# zinc finger protein
# zinc finger protein 2-like protein
# zinc finger protein 92 isoform
# zinc finger protein, TraR family
# zinc metallo-proteinase
# zinc metallopeptidase
# zinc metallopeptidase motif containing protein
# zinc metallopeptidase motif-containing protein
# zinc peptidase
# zinc protease
# zinc ribbon 14 domain-containing protein
# zinc ribbon binding domain protein
# zinc ribbon domain containing protein
# zinc ribbon domain protein
# zinc ribbon domain-containing protein
# zinc ribbon-containing protein
# zinc transport protein
# zinc uptake regulation protein
# zinc-binding APOBEC/CMP deaminase
# zinc-binding CMP/dCMP deaminase
# zinc-binding alcohol dehydrogenase
# zinc-binding cytidine and deoxycytidylate deaminase
# zinc-binding domain of primase-helicase
# zinc-binding domain primase-helicase
# zinc-binding loop region of homing endonuclease
# zinc-containing alcohol dehydrogenase superfamily protein
# zinc-dependent metalloprotease
# zinc-finger containing protein
# zinc-finger domain protein
# zinc-finger domain-containing protein
# zinc-finger protein
# zinc-finger-containing domain protein
# zinc-finger-containing protein
# zinc-metallo-proteinase
# zinc-ribbon domain containing protein
# zinc-ribbon domain protein
# zinc-ribbon domain-containing protein
# zinc-ribbon protein
# zinc-ribbon transposase
# zinc-ribbon-containing protein
# zincin protease
# zincin-like protease
# zincin-like protease fused to vWA domain
# zine-ribbon domain containing protein
# zona occludens toxin
# zonula occludens toxin
# zonular occludens toxin
# zot-like protein

# %%
rbp_products, hypothetical_proteins = util.get_rbp_hypothetical_proteins(constants.RBP_REGEX)
# Out:
# Processed 1000 records
# Processed 2000 records
# Processed 3000 records
# Processed 4000 records
# Processed 5000 records
# Processed 6000 records
# Processed 7000 records
# Processed 8000 records
# Processed 9000 records
# Processed 10000 records
# Processed 11000 records
# Processed 12000 records
# Processed 13000 records
# Processed 14000 records
# Processed 15000 records
# Processed 16000 records
# Processed 17000 records
# Processed 18000 records
# Processed 19000 records
# Processed 20000 records
# Processed 21000 records
# Processed 22000 records
# Processed 23000 records
# Processed 24000 records
# Processed 25000 records
# Processed 26000 records
# Processed 27000 records
# Processed 28000 records
# Processed 29000 records
# Processed 30000 records
# Processed 31000 records
# Processed 32000 records
# Processed 33000 records
# Processed 34000 records

# %%
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.RBP_PRODUCTS),'wb') as rbp_products_file:
    pickle.dump(rbp_products, rbp_products_file)
    
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.HYPOTHETICAL_PRODUCTS),'wb') as hypothetical_proteins_file:
    pickle.dump(hypothetical_proteins, hypothetical_proteins_file)

# %%
with open(f'{constants.TEMP_PREPROCESSING}/{constants.RBP_PRODUCTS}','rb') as rbp_products_file:
    rbp_products = pickle.load(rbp_products_file)
    
util.set_rbp_products(rbp_products)
rbp_products
# Out:
# {'adhesin tip for distal long tail fiber',
#  'bacteriophage tail fiber protein',
#  'central straight tail fiber',
#  'central tail fiber',
#  'central tail fiber j',
#  'central tail fiber receptor binding protein',
#  'central tail spike',
#  'colanidase tailspike',
#  'colanidase tailspike [enterobacteria phage ecgd1]',
#  'conserved hypothetical tail fiber protein',
#  'conserved tail fiber protein',
#  'defective tail fiber protein',
#  'depolymerase tail fiber protein',
#  'distal long tail fiber adhesin',
#  'distal long tail fiber subunit',
#  'distal tail fiber protein',
#  'distal/tail fiber protein',
#  'duf1983 containing putative tail fiber protein',
#  'endolysin tail fiber',
#  'endolysin tail fiber hydrolase',
#  'endosialidase tailspike',
#  'endosialidase tailspike protein',
#  'fhua receptor-binding tail protein',
#  'fusion long tail fiber distal subunit',
#  'gp12 short tail fiber protein',
#  'gp12 short tail fibers',
#  'gp12 short tail fibers protein',
#  'gp21, tail fiber protein',
#  'gp25, tail fiber',
#  'gp36 putative tail-fiber protein',
#  'gp36 small distal tail fiber subunit',
#  'gp36+37 fusion long tail fiber distal subunit',
#  'gp37 large distal tail fiber subunit',
#  'gp37 long tail fiber distal subunit',
#  'gp37 long tail fiber, distal subunit',
#  'gp38 distal long tail fiber adhesin',
#  'gp38 long tail fiber, distal tip',
#  'gp38 putative tail-fiber protein',
#  'gp55 putative tail-fiber/lysozyme protein',
#  'gp63 tail-fiber protein',
#  'gp77 putative tail-fiber protein',
#  'host specificity protein (tail fiber protein)',
#  'host specificity protein/ receptor binding protein',
#  'hypothetical protein; putative tail fibre',
#  'l shaped tail fiber protein',
#  'l-shaped tail fiber',
#  'l-shaped tail fiber protein',
#  'l-shaped tail fiber protein a',
#  'l-shaped tail fiber protein b',
#  'l-shaped tail fiber protein p132',
#  'l-shaped tail fibre protein',
#  'l-shaped type i tail fiber protein',
#  'lambda-like host specificity tail fiber protein j',
#  'large distal long tail fiber subunit',
#  'large distal tail fiber subunit',
#  'large tail fiber protein',
#  'large tail fiber subunit',
#  'lateral fiber tailspike with putative carbohydrate deacetylase domain',
#  'lateral tail fiber',
#  'lateral tail fiber protein',
#  'lateral tail fiber protein with fibronectin type iii domain',
#  'lateral tail fiber protein with glycosidase domain',
#  'lateral tail fiber protein with intimin domain',
#  'lateral tail fiber protein with type i collagen domain',
#  'lateral tail fibers protein',
#  'long distal tail fiber subunit',
#  'long tail fiber',
#  'long tail fiber adhesin',
#  'long tail fiber distal subunit',
#  'long tail fiber distal subunit adhesine',
#  'long tail fiber distal subunit receptor recognizing protein',
#  'long tail fiber distal subunit with adhesin domain',
#  'long tail fiber protein',
#  'long tail fiber protein distal subunit',
#  'long tail fiber protein p37',
#  'long tail fiber protein, distal subunit',
#  'long tail fiber subunit, distal',
#  'long tail fiber, distal part',
#  'long tail fiber, distal subunit',
#  'long-tail fiber adhesin',
#  'long-tail fiber protein',
#  'lower tail fiber protein',
#  'lytic tail fiber',
#  'major tail fiber',
#  'major tail fibers protein',
#  'minor tail fiber',
#  'minor tail fiber protein',
#  'neck appendage protein/tailspike protein',
#  'non-contractile tail fiber protein',
#  'phage long tail fiber',
#  'phage short tail fiber protein #t4-like phage gp12',
#  'phage short tail fiber protein gp12, middle domain',
#  'phage short tail fibers protein',
#  'phage straight tail fiber (short tail fiber)',
#  'phage t4 tail fiber',
#  'phage t4 tail fibre',
#  'phage t7 tail fiber protein',
#  'phage t7 tail fibre protein',
#  'phage tail fiber',
#  'phage tail fiber adhesin',
#  'phage tail fiber adhesin gp38',
#  'phage tail fiber host specificity protein',
#  'phage tail fiber protein',
#  'phage tail fiber protein / t7-like tail tubular protein a',
#  'phage tail fiber protein / t7-like tail tubular protein b',
#  'phage tail fiber protein [enterobacteria phage ime09]',
#  'phage tail fiber protein-like protein',
#  'phage tail fiber protein/t7-like tail tubular protein a',
#  'phage tail fiber repeat protein',
#  'phage tail fiber-like protein',
#  'phage tail fibers',
#  'phage tail fibers / putative tailspike protein',
#  'phage tail fibers protein',
#  'phage tail fibre',
#  'phage tail fibre adhesin',
#  'phage tail fibre tip',
#  'phage tailspike protein',
#  'polygalacturonase tail fiber hydrolase',
#  'polygalacturonase/tailspike protein',
#  'possible phage tail fiber protein',
#  'potential tail fiber',
#  'potential tail fiber protein with glycosidase activity or carbohydrate binding module',
#  'predicted tail fiber protein',
#  'probable tail fiber protein',
#  'probably distal tail fiber protein',
#  'probably gp37-like tail fiber protein',
#  'prophage tail fiber n-terminal domain-containing protein',
#  'puative tail fiber protein',
#  'putative central tail fiber',
#  'putative fusion long tail fiber distal subunit',
#  'putative gp55 tail-fiber/lysozyme protein',
#  'putative head decoration or putative tail fiber protein',
#  'putative host-binding tail fiber',
#  'putative l-shaped tail fiber protein',
#  'putative large distal tail fiber subunit',
#  'putative large distal tail fiber subunit 1',
#  'putative large distal tail fiber subunit 2',
#  'putative large distal tail fiber subunit protein',
#  'putative long distal tail fiber subunit',
#  'putative long tail fiber',
#  'putative long tail fiber distal subunit',
#  'putative long tail fiber protein',
#  'putative long tail fiber-distal subunit',
#  'putative lytic tail fiber protein',
#  'putative minor tail fiber protein',
#  'putative non-contractile tail fiber protein',
#  'putative phage tail fiber',
#  'putative phage tail fiber protein',
#  'putative phage tail fiber protein [escherichiaphage phapec8]',
#  'putative phage tail fiber tip protein',
#  'putative phage tail fibre protein',
#  'putative phage tail spike protein',
#  'putative phage tail-fibre protein',
#  'putative phage tailspike protein, partial',
#  'putative phage-related tail fiber protein',
#  'putative prophage tail fiber n-terminal domain-containing protein',
#  'putative prophage tail fibre c-terminus family protein',
#  'putative receptor binding protein',
#  'putative receptor binding protein 1',
#  'putative receptor binding protein 2',
#  'putative receptor binding tail protein',
#  'putative receptor recognition protein',
#  'putative receptor recognition tail fiber protein',
#  'putative receptor recognizing protein',
#  'putative receptor-binding protein',
#  'putative receptor-binding tail protein',
#  'putative receptor-recognising phage tail fiber adhesin',
#  'putative receptor-recognizing protein',
#  'putative short tail fiber',
#  'putative short tail fiber protein',
#  'putative short tail fiber protein [shigella phage shfl2]',
#  'putative short tail fibers',
#  'putative short tail fibers protein',
#  'putative short tail fibre',
#  'putative sialate o-acetylesterase tail fiber protein',
#  'putative side tail fiber domain protein',
#  'putative side tail fiber protein',
#  'putative small distal tail fiber subunit',
#  'putative straight tail fiber',
#  'putative straight tail fiber protein',
#  'putative straight tail fibers protein',
#  'putative t7-like tail fiber protein',
#  'putative tail fiber',
#  'putative tail fiber (tailspike) protein',
#  'putative tail fiber 1',
#  'putative tail fiber 2',
#  'putative tail fiber [escherichia virus vec25]',
#  'putative tail fiber adhesin',
#  'putative tail fiber adhesin protein',
#  'putative tail fiber adhesion',
#  'putative tail fiber adhesion protein',
#  'putative tail fiber distal protein',
#  'putative tail fiber domain-containing protein',
#  'putative tail fiber family protein',
#  'putative tail fiber i',
#  'putative tail fiber ii',
#  'putative tail fiber like protein',
#  'putative tail fiber protein',
#  'putative tail fiber protein / tail tubular protein a',
#  'putative tail fiber protein / tail tubular protein b',
#  'putative tail fiber protein 1',
#  'putative tail fiber protein 2',
#  'putative tail fiber protein [enterobacteria phage vb_ecom-fv3]',
#  'putative tail fiber protein [escherichia phage 2 jes-2013]',
#  'putative tail fiber protein [escherichia phage rv5]',
#  'putative tail fiber protein [escherichia phage v5]',
#  'putative tail fiber protein [escherichia phage vb_ecom_ffh2]',
#  'putative tail fiber protein [escherichia phage vb_vpm_pd06]',
#  'putative tail fiber protein [salmonella phage 40]',
#  'putative tail fiber protein [salmonella phage40]',
#  'putative tail fiber protein complex',
#  'putative tail fiber protein gp37',
#  'putative tail fiber protein h',
#  'putative tail fiber protein j',
#  'putative tail fiber protein.',
#  'putative tail fiber protein/putative eps depolymerase',
#  'putative tail fiber protein/putative epsdepolymerase',
#  'putative tail fiber protien',
#  'putative tail fiber repeat family protein',
#  'putative tail fiber tip protein',
#  'putative tail fiber-like protein',
#  'putative tail fiber/intimin-like protein',
#  'putative tail fibers protein',
#  'putative tail fibre',
#  'putative tail fibre protein',
#  'putative tail receptor-binding protein',
#  'putative tail spike',
#  'putative tail spike 1',
#  'putative tail spike associated glycoside hydrolase',
#  'putative tail spike associated hydrolase',
#  'putative tail spike protein',
#  'putative tail spike protein 2',
#  'putative tail spike protein head-binding protein',
#  'putative tail spike protein with depolymerase domain',
#  'putative tail spike with endopeptidase domain',
#  'putative tail-fiber protein',
#  'putative tail-fiber/lysozyme protein',
#  'putative tail-spike protein',
#  'putative tailspike',
#  'putative tailspike 63d sialidase',
#  'putative tailspike colanidase',
#  'putative tailspike protein',
#  'putative tailspike, beta-helical glycoside',
#  'putative tailspike, beta-helical glycoside hydrolase',
#  'putative variable tail fiber protein',
#  'putative variable tail fibre protein',
#  'rbp protein',
#  'recepter binding protein',
#  'receptor binding',
#  'receptor binding protein',
#  'receptor binding protein 1',
#  'receptor binding protein 2',
#  'receptor binding protein 3',
#  'receptor binding protein 4',
#  'receptor binding protein kinase',
#  'receptor binding tail protein',
#  'receptor recognition',
#  'receptor recognition protein',
#  'receptor recognizing protein',
#  'receptor-binding protein',
#  'receptor-binding protein 1',
#  'receptor-binding protein 2',
#  'receptor-binding tail protein',
#  'receptor-binding tail tip protein',
#  'receptor-recognition protein',
#  'receptor-recognizing adhesin protein',
#  'receptor-recognizing protein',
#  'receptor-recognizing protein 38',
#  'repeat-containing tail fiber protein',
#  'sgnh hydrolase domain containing tail fiber protein',
#  'short tail fiber',
#  'short tail fiber adhesin',
#  'short tail fiber protein',
#  'short tail fiber protein middle domain',
#  'short tail fiber protein receptor-binding domain',
#  'short tail fiber protein t4-like gp12',
#  'short tail fibers',
#  'short tail fibers protein',
#  'side tail fiber',
#  'side tail fiber protein',
#  'side tail fiber protein from bacteriophage origin',
#  'side tail fiber protein stf',
#  'side tail fiber protein-like protein',
#  'side tail fiber protein.',
#  'small distal long tail fiber subnit',
#  'small distal tail fiber',
#  'small distal tail fiber subunit',
#  'straight tail fiber',
#  'straight tail fiber (short tail fiber) protein',
#  'straight tail fiber protein',
#  't7 tail fiber protein',
#  't7-like tail fiber',
#  'tai fiber',
#  'tail fiber',
#  'tail fiber (host specificity) protein',
#  'tail fiber (whisker) protein',
#  'tail fiber - eps depolymerase',
#  'tail fiber / spike protein',
#  'tail fiber adhesin',
#  'tail fiber adhesin family protein',
#  'tail fiber adhesine',
#  'tail fiber adhesion protein',
#  'tail fiber cell wall hydrolase',
#  'tail fiber distal subunit',
#  'tail fiber domain protein',
#  'tail fiber domain-containing protein',
#  'tail fiber domain-containing protein_gp073',
#  'tail fiber domain-containing protein_gp076',
#  'tail fiber estarase',
#  'tail fiber extension',
#  'tail fiber extension protein',
#  'tail fiber family',
#  'tail fiber family protein',
#  'tail fiber fragment',
#  'tail fiber host specificity protein',
#  'tail fiber host-specificity protein j',
#  'tail fiber hydrolase',
#  'tail fiber j',
#  'tail fiber like protein',
#  'tail fiber lyase',
#  'tail fiber n-terminal domain-containing protein',
#  'tail fiber pblb-like protein',
#  'tail fiber protein',
#  'tail fiber protein / depolymerase domain',
#  'tail fiber protein / pectate lyase superfamily protein',
#  'tail fiber protein / t7-like tail tubular protein a',
#  'tail fiber protein / t7-like tail tubular protein b',
#  'tail fiber protein / tail tubular protein a',
#  'tail fiber protein / tail tubular protein b',
#  'tail fiber protein / tubular protein a',
#  'tail fiber protein / tubular protein b',
#  'tail fiber protein 1',
#  'tail fiber protein 2',
#  'tail fiber protein [aeromonas phage t7-ah]',
#  'tail fiber protein [eschericha phage vb_ecom-ecp26]',
#  'tail fiber protein [escherichia phage ll12]',
#  'tail fiber protein [escherichia phage vb_ecom-pr121lw]',
#  'tail fiber protein [escherichia phage vb_ecom_ffh2]',
#  'tail fiber protein [klebsiella phage knp2]',
#  'tail fiber protein a',
#  'tail fiber protein b',
#  'tail fiber protein complex',
#  'tail fiber protein gp35',
#  'tail fiber protein h',
#  'tail fiber protein ii',
#  'tail fiber protein j',
#  'tail fiber protein l',
#  'tail fiber protein of complex nature',
#  'tail fiber protein or l-shaped tail fiber protein',
#  'tail fiber protein p35',
#  'tail fiber protein p35 [enterobacteria phage ime09]',
#  'tail fiber protein p36',
#  'tail fiber protein p36 (protein gp36)',
#  'tail fiber protein p36 [enterobacteria phage ime09]',
#  'tail fiber protein protein',
#  'tail fiber protein r',
#  'tail fiber protein s',
#  'tail fiber protein sc',
#  'tail fiber protein stf',
#  'tail fiber protein xhla motif',
#  'tail fiber protein, t7 family',
#  'tail fiber protein-like protein',
#  'tail fiber protein; host specificity',
#  'tail fiber receptor binding protein',
#  'tail fiber receptor recognition protein',
#  'tail fiber related protein',
#  'tail fiber repeat family protein',
#  'tail fiber repeat protein',
#  'tail fiber s',
#  'tail fiber subunit',
#  'tail fiber tip protein',
#  'tail fiber-like protein',
#  'tail fiber/glycoside hydrolase',
#  'tail fiber/host adhesion protein',
#  'tail fiber/intimin-like protein',
#  'tail fiber/tail spike',
#  'tail fiber/tail spike protein',
#  'tail fibers',
#  'tail fibers [escherichia phage vb_ecom_js09]',
#  'tail fibers a',
#  'tail fibers b',
#  'tail fibers c',
#  'tail fibers d',
#  'tail fibers f',
#  'tail fibers protein',
#  'tail fibers protein [shigella phage shfml-26]',
#  'tail fibre adesine',
#  'tail fibre protein',
#  'tail fibrer protein gps',
#  'tail hyaluronidase/tail fiber',
#  'tail protein / putative rbp',
#  'tail sheath and receptor binding vision protein',
#  'tail spike',
#  'tail spike 1',
#  'tail spike 1 hypothetical c-terminal',
#  'tail spike 1 hypothetical n-terminal',
#  'tail spike 2',
#  'tail spike 3',
#  'tail spike 4',
#  'tail spike endosialidase',
#  'tail spike gp9',
#  'tail spike n domain-containing protein',
#  'tail spike protein',
#  'tail spike protein 1',
#  'tail spike protein 2',
#  'tail spike protein 3',
#  'tail spike protein endosialidase',
#  'tail spike protein head-binding protein',
#  'tail spike protein, capsular polysaccharide depolymerase',
#  'tail spike receptor binding protein',
#  'tail spike-like protein',
#  'tail-fiber associated protein',
#  'tail-fiber protein',
#  'tail-spike',
#  'tail-spike protein',
#  'tail_spike_n domain-containing protein',
#  'tailfiber like protein',
#  'tailspike',
#  'tailspike / endorhamnosidase',
#  'tailspike / hydrolase',
#  'tailspike 63d sialidase',
#  'tailspike colanidase',
#  'tailspike endosialidase',
#  'tailspike protein',
#  'tailspike protein 3',
#  'tailspike protein i',
#  'tailspike protein ii',
#  'tailspike protein iii',
#  'tailspike protein/preneck appendage',
#  'tailspike sialidase',
#  'type i tail fiber',
#  'type ii tail fiber/depolymerase',
#  'upper tail fiber protein',
#  'variable tail fiber protein',
#  'variable tail fiber protein h'}

# %%
with open(f'{constants.TEMP_PREPROCESSING}/{constants.HYPOTHETICAL_PRODUCTS}','rb') as hypothetical_proteins_file:
    hypothetical_proteins = pickle.load(hypothetical_proteins_file)
    
util.set_hypothetical_proteins(hypothetical_proteins)
for protein in hypothetical_proteins:
    print(protein)
# Out:
# gp30.2 conserved hypothetical protein
# protein of unknown function duf1493
# rb69orf033c hypothetical protein
# arn.3 hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 798
# gp30.3 conserved hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 313
# hypothetical helix-turn-helix domain protein
# hypothetical protein containing coiled-coil segments
# protein of unknown function duf1523
# hypothetical protein_gp147
# hypothetical protein [escherichia phage olb145]
# cd.3 hypothetical protein
# hypothetical protein_gp019
# hypothetical protein [escherichia phagevb_ecom_phb05
# hypothetical protein rdjlphi1_gp14
# hypothetical protein jb75_0167 [escherichia phage vb_ecom_jb75]
# hypothetical protein vn4_19 [vibrio phage n4]
# nrdc.2 hypothetical protein
# hyphothetical protein
# hypothetical protein a368
# gp44, hypothetical protein
# hypothetical protein_gp031
# protein of unknown function duf2163
# alt.1 conserved hypothetical protein
# hypothetical protein, duf3310
# hypothetical protein g53_00272 [escherichia phage vb_ecom_g53]
# hypothetical protein_gp279
# hypothetical protein kp16
# hypothetical protein rdjlphi1_gp42
# hypothetical protein acg-c40_0195 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein c118
# hypothetical protein d5505_00080[escherichiaphage d5505]
# hypothetical protein dexa.2
# fig01221575: hypothetical protein
# hypothetical protein hy01_0032 [escherichiaphagehy01]
# vs.1 conserved hypothetical phage protein
# hypothetical protein_gp295
# frd.3 conserved hypothetical protein
# putative protein of unknown function duf2828
# protein of unknown function duf1376
# gp47, hypothetical protein
# protein of uncharacterised function (duf3383)
# putative protein of unknown function duf3310
# rb32orf041c hypothetical protein
# putative tk 4 conserved hypothetical protein
# protein of unknown function duf3383
# ndd.2a hypothetical protein
# rb69orf156c hypothetical protein
# gp55.6 hypothetical protein
# hypothetical protein syn19_054
# hypothetical protein_gp203
# hypothetical protein a
# nrdc.11 conserved hypothetical phage protein
# hypothetical protein, duf3307
# hypothetical protein_gp010
# nrdc.3 hypothetical protein
# unknown protein encoded by prophage cp-933o
# hypothetical protein acg-c40_0219 [enterobacteria phage vb_ecom_acg-c40]
# rb69orf025c hypothetical protein
# hypothetical host-like protein
# hypothetical protein moda.2
# hypothetical protein gh15_010
# hypothetical protein rdjlphi1_gp69
# conserved hypothetical protein (xkdk-like)
# gp57b conserved hypothetical phage protein
# fig00642428: hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 760
# hypothetical zinc-finger containing protein
# hypothetical protein js09_070 [escherichia phage vb_ecom_js09]
# hypothetical-protein | belonging to t4-like gc: 836
# protein of unknown function duf1414
# hypothetical protein_gp135
# hypothetical protein [escherichia phagevb_ecom_phb05]
# conserved protein of unknown function upfb
# hypothetical protein kp20
# protein of unknown function duf3164
# rb69orf020c hypothetical protein
# gp55.1 hypothetical protein
# fig00638738: hypothetical protein
# hypothetical nrda
# hypothetical protein_gp149
# protein of unknown function duf4974
# protein of unknown function duf669
# rb69orf091c hypothetical protein
# protein of unknown function duf5491
# hypothetical-protein | belonging to t4-like gc: 250
# nin 68 (pept unknown;68)
# duf3987 protein of unknown function
# rb69orf072c hypothetical protein
# hypothetical protein_gp181
# hypothetical protein-like protein
# hypothetical protein vs.5
# hypothetical protein (pcfj domain-containing protein)
# gp5.4 conserved hypothetical protein
# hypothetical protein nrdc.8
# gp25, conserved hypothetical protein
# hypothetical protein_gp241
# unknown protein encoded in isec8
# hypothetical protein_gp271
# hypothetical protein yjhs
# hypothetical protein, ninh homolog
# hypothetical cyanophage protein
# hypothetical protein_gp198
# hypothetical protein_gp080
# hypothetical protein rdjlphi1_gp02
# hypothetical protein_gp231
# gp48, hypothetical protein
# hypothetical protein_gp146
# hypothetical protein moda.4
# hypothetical protein gh15_053
# hypothetical-protein | belonging to t4-like gc: 758
# hypothetical protein [escherichia phage rv5]
# frd.2 hypothetical protein
# hypothetical protein_gp039
# hypothetical protein acg-c40_0220 [enterobacteria phage vb_ecom_acg-c40]
# gp30.4 hypothetical protein
# conserved protein of unknown function pdcb
# a-gt.5 conserved hypothetical protein
# similar to a conserved hypotheical protein of vibrio cholerae
# putative hypothetical protein
# hypothetical protein hor21_gp061 [escherichiaphage esco13]
# conserved hypothetical protein (xkdn-like)
# hypothetical protein_gp153
# gp49.1 conserved protein of unknown function
# unknown
# hypothetical protein_gp143
# gp10, conserved hypothetical protein
# hypothetical protein_gp075
# border orf l protein, unknown function
# rb69orf150c hypothetical protein
# fig00639050: hypothetical protein
# conserved protein of unknown function upl
# hypothetical protein nrdc.7
# hypothetical protein vec25_57 [escherichiavirusvec25]
# pset.1 conserved hypothetical protein
# hypothetical protein_gp193
# hypothetical protein_gp035
# hypothetical protein orf00256
# hypothetical protein e.3
# gp42.1 hypothetical protein
# ndd.5 hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 780
# gp30.5 conserved hypothetical protein
# hypothetical protein shfl2p111 [shigella phage shfl2]
# protein of unknown function duf2800
# hypothetical protein [escherichia phage ime09]
# hypothetical-protein | belonging to t4-like gc: 201
# unknown product
# hypothetical-protein | belonging to t4-like gc: 784
# protein of unknown function (duf2303)
# hypothetical-protein | belonging to t4-like gc: 815
# hypothetical protein_gp072
# mobd.4 hypothetical protein [enterobacteria phage rb51]
# hypothetical protein ek99p-1_0011
# hypothetical protein rdjlphi1_gp73
# protein of unknown function duf2883
# putative protein of unknown function duf723
# hypothetical protein ecgd1_080 [enterobacteriaphage ecgd1]
# hypothetical protein_gp297
# hypothetical-protein | belonging to t4-like gc: 819
# hypothetical protein shfl2p185 [shigella phage shfl2]
# hypothetical protein_gp257
# protein of unknown function duf5664
# hypothetical-protein | belonging to t4-like gc: 730
# trna.2 hypothetical protein
# hypothetical protein_gp249
# a-gt.4 hypothetical protein
# hypothetical protein gp37
# motb.1 hypothetical protein
# hypothetical proetein
# hypothetical rem protein
# hypothetical protein rdjlphi1_gp21
# hypothetical protein acg-c40_0204 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein_gp114
# hypothetical protein [escherichia phagevb_vpm_pd114]
# hypothetical protein acg-c40_0069 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein shfl2p197 [shigella phage shfl2]
# hypothetical protein [escherichia phage eco4]
# tk.3 hypothetical protein
# protein of unknown function duf4065
# hypothetical protein shfl2p277 [shigella phage shfl2]
# protein of unknown function duf5856
# hypothetical protein mobd.6 [shigella phage shfl2]
# hypothetical-protein | belonging to t4-like gc: 684
# hypothetical protein gp30
# gp43.1 hypothetical protein
# hypothetical protein acg-c40_0130 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical-protein | belonging to t4-like gc: 394
# hypothietical protein
# hypothetical protein (d10 5' region)
# vs.6 hypothetical protein
# hypothetical protein_gp240
# protein of unknown function duf2815
# uncharacterized conserved protein
# hypothetical protein acg-c40_0093 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein kp36
# hypothetical protein_gp123
# protein of unknown function duf2737
# hypothetical phage-related protein
# rb69orf089c hypothetical protein
# rb32orf110c hypothetical protein
# gp49.3 hypothetical protein
# hypothetical protein cpt_phagek_gp057
# putative protein of unknown function
# protein of unknown function duf1642
# putative protein of unknown function (duf2833)
# unnamed protein product
# hypothetical protein_gp132
# hypothetical protein jd18_193
# hypotthetical protein
# hypothetical protein_gp086
# hypothetical protein_gp215
# hypothetical-protein | belonging to t4-like gc: 726
# hypothetical-protein | belonging to t4-like gc: 813
# gp38, hypothetical protein
# hypothetical protein_gp246
# tk.2 hypothetical protein
# hypothetical protein rb32orf128c [enterobacteria phage rb32]
# hypothetical protein [escherichia phage e11/2]
# rb69orf135c hypothetical protein
# protein of unknown function duf4347
# conserved protein of unknown function, isaa
# hypothetical protein vec25_44 [escherichiavirusvec25]
# hypothetical protein ep23p40
# gp14, conserved hypothetical protein
# hypothetical protein_gp014
# gp21, hypothetical protein
# hypothetical protein rdjlphi1_gp57
# fig01049728: hypothetical protein
# hypothetical protein within prophage
# protein of unknown function (duf1364)
# hypothetical-protein | belonging to t4-like gc: 768
# hypothetical protein gp21
# hypothetical protein_gp022
# hypothetical protein_gp125
# protein of unknown function duf1983
# hypothetical protein ecgd1_063 [enterobacteriaphage ecgd1]
# hypothetical protein vec25_69 [escherichiavirusvec25]
# hypothetical protein cpt_phagek_gp079
# hypothetical-protein | belonging to t4-like gc: 734
# protein of unknown function duf1768
# nrda.2 hypothetical protein
# nrdc.1 hypothetical protein
# hypothetical protein_gp007
# hypothetical-protein | belonging to t4-like gc: 778
# hypothetical protein cpt_phagek_gp174
# gp15, conserved hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 840
# mobd.6 conserved hypothetical protein
# hypothetical protein ecgd1_183 [enterobacteriaphage ecgd1]
# rb69orf259c hypothetical protein
# fig00644188: hypothetical protein
# protein of uncharacterised function (duf3800)
# hypothetical protein gp61.4
# regulatory hypothetical protein
# hypothetical protein rdjlphi1_gp11
# hypothetical-protein | belonging to t4-like gc: 781
# hypothetical protein rdjlphi1_gp38
# uncharacterized protein family upf0027
# hypothetical protein_gp028
# pset.2 conserved hypothetical phage protein
# hypothetical protein a63
# hypothetical-protein | belonging to t4-like gc: 852
# rb32orf082c hypothetical protein
# hypothetical protein_gp270
# fig00643696: hypothetical protein
# mobd.5 hypothetical protein
# protein of unknown function (duf1367)
# hypothetical protein rdjlphi1_gp34
# dexa.1 hypothetical protein
# gp17'' unknown function
# gp40, hypothetical protein
# hypothetical protein nrdc.4
# hypothetical-protein | belonging to t4-like gc: 871
# gp31.2 hypothetical protein [enterobacteria phage rb51]
# gp14, hypothetical-acquired protein
# protein of unknown function duf1129
# hypothetical-protein | belonging to t4-like gc: 759
# hypothetical protein_gp256
# hypothetical protein ek99p-1_0042
# conserved protein of unknown function, part 2
# protein of unknown function duf4379
# e.2 hypothetical protein
# hypothetical protein av954_gp55
# rb69orf117c hypothetical protein
# hypothetical protein rdjlphi1_gp41
# protein of unknown function duf5048
# gp39.2 hypothetical protein
# unknown phi protein
# rb69orf082c hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 741
# fig00640206: hypothetical protein
# protein of unknown function duf4116
# protein of unknown function duf3396
# n315 hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 821
# mobd.2a hypothetical protein
# 57b conserved hypothetical protein
# cd.5 hypothetical protein
# gp18, conserved hypothetical protein
# hypothetical protein c134
# fig00642859: hypothetical protein
# protein of unknown function duf646
# gp7, hypothetical protein
# hypothetical protein vs.1
# protein of unknown function duf1391
# uncharacterized protein conserved in bacteria
# gp47, conserved hypothetical protein
# nrdc.8 hypothetical protein
# gp55.1 conserved hypothetical protein
# hypothetical protein, pv83 orf19-like protein
# hypothetical-protein | belonging to t4-like gc: 776
# hypothetical protein with c-terminal zinc finger, ranbp2-type
# fig00641962: hypothetical protein
# hypothetical protein kp9
# protein of unknown function duf4858
# hypothetical protein orf013
# hypothetical protein acg-c40_0072 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein c119
# hypothetical protein nrdc.6
# hypothetical protein, pvl orf50-like protein
# hypotheticall protein
# protein of unknown function duf159
# protein of unknown function duf3127
# frd.1 hypothetical protein
# rb32orf010c hypothetical protein
# found by: glimmer and metageneannotatorhypothetical protein g377_gp160 [escherichia phage phapec8] ncbi blastx nr phage yp_007348477.1
# hypothetical protein rdjlphi1_gp52
# hypothetical-protein | belonging to t4-like gc: 804
# hypothetical protein_gp275
# hypothetical protein ptxu06_00058
# protein of unknown function duf1382
# protein of unknown function duf2513
# hypothetical protein_gp038
# hypothetical protein ri.1 [shigella phage shfl2]
# hypothetical protein [enterobacteria phage hx01]
# hypothetical protein_gp210
# hypothetical protein [escherichia virus t4]
# hypothetical protein vn4_42 [vibrio phage n4]
# hypothetical-protein | belonging to t4-like gc: 823
# protein of unknown function duf4047
# hypothetical group i intron protein
# ri.1 hypothetical protein
# protein of unknown function duf2577
# hypothetical protein gh15_070
# hypothetical protein ecgd1_224[enterobacteriaphage ecgd1]
# hypothetical protein rb32orf213c [enterobacteria phage rb32]
# hypothetical-protein | belonging to t4-like gc: 733
# conserved exported protein of unknown function
# hypothetical protein_gp290
# hypothetical protein hk578_011
# hypothetical protein aeh1orf302c-like protein
# hypothetical protein pgug_03229
# hypothetical protein rdjlphi1_gp30
# hypothetical protein_gp168
# rb69orf012c hypothetical protein
# gp11, conserved hypothetical protein
# conserved uncharacterized protein
# hypothetical protein kp14
# rb69orf024c hypothetical protein
# hypothetical protein_gp089
# hypothetical protein shfl2p102 [shigella phage shfl2]
# vr7orf006c hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 825
# rb69orf145c hypothetical protein
# gp61.4 hypothetical protein
# gp24.3 conserved hypothetical protein
# rb69orf124c hypothetical protein
# hypothetical protein rb32orf133c [enterobacteria phage rb32]
# hypothetical protein b76
# hypothetical protein mrh.2
# hypothetical protein_gp199
# hypothetical protein_gp052
# hypotheticl protein
# motb.2 hypothetical protein
# hypothetical protein hy01_0102 [escherichiaphagehy01]
# protein of unknown function duf2280
# hypothetical protein epjs98_gp232[escherichiaphage js98]
# hypothetical-protein | belonging to t4-like gc: 844
# riia.1 hypothetical protein
# gp39.1 hypothetical protein
# moda.3 hypothetical protein
# hypothetical protein kp27
# gp34, hypothetical protein
# protein of unknown function duf927
# protein of unknown function duf3310
# protein of unknown function duf1071
# conserved hypothetical protein [escherichiaphagejs98]
# hypothetical protien
# gp46.1 conserved hypothetical protein
# hypotheticla protein
# rb69orf029w hypothetical protein
# pset.3 conserved hypothetical protein
# protein of unknown function duf1140
# hypothetical protein [enterobacteria phage vb_ecom_ime341]
# fig00640898: hypothetical protein
# protein of unknown function duf2612
# hypothetical protein vs.6
# hypothetical-protein | belonging to t4-like gc: 788
# conserved hypothetical phage protein (pseudogene)
# putative protein of unknown function duf968
# hypothetical-protein | belonging to t4-like gc: 808
# gp55.4 conserved hypothetical protein
# rb32orf214c hypothetical protein
# rb69orf137c hypothetical protein
# hypothetical
# protein of unknown function (duf5476)
# hypothetical protein psco10_87
# conserved hypothetical protein - phage
# protein of unknown function duf1073
# dda.1 conserved hypothetical protein
# unknown protein
# gp24.2 conserved hypothetical protein
# hypotheticla protien
# glu-rich hypothetical protein
# hypothetical protein shfl2p083 [shigella phage shfl2]
# rb32orf096c hypothetical protein
# nrdc.2 hypothetical protein [enterobacteria phage rb51]
# hypothetical protein d
# fig00641337: hypothetical protein
# protein of unknown function duf1320
# gp46.2 hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 846
# hypothetical protein acg-c40_0206 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein nrdc.10
# gp18, hypothetical protein
# hypothetical protein jd18_139 [klebsiellaphagejd18]
# nrdc.11 conserved hypothetical protein
# hypothetical protein a-gt.4 [shigella phage shfl2]
# hypothetical protein_gp174
# rb69orf047c hypothetical protein
# hypothetical protein_gp157
# hypothetical protein rdjlphi1_gp13
# nrdc.9 hypothetical protein [enterobacteria phage rb14]
# protein of unknown function duf1351
# hypothetical-protein | belonging to t4-like gc: 783
# hypothetical protein wf5505_00007
# hypothetical-protein | belonging to t4-like gc: 835
# hypothetical protein_gp145
# hypothetical protein sp18_gp007 [shigellaphagesp18]
# protein of unknown function duf2793
# conserved hypothetical protein (xkds-like)
# hypothetical protein_gp049
# gp30.8 conserved hypothetical protein
# vs.6 conserved hypothetical protein
# hypothetical phage
# hypothetical-protein | belonging to t4-like gc: 160
# hypothetical protein_gp209
# hypothetical protein ec2_008 [escherichia phage 2 jes-2013]
# hypothetical protein_gp011
# hypothetical-protein | belonging to t4-like gc: 864
# rb69orf149c hypothetical protein
# protein of unknown function duf1364
# hypothetical protein trna.4
# gp54, conserved hypothetical protein
# gp30.4 conserved hypothetical protein
# hypothetical protein, duf859
# hypothetical protein_gp214
# hypothetical protein_gp281
# protein of unknown function duf853
# uncharacterized protein
# hypothetical protein hor21_gp167 [escherichiaphage esco13]
# protein of unknown function (duf5516)
# hypothetical-protein | belonging to t4-like gc: 873
# protein of unknown function duf4815
# hypothetical protein_gp020
# rb69orf132c hypothetical protein
# hypothetical protein g377_gp171 [escherichiaphage phapec8]
# trna.2 conserved hypothetical protein
# hypothetical protein gp47
# nin 56 (pept unknown;56)
# protein of unknown function duf4083
# hypothetical protein g377_gp267 [escherichiaphage phapec8]
# moda.4 conserved hypothetical protein
# protein of unknown function duf4222
# protein of unknown function duf2740
# hypothetical-protein | belonging to t4-like gc: 198
# hypothetical protein mobd.4
# hypothetical protein kp8
# hypothetical-protein | belonging to t4-like gc: 762
# hypothetical protein_gp283
# fig00638886: hypothetical protein
# protein of unknown function duf2717
# hypothetical protein orf00049
# hypothetical protein_gp244
# ip5 hypothetical protein
# hypothetical protein_gp138
# protein of unknown function duf1125
# ndd.1 conserved hypothetical protein
# hypothetical protein cpt_phagek_gp022
# fig00638423: hypothetical protein
# hypothetical protein trna.3
# hypothetical-protein | belonging to t4-like gc: 766
# hypothetical protein gp33
# putative uncharacterized protein dpse_ga13493
# arn.4 hypothetical protein
# protein of unknown function duf469
# hypothetical protein fh31_gp69
# uncharacterized protein ybcv, duf1398
# rb32orf229c hypothetical protein
# hypothetical protein c125
# rb32orf005c hypothetical protein
# gp24, conserved hypothetical protein
# hypothetical protein trna.2
# intein-containing hypothetical protein
# protein of unknown function duf2184
# fig00553794: hypothetical protein
# rb69orf092c hypothetical protein
# rb32orf033c hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 824
# conserved protein of unknown function uhr
# conserved hypothetical bacterial protein
# fig00642676: hypothetical protein
# hypothetical protein orf031
# hypothetical-protein | belonging to t4-like gc: 837
# protein of unknown function duf4128
# exported protein of unknown function
# tk.1 hypothetical protein
# hypothetical protein gp1
# fig00640927: hypothetical protein
# hypothetical protein gh15_016
# mota.1 hypothetical protein
# hypothetical protein_gp151
# hypothetical-protein | belonging to t4-like gc: 802
# protein of unknown function duf1514
# hypothetical protein vec25_45 [escherichiavirusvec25]
# conserved hypothetical phage-related protein
# protein of unknown function duf550
# gp29, conserved hypothetical protein
# hypothetical protein_gp117
# protein of unknown function duf722
# hypothetical protein_gp150
# hypothetical-protein | belonging to t4-like gc: 872
# ri.-1 hypothetical protein
# fig00639830: hypothetical protein
# rb32orf047c hypothetical protein
# hypothetical protein [salmonella phage sg1]
# hypothetical protein rz
# hypothetical protein acg-c40_0120 [enterobacteria phage vb_ecom_acg-c40]
# hypotheical protein
# hypothetical-protein | belonging to t4-like gc: 785
# hypothetical protein_gp139
# hypothetical protein rdjlphi1_gp39
# hypothetical-protein | belonging to t4-like gc: 750
# hypothetical-protein | belonging to t4-like gc: 834
# gp55.3 hypothetical protein
# hypothetical protein [escherichia coli]
# fig00637998: hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 816
# hypothetical protein_gp136
# protein of unknown function duf5484
# fig00640518: hypothetical protein
# a-gt.3 hypothetical protein
# protein of unknown function duf1874
# hypothetical protein tk.2
# rb69orf051c hypothetical protein
# hypothetical protein ning
# hypothetical 9.2 kda protein
# mobd.3 hypothetical protein
# hypothetical zinc ribbon protein
# hypothetical-protein | belonging to t4-like gc: 650
# hypothetical protein nrdc.3 [shigella phage shfl2]
# hypothethical phage protein
# protein of unknown function duf2313
# hypothetical protein_gp194
# hypothetical protein, pvl orf51-like protein
# protein of unknown function duf2685
# protein of unknown function duf1631
# hytothetical protein
# uvsw.1 conserved hypothetical protein
# hypothetical protein kp7
# fig00639155: hypothetical protein
# hypothetical protein_gp001
# hypothetical protein gp6
# hypothetical protein sp18_gp281 [shigella phage sp18]
# hypothetical protein cpt_marfa_271[klebsiellaphage marfa]
# hypothetical protein kvp40.0188
# conserved protein of unknown function pdca
# hypothetical protein rdjlphi1_gp05
# putative protein of unknown function duf1367
# hypothetical protein rdjlphi1_gp40
# gp45, conserved hypothetical protein
# mobd.2 hypothetical protein
# hypothetical protein gp26
# hypothetical protein acg-c40_0100 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein ep23p43 [shigellaphageep23]
# protein of unknown function duf3862
# protein of unknown function duf955
# hypothetical-protein | belonging to t4-like gc: 860
# ndd.2 hypothetical protein [enterobacteria phage rb51]
# hypothetical protein_gp122
# rb69orf258c hypothetical protein
# mrh.2 conserved hypothetical protein
# unknown function protein
# mobd.2 conserved hypothetical protein
# protein of unknown function duf1441
# hypothetical-protein | belonging to t4-like gc: 729
# fig00639676: hypothetical protein
# hypothetical protein_gp142
# protein of unknown function duf4031
# protein of unknown function duf3042
# hypothetical protein_gp180
# hypothetical protein [escherichia phage wv7]
# fig01046459: hypothetical protein
# rb69orf127c hypothetical protein[escherichiaphage rb69]
# hypothetical protein gp29
# hypothetical protein ecgd1_038 [enterobacteriaphage ecgd1]
# hypothetical-protein | belonging to t4-like gc: 771
# hypothetical protein ek99p-1_0044
# gp68, hypothetical protein
# asia.1 hypothetical protein
# hypothetical protein cpt_phagek_gp063
# fig00694808: hypothetical protein
# hypothetical protein kp44
# nin 221 (pept unknown;221)
# uncharacterized protein ybcn
# hypothetical protein rdjlphi1_gp65
# protein of unknown function duf2724
# protein of unknown function duf4224
# hypothetical protein_gp286
# hypothetical protein rdjlphi1_gp62
# hypothetical protein rdjlphi1_gp87
# hypothetical protein jr320_gp030 [escherichiaphage alia]
# hypothetical protein rb14orf29 [enterobacteria phage rb14]
# hypothetical protein similar to mu gema
# hypothetical-protein | belonging to t4-like gc: 777
# mobd.1 conserved hypothetical protein
# hypothetical protein rdjlphi1_gp71
# putative dexa.1 hypothetical protein
# mu phage uncharacterized protein
# hypothetical protein vsip_49
# hypothetical protein mobd.5
# hypothetical protein, duf4830
# hypothetical protein p108_0018
# hypothetical protein moda.3
# hypothetical-protein | belonging to t4-like gc: 799
# hypothetical protein rb32orf095c [enterobacteria phage rb32]
# hypothetical protein rdjlphi1_gp59
# hypothetical protein cr3_gp151 [cronobacter phagecr3]
# hypothetical protein_gp179
# protein of unknown function duf2635
# hypothetical protein_gp047
# hypothetical protein vs.7
# conserved protein of unknown function ppfa
# hypothetical protein ddb_g0286989
# hypothetical-protein | belonging to t4-like gc: 826
# hypothetical protein hor21_gp123 [escherichiaphage esco13]
# hypothetical protein moda.3 [shigella phage shfl2]
# hypothetical protein rdjlphi1_gp68
# moda.4 hypothetical protein [enterobacteria phage rb51]
# fig01045970: hypothetical protein
# hypothetical protein [enterobacteria phage rb51]
# hypothetical protein g10400_00016[escherichiaphage vb_ecom_g10400]
# hypothetical-protein | belonging to t4-like gc: 68
# hypothetical protein_gp264
# hypothetical protein rdjlphi1_gp72
# hypothetoical protein
# hypothetical protein kp35
# fig01254993: hypothetical protein
# protein of unknown function duf3113
# fig00640097: hypothetical protein
# hypothetical protein ecgd1_057 [enterobacteriaphage ecgd1]
# gp30.9 conserved hypothetical protein
# protein of unknown function duf1643
# hypothetical-protein | belonging to t4-like gc: 321
# hypothetical protein_gp298
# hypothetical protein_gp158
# hypothetical protein rdjlphi1_gp06
# hypothetical protein orf_0028
# rb69orf022c hypothetical protein
# hypothetical protein pg7_094 [enterobacter phage pg7]
# hypothetical protein kp43
# hypothetical protein_gp033
# hypothetical protein rdjlphi1_gp79
# gp55.3 conserved hypothetical protein
# hypothetical protein_gp068
# hypothetical-protein | belonging to t4-like gc: 10
# protein of unknown function duf3768
# protein of unknown function duf3987
# hypothetical protein_gp126
# hypothetical protein gh15_104
# conserved protein of unknown function ygbk
# pset.2 conserved hypothetical protein
# conserved hypothetical protein
# hypothetical protein [enterobacteria phage vb_ecom_ime281]
# hypothetical-protein | belonging to t4-like gc: 822
# vs.3 conserved hypothetical protein
# hypothetical protein rdjlphi1_gp64
# nrdc.9 hypothetical protein
# gp55.8 hypothetical protein
# mobd.2a conserved hypothetical protein
# hypothetical protein moda.2 [shigella phage shfl2]
# gp55.4 hypothetical protein
# hypothetical protein_gp054
# hypothetical protein_gp109
# hypothetical protein_gp074
# a-gt.4 conserved hypothetical protein
# hypotetical protein
# protein of unknown function duf6388
# protein of unknown function duf4376
# hypothetical protein nrdc.11
# hypothetical protein [escherichia phage slur07]
# hypothetical protein_gp253
# hypothetical protein rdjlphi1_gp03
# hypothetical protein_gp037
# hypothetical-protein | belonging to t4-like gc: 786
# hypothetical protein a-gt.2
# nrd.1 hypothetical protein
# hypothetical protein shfl1p001 [shigella phage shfl2]
# uvsy.-2 hypothetical protein
# uncharacterized protein orf43.1
# hypothetical-protein | belonging to t4-like gc: 814
# conserved hypotethical phage protein
# rb69orf188c hypothetical protein
# conserved hypothetical protein; skin element
# dexa.2 conserved hypothetical protein
# protein of unknown function duf3799
# hypothetical protein_gp053
# gp24, hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 761
# protein of unknown function duf2590
# protein of unknown function duf488
# enterobacter protein of unknown function
# hypothetical protein shfl2p074 [shigella phage shfl2]
# hypothetical protein gp45.2
# nrdc.3 conserved hypothetical protein
# gp35, hypothetical protein
# hypothetical protein gap32_442 [cronobacter phage vb_csam_gap32]
# hypothetical protein, duf1140
# uncharacterized protein conserved in bacteria, prophage-related
# hypothetical protein_gp187
# gp46.1 hypothetical protein
# hypothetical protein_gp200
# hypothetical protein
# gp5.4 hypothetical protein
# cd.1 hypothetical protein
# rb32orf081c hypothetical protein
# fig00638873: hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 15
# gp17'b unknown function
# ri.1 conserved hypothetical protein
# putative conserved hypothetical protein
# fig00638770: hypothetical protein
# protein of unknown function (duf3268)
# protein of unknown function (duf551)
# rb69orf148c hypothetical protein
# hypothetical protein_gp056
# gp30.9 hypothetical protein
# ndd.4 hypothetical protein
# riia.1 conserved hypothetical protein
# protein of unknown function duf859
# hypothetical protein orf00021
# conserved hypothetical protein, fragment
# hypothetical protein yfdr
# hypothetical protein rdjlphi1_gp45
# cd.2 hypothetical protein
# protein of unknown function duf2187
# gp32, hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 755
# fig00642906: hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 746
# hypothetical protein a73
# hypothetical protein_gp021
# hypothetical protein ac3ha13_160[escherichiaphage vb_ecop_3ha13]
# protein of unknown function duf2158
# fig00640542: hypothetical protein
# hypothetical protein pa4870
# protein of unknown function duf5663
# hypothetical protein shfl2p247 [shigella phage shfl2]
# protein of unknown function duf1381
# putative protein of unknown function duf2800
# protein of unknown function duf4494
# hypothetical protein rdjlphi1_gp49
# fig00129991: hypothetical protein
# gp30.3 hypothetical protein
# nin 146 (pept unknown;146)
# hypothetical protein gp15
# fig00641106: hypothetical protein
# mrh.1 hypothetical protein
# protein of unknown function duf2019
# fig01046174: hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 793
# gp26, conserved hypothetical protein
# fig00638505: hypothetical protein
# hypothetical protein kp45
# hypothetical protein_gp004
# hypothetical protein_gp105
# fig01045770: hypothetical protein
# hypothetical protein dda.1
# hypothetical protein_gp023
# protein of unknown function duf2460
# hypothetical protein [escherichia phage pmbt57]
# tk.2 conserved hypothetical protein
# fig00638312: hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 842
# protein of unknown function duf600
# hypothetical protein psco10_10
# hypothetical protein [serratia phage x20]
# gp15, hypothetical replication protein
# putative imm.1 hypothetical protein
# protein of unknown function duf1799
# hypothetical protein gh15_142
# hypothetical protein_gp026
# gp20, conserved hypothetical protein
# hypothetical protein rdjlphi1_gp86
# hypothetical protein_gp196
# ri.-1 conserved hypothetical protein
# nrdc.4 hypothetical protein
# hypothetical protein [enterobacteria phage vb_ecom-fv3]
# hypothetical protein_gp258
# hypothetical-protein | belonging to t4-like gc: 830
# hypothetical protein_gp107
# hypothetical protein_gp078
# conserved protein of unknown function upfa
# gp49.2 hypothetical protein
# putative uncharacterized nin region protein
# fig00638450: hypothetical protein
# gp2 hypothetical protein
# rb69orf245c hypothetical protein
# protein of unknown function duf820
# hypothetical protein a-gt.3 [shigella phage shfl2]
# hypothetical protein_gp201
# gp55.5 hypothetical protein
# hypothetical protein rb49orf238c-like protein
# protein of unknown function duf2303
# hypothetical protein_gp162
# dexa.2 hypothetical protein [enterobacteria phage rb51]
# hypothetical proteins
# fig00638683: hypothetical protein
# uncharacterized protein ybcw
# hypothetical protein shfl2p003 [shigella phage shfl2]
# hypothetical protein acg-c40_0046 [enterobacteria phage vb_ecom_acg-c40]
# cd.1 conserved hypothetical protein
# protein of unknown function duf932
# hypothetical protein_gp062
# hypothetical protein gp48
# hypothetical protein rb32orf111c [enterobacteria phage rb32]
# fig00641386: hypothetical protein
# e.4 hypothetical protein [enterobacteria phage rb14]
# protein of unknown function duf5487
# protein of unknown function duf2560
# protein of unknown function duf1492
# motb.2 hypothetical protein [enterobacteria phage rb51]
# hypothetical protein (hth domain-containing protein)
# fig00640165: hypothetical protein
# hypothetical protein lpppvgp01
# hypothetical-protein | belonging to t4-like gc: 765
# hypothetical protein_gp133
# hypothetical protein rdjlphi1_gp33
# gp30.8 hypothetical protein
# hypothetical protein c131
# hypothetical protein rdjlphi1_gp58
# rb69orf230c hypothetical protein
# vs.3 hypothetical protein
# hypothetical protein vs.8
# fig00638659: hypothetical protein
# protein of unknown function duf3622
# hypothetical protein shfl2p225 [shigella phage shfl2]
# hypothetical pbsx family phage portal protein
# hypothetical protein kp10
# hypothetical protein psesnuabm01_047[salmonellaphage pse_snuabm_01]
# gp66, conserved hypothetical protein
# fig00639844: hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 818
# fig01221266: hypothetical protein
# fig00642187: hypothetical protein
# phage uncharacterized protein
# hypothetical protein gh15_139
# tk.4 conserved hypothetical phage protein
# hypothetical protein shfl2p206 [shigella phage shfl2]
# hypothetical protein gp20
# hypothetical protein (d10 3' region)
# hypothetical protein_gp124
# hypothetical protein_gp127
# hyppothetical protein
# domain of uncharacterised function (duf1833)
# tk.4 hypothetical protein
# hypothetical protein [yersinia phage pst]
# fig00641471: hypothetical protein
# hypothetical protein sh7_0145 [shigellaphagesh7]
# hypothetical protein gp8
# hypothetical-protein | belonging to t4-like gc: 737
# rb69orf048c hypothetical protein
# gp12, hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 791
# fig00640743: hypothetical protein
# putative protein of unknown function (duf3154)
# hypothetical protein phite_096 [pectobacterium phage phite]
# hypothetical protein acg-c40_0035 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical-protein | belonging to t4-like gc: 779
# hypothetical protein sp18_gp006 [shigellaphagesp18]
# hypothetical protein js09_055 [escherichia phage vb_ecom_js09]
# protein of unknown function duf723
# uncharacterized protein mj0770
# protein of unknown function duf3486
# protein of unknown function duf2213
# hypothetical protein_gp156
# hypothetical protein_gp063
# hypothetical protein rdjlphi1_gp29
# hypothetical protein g377_gp182 [escherichiaphage phapec8]
# hypothetical protein shfl2p005 [shigella phage shfl2]
# rb69orf127c hypothetical protein
# fig00637919: hypothetical protein
# protein of unknown function
# gp30.6 hypothetical protein
# hypothetical protein_gp154
# hypothetical protein_gp120
# hypothetical protein acg-c40_0081 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical-protein | belonging to t4-like gc: 355
# conserved protein of unknown function hdf
# alt.-1 hypothetical protein
# rb69orf231c hypothetical protein
# rb69orf087c hypothetical protein
# protein of unknown function duf1031
# hypothetical protein gp46.1
# hypothetical protein_gp148
# hypothetical protein shfl2p211 [shigella phage shfl2]
# hypothetical protein wf5505_00041
# gp52.1 hypothetical protein
# gp16, conserved hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 772
# hypothetical-protein | belonging to t4-like gc: 868
# blast to axy86382 hypothetical protein meda_122
# hypothetical protein sssm5_047
# vs.8 conserved hypothetical protein
# hypothetical protein rv5_gp169 [escherichia phagev5]
# hypothetical-protein | belonging to t4-like gc: 867
# protein of unknown function duf167
# putative protein of unknown function duf1768
# hypothetical-protein | belonging to t4-like gc: 769
# protein of unknown function duf1833
# hypothetical protein i
# hypothetical protein_gp223
# hypothetical protein rostov1_00018 [vibrio phage rostov-1]
# hypothetical-protein | belonging to t4-like gc: 763
# trna.4 hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 66
# alt.-3 hypothetical protein
# hypothetical protein_gp197
# protein of unknown function duf4064
# hypothetical protein g377_gp242 [escherichiaphage phapec8]
# fig00644832: hypothetical protein
# protein of unknown function duf5471
# hypothetical protein, pv83 orf23-like protein
# fig01049434: hypothetical protein
# vs.7 conserved hypothetical protein
# uncharacterized protein ylcg
# hypothetical protein_gp167
# protein of unknown function duf5016
# rb69orf052c hypothetical protein
# rb69orf050c hypothetical protein
# hypothetical protein cpt_phagek_gp001
# trna.4 conserved hypothetical protein
# gp23, hypothetical protein
# hypothetical protein acg-c40_0088 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein_gp204
# denb.1 hypothetical protein
# hypothetical protein_gp134
# hypothetical-protein | belonging to t4-like gc: 795
# gp61.1 conserved hypothetical protein
# hypothetical protein rdjlphi1_gp27
# hypothetical protein tk.4
# nrdc.2 conserved hypothetical protein
# rb69orf046c hypothetical protein
# hypothetical protein_gp207
# hypothetical protein avu03_gp10 yp_009208096.1
# hypothetical protein, contains bacterial ig-like and invasin/intimin cell-adhesion domains
# protein of uncharacterised function (duf2693)
# gp45, hypothetical protein
# hypothetical protein [escherichia phage anyang]
# hypothetical protein_gp092
# hypothetical protein within a prophage
# protein of uncharacterised function (duf2612)
# hypothetical protein_gp152
# protein of unknown function duf3850
# hypothetical protein wfi_00043
# hypothetical protein phig1ep23
# hypothetical-protein | belonging to t4-like gc: 773
# nrdc.6 conserved hypothetical protein
# fig01046701: hypothetical protein
# hypothetical protein a116
# hypothetical protein rdjlphi1_gp32
# hypothetical early protein
# hypothetical protein acg-c40_0126 [enterobacteria phage vb_ecom_acg-c40]
# gp61.4 hypothetical protein [enterobacteria phage t4]
# hypothetical protein [siphoviridae sp.]
# nrda.1 conserved hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 812
# hypothetical protein js09_048 [escherichia phage vb_ecom_js09]
# hypothetical protein rdjlphi1_gp67
# a-gt.2 conserved hypothetical protein
# hypothetcial protein
# rb69orf075c hypothetical protein
# ndd.1 hypothetical protein
# hypothetical protein_gp090
# gp45.2 conserved hypothetical protein
# protein of unknown function duf 4343
# hypothetical protein_gp005
# hypothetical protein ek99p-1_0033
# hypothetical protein predicted by glimmer/critica
# hypothetical protein eflk1_massa178
# non-conserved hypothetical protein
# frd.2 hypothetical protein [enterobacteria phage rb14]
# hypothetical protein acg-c40_0271 [enterobacteria phage vb_ecom_acg-c40]
# protein of unknown function duf2190
# protein of unknown function duf3873
# protein of unknown function duf1707
# moda.2 conserved hypothetical protein
# protein of unknown function duf2591
# conserved protein of unknown function, ddrb
# hypothetical protein_gp218
# fig00441406: hypothetical protein
# deoxyuridine 5'-triphosphate hypothetical protein
# rb69orf136c hypothetical protein
# nin 60 (pept unknown;60)
# hypothetical protein rdjlphi1_gp61
# hypothetical protein_gp260
# uncharacterized 11.1 kda protein
# gp49.1 conserved protein of unknown function [escherichiavirus t4]
# hypothetical protein_gp242
# protein of unknown function (duf5471)
# motb.2 conserved hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 71
# hypothetical protein_gp184
# protein of unknown function (duf2717)
# protein of unknown function duf5496
# hypothetical-protein | belonging to t4-like gc: 797
# hypothetical protein rdjlphi1_gp12
# hypothetical protein_gp171
# hypothetical protein rdjlphi1_gp44
# gp31.1 hypothetical protein
# hypothetical protein d5505_00079[escherichiaphage d5505]
# hypothetical protein mobd.6
# vr7orf017w hypothetical protein
# protein of unknown function duf5480
# pset.1 hypothetical protein
# rb69orf040c hypothetical protein
# fig00637981: hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 166
# tk.3 conserved hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 843
# hypothetical protein wfl6982_00251[escherichiaphage vb_ecom_wfl6982]
# hypothetical protein acg-c40_0031 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein gp5.4 [shigella phage shfl2]
# protein of uncharacterised function (duf2654)
# fig00640631: hypothetical protein
# hypothetical protein avu03_gp28
# gp42, conserved hypothetical protein
# conserved hypothetical phage protein
# gp8, conserved hypothetical protein
# mobd.6 conserved hypothetical phage protein
# protein of unknown function duf4942
# gp45.2 hypothetical phage protein
# hypothetical protein_gp112
# hypothetical protein a40
# putative hyphothetical protein
# hypothetical-protein | belonging to t4-like gc: 328
# hypothetical protein rdjlphi1_gp48
# hypothetical protein rdjlphi1_gp54
# protein of unknown function duf2654
# protein of unknown function duf2514
# hypothetical proteins containing pentapeptide repeats
# hypothetical 12kd protein
# hypothetical protein gp39
# protein of unknown function duf2400
# hypothetical-protein | belonging to t4-like gc: 112
# hypothetical-protein | belonging to t4-like gc: 770
# a-gt.2 hypothetical protein
# hypothetical protein nrdc.1
# hypothetical protein nrdc.2
# uncharacterized protein ynfn
# protein of unknown function duf4355
# hypothetical protein of isec8
# hypothetical-protein | belonging to t4-like gc: 314
# gp17, hypothetical protein
# hypothetical protein gh15_008
# hypothetical protein acg-c40_0099 [enterobacteria phage vb_ecom_acg-c40]
# fig00644273: hypothetical protein
# protein of unknown function duf4055
# hypothetical protein wfi_00011
# fig00638520: hypothetical protein
# hypothetical protein rdjlphi1_gp51
# protein of unknown function duf5073
# hypothetical-protein | belonging to t4-like gc: 874
# hypothetical protein_gp245
# hypothetical protein nrdc.5 [shigella phage shfl2]
# hypothetical phage protein
# hypothetical protein_gp276
# protein of unknown function duf2977
# hypothetical protein_gp118
# fig00638417: hypothetical protein
# moda.4 hypothetical protein
# conserved hypothetical conserved phage protein
# hypothetical-protein | belonging to t4-like gc: 792
# hypothetical protein_gp166
# hypothetical protein [escherichia phage ec121]
# hypothetical protein gp44
# fig00638990: hypothetical protein
# hypothetical protein sf25_gp216 [shigellaphagesf25]
# hypothetical protein shfl2p237 [shigella phage shfl2]
# gp61.1 hypothetical protein
# hypothetical ptotein
# hypothetical protein_gp159
# hypothetical protein psco10_86
# hypothetical-protein | belonging to t4-like gc: 739
# hypothetical-protein | belonging to t4-like gc: 801
# gp30.3' hypothetical protein
# conserved hypothetical protein [escherichiaphagear1]
# frd.2 conserved hypothetical protein
# hypothetical protein jl1_9
# hypothetical protein e.4
# hopothetical protein
# gp30.2 hypothetical protein
# hypothetical protein ptxu06_00024
# hypothetical protein acg-c40_0042 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein_gp176
# hypothetical protein_gp227
# gp5.3 conserved hypothetical protein
# dexa.2 hypothetical protein
# hypothetical protein gh15_042
# hypothetical protein nrdc.5
# rb69orf055c hypothetical protein
# protein of unknown function duf4326
# mobd.4 hypothetical protein
# hypothetical protein avu03_gp29
# hypothetical protein rz1
# hypothetical protein_gp268
# hypothetical protein_gp269
# hypothetical protein gh15_151
# hypothetical protein, duf4815
# protein of uncharacterised function (duf559)
# hypothetical protein acg-c40_0091 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein_gp226
# protein of unknown function duf5499
# vs.8 hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 847
# hypothetical-protein | belonging to t4-like gc: 853
# fig00641093: hypothetical protein
# conserved protein of unknown function ddra
# fig00639051: hypothetical protein
# rb69orf138c hypothetical protein
# protein of unknown function duf2586
# hypothetical protein ecgd1_116 [enterobacteriaphage ecgd1]
# mobd.1 hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 754
# hypothetical-protein | belonging to t4-like gc: 787
# hypothetical protein e.6
# hypothetical protein_gp059
# hypothetical protein orf_0137
# protein of unknown function (duf4236)
# uncharacterized protein ydfd
# unknown early protein
# gp24.2 hypothetical protein
# gp3, conserved hypothetical protein
# nrdc.9 conserved hypothetical protein
# hypothetical protein a115
# nrdc.5 conserved hypothetical protein
# hypothetical protein gp5.4
# hypothetical protein, duf1351
# hypothetical protein_gp213
# hypothetical protein ek99p-1_0031
# hypothetical protein_gp121
# hypothetical protein_gp099
# hypothetical protein gp40
# hypothetical protein_gp225
# protein of unknown function duf2828
# e.6 hypothetical protein
# hypothetical protein_gp222
# hypothetial protein
# tk.4 conserved hypothetical protein
# fig00638221: hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 806
# hypothetical protein rdjlphi1_gp43
# protein of unknown function duf1425
# hypothetical protein [escherichia phage pmbt]
# hypothetical-protein | belonging to t4-like gc: 838
# protein of unknown function duf1737
# vs.1 hypothetical protein
# hypothetical protein c225
# hypothetical protein_gp169
# protein of unknown function duf2730
# hypothetical protein hypothetical protein meda_023 [salmonella phage meda] axy86283.1
# e.6 conserved hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 727
# hypothetical protein_gp261
# gp61.2 hypothetical protein
# fig00641267: hypothetical protein
# putative protein of unknown function duf3383
# gp5.1 conserved hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 662
# hypothetical protein rdjlphi1_gp76
# hypothetical protein ecgd1_228 [enterobacteriaphage ecgd1]
# hypothetical protein_gp233
# hypothetical protein rdjlphi1_gp60
# protein of unknown function duf4373
# nrdc.6 hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 747
# hypothetical protein with lpxb motif
# hypothetical protein rdjlphi1_gp10
# hypotetical phage protein
# nin 290 (pept unknown;290)
# hypothetical protein rostov1_00066 [vibrio phage rostov-1]
# conserved uncharacterised protein
# hypothetical-protein | belonging to t4-like gc: 851
# hypothetical protein b79
# protein of unknown function duf276
# arn.1 hypothetical protein
# rb32orf249c hypothetical protein
# hypothetical protein_gp248
# a-gt.3 conserved hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 757
# hypothetical protein 812_048
# cd.4 conserved hypothetical protein
# hypothetical protein kp11
# hypothetical protein_gp205
# hypothetical protein_gp119
# nrdc.11 hypothetical protein
# hypothetical protein rb32orf151w [enterobacteria phage rb32]
# hypothetical protein similar to phage protein (n4 gp49/phage sf6 gene 66) family
# hypothetical protein ecgd1_182 [enterobacteriaphage ecgd1]
# hypothetical protei
# rb32orf252c hypothetical protein
# rb69orf125c hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 392
# hypothetical protein mobd.1
# putative protein of unknown function duf2945
# hypothetical protein vs.1 [shigella phage shfl2]
# hypothetical-protein | belonging to t4-like gc: 807
# hypothetical protein_gp009
# hypothetical protein psco10_99
# arn.2 conserved hypothetical protein
# nin 204 (pept unknown;204)
# hypothetical protein_gp234
# protein of unknown function duf5376
# hypothetical protein [salmonella enterica subsp. enterica]
# uvsy.-1 conserved hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 796
# hypothetical protein_gp273
# hypothetical protein_gp232
# protein of unknown function duf5486
# vr7orf004c hypothetical protein
# e.8 hypothetical protein
# vr7orf023c hypothetical protein
# hypothetical protein_gp161
# fig00641663: hypothetical protein
# hypothetical protein [enterobacteria phage ime09]
# hypothetical protein [escherichia phage 2 jes-2013]
# hypothetical protein_gp291
# protein of unknown function duf551
# gp49.1 conserved hypothetical protein
# fig00639828: hypothetical protein
# protein of unknown function duf968
# hypothetical protein nrdc.3
# protein of unknown function (duf2833)
# hypothetical protein rdjlphi1_gp53
# moda.2 hypothetical protein
# hypothetical protein_gp036
# vr7orf003c hypothetical protein
# gp39.2 conserved hypothetical protein
# hypothetical protein, c-terminal half
# hypothetical-protein | belonging to t4-like gc: 850
# hypothetical+protein
# fig00641808: hypothetical protein
# hypothetical protein_gp115
# protein of unknown function duf2500
# rb69orf272c hypothetical protein
# protein of unknown function duf4054
# hypothetical protein gp43
# hypothetical protein p108_0112
# hypothetical protein_gp057
# protein of unknown function duf390
# hypothetical protein_gp280
# nrda.1conserved hypothetical protein[escherichiavirus t4]
# hypothetical-protein | belonging to t4-like gc: 176
# rb32orf111c hypothetical protein
# hypothetical protein epyd_13
# protein of unknown function duf2570
# hypothetical protein_gp252
# hypothetical protein_gp172
# hypothetical protein_gp221
# hypothetical protein_gp219
# hypothetical protein a188
# fig01220105: hypothetical protein
# gp17'a unknown function
# hypothetical protein_gp228
# rb32orf030w hypothetical protein
# fig01219977: hypothetical protein
# fig00642496: hypothetical protein
# hypothetical protein [escherichia phage vb_ecom_js09]
# hypothetical protein gpg
# hypothetical protein_gp045
# gp60.1 hypothetical protein
# protein of unknown function duf1018
# protein of unknown function duf3045
# ...
# hypothetical-protein | belonging to t4-like gc: 774
# hypothetical-protein | belonging to t4-like gc: 424
# hypothetical protein gp38
# protein of unknown function duf5476
# gp30.6 conserved hypothetical protein
# hypothetical protein_gp220
# fig00640809: hypothetical protein
# gp8, hypothetical protein
# hypothetical ptoein
# uncharacterized+conserved+protein, phage+conserved+hypothetical+protein+br0599, phage+conserved+hypothetical+protein+br0599
# protein of unknown function duf724
# cd.3 conserved hypothetical protein
# hypothetical protein_gp006
# gp04, hypothetical protein
# rb69orf005c hypothetical protein
# protein of uncharacterised function (duf2685)
# fig00953163: hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 800
# hypothetical protein shfl2p077 [shigella phage shfl2]
# hypothetical-protein | belonging to t4-like gc: 849
# fig00639767: hypothetical protein
# hypothetical protein b
# hypothetical-protein | belonging to t4-like gc: 745
# ndd.2a hypothetical protein [enterobacteria phage rb51]
# hypothetical protein tk.3
# hypothetical protein yomd
# hypothetical protein gpgt
# conserved hypothetical protein (gp157-like)
# gp28, hypothetical protein
# rb69orf270c hypothetical protein
# rb69orf032c hypothetical protein
# gp42.1 conserved hypothetical protein
# hypothetical protein nrdc.9
# protein of unknown function duf2829
# hypothetical-protein | belonging to t4-like gc: 177
# hypothetical protein_gp108
# uvsy.-1 hypothetical protein
# protein of unknown function duf4406
# gp55, hypothetical protein
# uncharacterized protein ydfu, duf968 family
# hypothetical protein vec25_30 [escherichiavirusvec25]
# hypothetical protein [escherichia phage vb_ecom_ffh2]
# protein of unknown function duf2700
# rb69orf053c hypothetical protein
# vs.4 hypothetical protein
# uncharacterized phage protein
# protein of unknown function duf1360
# hypothetical-protein | belonging to t4-like gc: 751
# gp30.7 hypothetical protein
# gp61.4 conserved hypothetical protein
# gp55.2 hypothetical protein
# cog1683: uncharacterized conserved protein / fig143828: hypothetical protein ybga
# protein of unknown function duf4060
# gp33, hypothetical protein
# gp30.5 hypothetical protein
# hypothetical protein_gp024
# hypothetical protein_gp044
# hypothetical protein_gp137
# gp39.1 conserved hypothetical protein
# protein of unknown function duf2774
# dda.1 hypothetical protein
# fig00639352: hypothetical protein
# protein of unknown function duf1408
# pset.2 hypothetical protein
# gp46.2 conserved hypothetical protein
# rb32orf217c hypothetical protein
# hypothetical bacteriophage protein
# hypothetical protein mrh.1
# rb69orf123c hypothetical protein
# hypothetical protein_gp177
# hypothetical-protein | belonging to t4-like gc: 749
# hypothetical protein, ninb homolog
# uncharacterised protein
# fig00553244: hypothetical protein
# protein of unknown function duf754
# hypothetical protein c109
# hypothetical protein a-gt.4
# hypothetical protein shfl2p069 [shigella phage shfl2]
# arn.4 conserved hypothetical protein
# protein of unknown function duf165
# hypothetical protein_gp042
# protein of unknown function duf2597
# fig01048930: hypothetical protein
# gp55.5 conserved hypothetical protein
# fig00639861: hypothetical protein
# hypothetical protein ecgd1_217 [enterobacteriaphage ecgd1]
# rb32orf268c hypothetical protein
# nrda.2 conserved hypothetical protein
# hypothetical protein hor27_gp141 [escherichiaphage esco5]
# protein of unknown function duf5347
# protein of unknown function duf3268
# hypothetical protein shfl2p085 [shigella phage shfl2]
# gp19, conserved hypothetical protein
# hypothetical conserved protein
# hypothetical protein p108_0017
# hypothetical protein mobd.5 [shigella phage shfl2]
# hypothetical-protein | belonging to t4-like gc: 775
# hypothetical protein gp27
# hypothetical protein protein
# hypothetical secreted protein
# hypothetical-protein | belonging to t4-like gc: 789
# a-gt.5 hypothetical protein
# protein of unknown function duf559
# hypothetical protein gh15_013
# vs.1 conserved hypothetical protein
# hypothetical protein_gp002
# hypothetical protein_gp182
# fig00638927: hypothetical protein
# protein of unknown function duf2786
# hypothetical protein gp42
# arn.3 conserved hypothetical protein
# e.3 hypothetical protein
# hypothetical protein_gp190
# hypothetical protein, rhh-3 domain
# hypothetical-protein | belonging to t4-like gc: 820
# protein of unknown function duf2482
# gp31.1 conserverd hypothetical protein
# probable gp5.4 conserved hypothetical protein
# hypothetical protein sa5_0165
# hypothetical protein shfl2p242 [shigella phage shfl2]
# gp45.2 hypothetical protein
# hypothetical protein vec25_49 [escherichiavirusvec25]
# hypothetical-protein | belonging to t4-like gc: 794
# uncharacterized 14.8 kda protein in frd-gp32 intergenic region
# nin 57 (pept unknown;57)
# hypothetical protein acg-c40_0133 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein phage protein
# hypothetical protein rdjlphi1_gp01
# hypothetical protein gp32
# rb69orf227c hypothetical protein
# hypothetical proteinhos48_gp06[escherichiaphageeg1]
# fig00642056: hypothetical protein
# uncharacterized protein ybck
# gp27, conserved hypothetical protein
# hypothetical protein_gp061
# hypothetical protein rdjlphi1_gp04
# hypothetical protein_gp141
# gp5.1 hypothetical protein
# fig00641340: hypothetical protein
# hypothetical protein hk578_040
# protein of unknown function duf4760
# protein of unknown function duf3309
# hypothetical protein psptot1_3768
# hypothetical-protein | belonging to t4-like gc: 49
# nrda.1 hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 767
# nrdc.8 conserved hypothetical protein
# rb69orf104c hypothetical protein
# fig00639062: hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 383
# hypothetical protein_gp046
# hypothetical protein kp13
# e.7 hypothetical protein
# phage uncharacterized protein, c-terminal domain
# uncharacterized 17.7 kda protein
# hypothetical protein rdjlphi1_gp36
# protein of unknown function duf3134
# mrh.1 hypothetical protein [enterobacteria phage t4]
# hypothtical protein
# gp41, hypothetical protein
# hypothetical protein ecgd1_164 [enterobacteriaphage ecgd1]
# fig00639556: hypothetical protein
# hypothetical rnha
# hypothetical protein rdjlphi1_gp09
# hypothetical protein e112_094 [escherichia phage vb_ecom_112]
# hypothetical protein psphkpp10_gp145
# vs.7 hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 803
# hypothetical protein e.2
# hypothetical-protein | belonging to t4-like gc: 743
# trna.3 conserved hypothetical protein
# gp49.1 hypothetical protein
# hypothetical protein, duf1768
# uncharacterized protein ybcv
# hypohtetical protein
# rb69orf133c hypothetical protein
# hypothetical protein e112_253 [escherichiaphage vb_ecom_112]
# fig00644807: hypothetical protein
# hypothetical protein gp28
# moda.3 conserved hypothetical protein
# ndd.2 hypothetical protein
# phage-related conserved hypothetical protein
# protein of unknown function duf2721
# hypothetical protein with tm2 domain
# alt.1 hypothetical protein
# hypotethical protein
# hypothetical protein_gp173
# hypothetical protein_gp230
# hypothetical-protein | belonging to t4-like gc: 841
# e.4 conserved hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 862
# protein of unknown function duf1024
# hypothetical protein_gp041
# hypothetical protein ecgd1_021 [enterobacteriaphage ecgd1]
# protein of unknown function duf5495
# hypothetical-protein | belonging to t4-like gc: 810
# hypothetical protein rdjlphi1_gp50
# fig00643041: hypothetical protein
# protein of unknown function duf5490
# protein of unknown function duf2185
# uvsy.-2 conserved hypothetical protein
# nrdc.5 hypothetical protein
# hypothetical protein_gp212
# hypothetical protein glov_0511
# ndd.4 conserved hypothetical protein
# frd.3 hypothetical protein
# imm.1 hypothetical protein
# hypothetical protein g377_gp232 [escherichiaphage phapec8]
# duf5681 protein of unknown function
# hypothetical protein_gp277
# e.5 hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 753
# hypothetical protein_gp206
# hypothetical protein_gp163
# alt.-2 hypothetical protein
# protein of unknown function duf935
# hypothetical protein_gp224
# gp47.1 hypothetical protein
# hypothetical protein_gp130
# exported hypothetical protein
# rb43orf060w hypothetical protein
# hypothetical protein_gp186
# yjdb uncharacterized conserved protein (ig-like fold protein)
# hypothetical protein kp33
# gp61.2 conserved hypothetical protein
# fig00638478: hypothetical protein
# protein of unknown function duf1937
# rb69orf102c hypothetical protein
# hypothetical protein_gp175
# hypothetical protein a-gt.5
# hypothetical-protein | belonging to t4-like gc: 744
# hypothetical protein_gp170
# hypothetical protein vs.3
# protein of unknown function duf5734
# hypothetical protein_gp129
# protein of unknown function duf5419
# t4-like hypothetical protein
# hypothetical protein kp40
# gp30.7 conserved hypothetical protein
# arn.2 hypothetical protein
# protein of unknown function duf4965
# hypothetical protein rdjlphi1_gp31
# fig01045252: hypothetical protein
# hypothetical protein ri.1
# hypothetical protein_gp155
# hypothetical protein ecgd1_126 [enterobacteriaphage ecgd1]
# protein of unknown function duf262
# hypothetical protein_gp262
# gp57b hypothetical protein
# vs.5 conserved hypothetical protein
# gp55.2 conserved hypothetical protein
# hypothetical protein shfl2p208 [shigella phage shfl2]
# protein of unknown function duf1108
# consaerved hypothetical protein
# fig00644776: hypothetical protein
# hypothetical protein nrdc.8 [shigella phage shfl2]
# hypothetical protein_gp289
# protein of unknown function duf4774
# fig00639373: hypothetical protein
# gp55.6 conserved hypothetical protein
# hypothetical protein_gp229
# uncharacterized protein ydfr
# hypothetical-protein | belonging to t4-like gc: 764
# putative nrdc.11 conserved hypothetical protein
# protein of unknown function duf4752
# conserved protein of unknown function, part 1
# protein of unknown function duf2937
# rb69orf079c hypothetical protein
# hypothetical protein gh15_161
# hypothetical-protein | belonging to t4-like gc: 856
# hypothetical-protein | belonging to t4-like gc: 331
# hypothetical protein_gp238
# vs.5 hypothetical protein
# conserved hypotetical phage protein
# hypothetical protein_gp185
# hypothetical-protein | belonging to t4-like gc: 637
# gp24.3 hypothetical protein
# hypothetical protein_gp160
# hypothetical-protein | belonging to t4-like gc: 142
# gp19.1 hypothetical protein
# hypothetical protein_gp259
# 188aa long conserved hypothetical protein
# rb69orf146c hypothetical protein
# e.8 conserved hypothetical protein
# vs.4 conserved hypothetical protein
# putative uncharacterized protein
# duf2514 protein of unknown function
# rb69orf130c hypothetical protein
# hypothetical protein, n-terminal half
# hypothetical protein acg-c40_0096 [enterobacteria phage vb_ecom_acg-c40]
# protein+of+uncharacterised+function+(duf2815)
# hypothetical-protein | belonging to t4-like gc: 857
# gp22, hypothetical protein
# gp30.1 conserved hypothetical protein
# hypothetical protein_gp165
# hypothetical protein rdjlphi1_gp75
# vr7orf013c hypothetical protein
# mobd.7 hypothetical protein
# nrdc.10 conserved hypothetical protein
# uvsw.1 hypothetical protein
# gp17, conserved hypothetical protein
# motb.1 conserved hypothetical protein
# conserved protein of unknown function upfc (paar motif)
# nrdc.10 hypothetical protein
# hypothetical protein gh15_196
# e.5 conserved hypothetical protein
# protein of unknown function duf905
# hypothetical gene
# fig00639586: hypothetical protein
# gp49, hypothetical protein
# uncharacterized 8.8 kda protein
# rb69orf151c hypothetical protein
# hypothetical protein acg-c40_0229 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein rdjlphi1_gp66
# hypothetical protein b136
# fig00640069: hypothetical protein
# hypothetical protein pbpra1818
# uncharacterized protein cog3236
# hypothetical protein_gp288
# hypothetical protein gp46.1 [shigella phage shfl2]
# hypothetical protein vbecomnbg2_223[escherichiaphage vb_ecom_nbg2]
# hypothetical protein_gp189
# hypothetical protein ning homolog
# gp13, conserved hypothetical protein
# hypothetical protein vs.4
# hypothetical protein kp18
# conserve hypothetical protein
# hypothetical protein p1-like protein
# mobd.6 hypothetical protein
# protein of unknown function duf2493
# protein of unknown function duf3672
# hypothetical protein psco10_39
# protein of unknown function duf3307
# hypothetical protein mobd.3
# protein of unknown function duf2624
# hypothetical protein_gp239
# nrdc.1 conserved hypothetical protein
# hypothetical protein_gp247
# nrdc.7 hypothetical protein
# rb69orf107c hypothetical protein
# hypothetical protein tk.2 [shigella phage shfl2]
# blast hypothetical protein
# putative protein of unkown function duf3268
# protein of unknown function duf6378
# protein+of+uncharacterised+function+(duf2800)
# rb69orf041c hypothetical protein
# protein of unknwon function (duf3310)
# hypothetical protein c153
# hypothetical protein ip4
# vr7orf033w hypothetical protein
# hypothetical protein g377_gp160 [escherichiaphage phapec8]
# hypothetical protein_gp128
# rb69orf003c hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 811
# protein of unknown function duf5417
# hypothetical protein_gp008
# hypothetical protein p108_0115
# gp30.1 hypothetical protein
# hypothetical protein_gp287
# hypothetical protein_gp164
# hypothetical-protein | belonging to t4-like gc: 790
# arn.1 conserved hypothetical protein
# protein of unknown function duf1367
# protein of unknown function duf847
# hypothetical protein_gp051
# hypothetical protein ecgd1_044 [enterobacteriaphage ecgd1]
# fig00638895: hypothetical protein
# hypothetical protein_gp178
# frd.1 conserved hypothetical protein
# no known function
# hypothetical protein ecgd1_004 [enterobacteriaphage ecgd1]
# uncharacterized protein ybco
# hypothetical protein acg-c40_0097 [enterobacteria phage vb_ecom_acg-c40]
# hypothetical protein_gp077
# putative protein of unknown function duf551
# hypothetical-protein | belonging to t4-like gc: 312
# uncharacterized phage-encoded protein
# fig00643674: hypothetical protein
# hypothetical protein cpt_phagek_gp058
# hypothetical protein shfl2p216 [shigella phage shfl2]
# protein of unknown function duf2951
# hypothetical protein gp36
# hypothetical protein vs.3 [shigella phage shfl2]
# hypothetical protein_gp091
# hypothetical protein rdjlphi1_gp55
# protein of unknown function duf2479
# hypothetical protein gp9
# gp31.1 conserved hypothetical protein
# protein of unknown function duf1311
# dda.1` hypothetical protein
# hypothetical protein_gp012
# hypothetical protein ecgd1_180 [enterobacteriaphage ecgd1]
# hypothetical protein gp5.1
# hypothetical protein b181
# gp20, hypothetical protein
# hypothetical protein [aeromonas phage t7-ah]
# protein of unknown function duf1653
# hypothetical protein_gp254
# protein of unknown function duf1565
# hypothetical protein rdjlphi1_gp25
# protein of unknown function duf3168
# protein of unknown function duf2861
# hypothetical protein hov53_gp195 [escherichiaphage vb_ecom_schickermooser]
# hypothetical-protein | belonging to t4-like gc: 858
# hypothetical-protein | belonging to t4-like gc: 61
# conserved hypothetical protein g
# ip4 hypothetical protein
# alt.-3 conserved hypothetical protein
# unnamed protein product [enterobacteriaphageime08]
# hypothetical-protein | belonging to t4-like gc: 390
# e.4 hypothetical protein
# hypothetical zinc-finger protein
# hypothetical protein_gp255
# rb69orf045c hypothetical protein
# gp7, conserved hypothetical protein
# hypothetical protein_gp066
# gp55.5 conserved protein of unknown function
# putative unknown
# hypothetical protein sf24_gp255 [shigellaphagesf24]
# hypotherical protein
# mrh.1 conserved hypothetical protein
# gp45.2 conserverd hypothetical protein
# protein of unknown function (duf968)
# protein of unknown function duf6651
# hypothetical protein a-gt.3
# protein of unknown function duf5481
# protein of unknown function duf4314
# fig00642297: hypothetical protein
# hypothetical protein rdjlphi1_gp19
# hypothetical protein_gp278
# hypothetical protein_gp192
# gp31.2 hypothetical protein
# hypothetical protein rdjlphi1_gp26
# protein+of+uncharacterised+function+(duf2793)
# hypothetical protein [escherichiaphagevb_ecos_pns1]
# protein of unknown function duf1353
# gp57b conserved hypothetical protein
# hypothetical-protein | belonging to t4-like gc: 742
# tk.1 conserved hypothetical protein
# hypothetical protein_gp087

# %% [markdown]
# ### Get distribution of RBP lengths

# %% [markdown]
# This preliminary analysis of the distribution of the RBP lengths covers both the sequences with CDS information and those where the CDS information features are predicted via Prokka. We carry it now in order since we need the lower and upper bounds for RBP lengths to generate the FASTA files.

# %%
len_distribution = util.generate_rbp_len_distribution()
util.generate_rbp_len_distribution_prokka(len_distribution, constants.INPHARED_GENOME)

lengths = []
for length, freq in len_distribution.items():
    for _ in range(freq):
        lengths.append(length)
# Out:
# Processed 1000 records
# Processed 2000 records
# Processed 3000 records
# Processed 4000 records
# Processed 5000 records
# Processed 6000 records
# Processed 7000 records
# Processed 8000 records
# Processed 9000 records
# Processed 10000 records
# Processed 11000 records
# Processed 12000 records
# Processed 13000 records
# Processed 14000 records
# Processed 15000 records
# Processed 16000 records
# Processed 17000 records
# Processed 18000 records
# Processed 19000 records
# Processed 20000 records
# Processed 21000 records
# Processed 22000 records
# Processed 23000 records
# Processed 24000 records
# Processed 25000 records
# Processed 26000 records
# Processed 27000 records
# Processed 28000 records
# Processed 29000 records
# Processed 30000 records
# Processed 31000 records

# %%
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.RBP_LENGTHS),'wb') as rbp_lengths_file:
    pickle.dump(lengths, rbp_lengths_file)

# %% [markdown]
# Statistically compute the lower and upper bounds for RBP lengths.

# %%
with open(f'{constants.TEMP_PREPROCESSING}/{constants.RBP_LENGTHS}','rb') as rbp_lengths_file:
    lengths = pickle.load(rbp_lengths_file)

Q1 = np.percentile(lengths, 25, interpolation = 'midpoint')
Q3 = np.percentile(lengths, 75, interpolation = 'midpoint')
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower bound:", lower_bound)
print("Upper bound:", upper_bound)
# Out:
# Lower bound: -533.0
# Upper bound: 1587.0

# %% [markdown]
# ### Generate FASTA for entries with CDS information

# %% [markdown]
# Generate FASTA files containing protein sequences of hypothetical proteins and RBPs

# %%
RBP_NEW_DIR = f'{constants.INPHARED}/{constants.FASTA}/{constants.RBP}/{constants.GENBANK}'
HYPOTHETICAL_NEW_DIR = f'{constants.INPHARED}/{constants.FASTA}/{constants.HYPOTHETICAL}/{constants.GENBANK}'

if not os.path.exists(RBP_NEW_DIR):
    os.makedirs(RBP_NEW_DIR)
    
if not os.path.exists(HYPOTHETICAL_NEW_DIR):
    os.makedirs(HYPOTHETICAL_NEW_DIR)

# %%
util.generate_rbp_hypothetical_fasta(RBP_NEW_DIR, HYPOTHETICAL_NEW_DIR, constants.LOWER_BOUND_RBP_LENGTH, 
                                     constants.UPPER_BOUND_RBP_LENGTH)
# Out:
# Processed 1000 records
# Processed 2000 records
# Processed 3000 records
# Processed 4000 records
# Processed 5000 records
# Processed 6000 records
# Processed 7000 records
# Processed 8000 records
# Processed 9000 records
# Processed 10000 records
# Processed 11000 records
# Processed 12000 records
# Processed 13000 records
# Processed 14000 records
# Processed 15000 records
# Processed 16000 records
# Processed 17000 records
# Processed 18000 records
# Processed 19000 records
# Processed 20000 records
# Processed 21000 records
# Processed 22000 records
# Processed 23000 records
# Processed 24000 records
# Processed 25000 records
# Processed 26000 records
# Processed 27000 records
# Processed 28000 records
# Processed 29000 records
# Processed 30000 records
# Processed 31000 records

# %% [markdown]
# The FASTA files are stored in the `inphared/fasta` directory, specifically in the `genbank` subdirectories.

# %% [markdown]
# ## *B. Process entries without CDS information*

# %% [markdown]
# - Annotate genes using [Prokka](https://academic.oup.com/bioinformatics/article/30/14/2068/2390517), which calls [Prodigal](https://bmcbioinformatics.biomedcentral.com/articles/10.1186/1471-2105-11-119) to predict coordinates of ORFs.
# - Configure Prokka to perform functional annotation using [PHROGs](https://academic.oup.com/nargab/article/3/3/lqab067/6342220).
# - Process in the same manner as the entries with CDS information.

# %%
RBP_NEW_DIR = f'{constants.INPHARED}/{constants.FASTA}/{constants.RBP}/{constants.PROKKA}'
HYPOTHETICAL_NEW_DIR = f'{constants.INPHARED}/{constants.FASTA}/{constants.HYPOTHETICAL}/{constants.PROKKA}'

if not os.path.exists(RBP_NEW_DIR):
    os.mkdir(RBP_NEW_DIR)
    
if not os.path.exists(HYPOTHETICAL_NEW_DIR):
    os.mkdir(HYPOTHETICAL_NEW_DIR)

# %% [markdown]
# Analyze the gene product annotations returned by PHROG.

# %%
annot_products_prokka = util.get_annot_products_prokka(constants.INPHARED_GENOME)
# Out:
# Processed 1000 records
# Processed 2000 records
# Processed 3000 records
# Processed 4000 records
# Processed 5000 records
# Processed 6000 records
# Processed 7000 records
# Processed 8000 records
# Processed 9000 records
# Processed 10000 records
# Processed 11000 records
# Processed 12000 records
# Processed 13000 records
# Processed 14000 records
# Processed 15000 records
# Processed 16000 records
# Processed 17000 records
# Processed 18000 records
# Processed 19000 records
# Processed 20000 records
# Processed 21000 records
# Processed 22000 records
# Processed 23000 records
# Processed 24000 records
# Processed 25000 records

# %%
x, y = util.get_rbp_hypothetical_proteins_prokka(constants.RBP_REGEX, annot_products_prokka)
# Out:
# Processed 1000 records
# Processed 2000 records
# Processed 3000 records
# Processed 4000 records

# %% [markdown]
# Combine the keywords for RBPs and hypothetical proteins from GenBank (i.e., entries with CDS information) and PHROG annotations (i.e., entries without CDS information).

# %%
util.set_rbp_products(rbp_products.union(x))
util.set_hypothetical_proteins(hypothetical_proteins.union(y))

# %%
rbp_products = rbp_products.union(x)
hypothetical_proteins = hypothetical_proteins.union(y)

# %%
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.RBP_PRODUCTS),'wb') as rbp_products_file:
    pickle.dump(rbp_products, rbp_products_file)
    
with open(os.path.join(constants.TEMP_PREPROCESSING, constants.HYPOTHETICAL_PRODUCTS),'wb') as hypothetical_proteins_file:
    pickle.dump(hypothetical_proteins, hypothetical_proteins_file)

# %% [markdown]
# ### Generate FASTA for entries without CDS information

# %% [markdown]
# Generate FASTA files containing protein sequences of hypothetical proteins and RBPs

# %%
util.generate_rbp_hypothetical_fasta_prokka(constants.INPHARED_GENOME, RBP_NEW_DIR, HYPOTHETICAL_NEW_DIR, 
                                            lower_bound, upper_bound)

# %% [markdown]
# The FASTA files are stored in the `inphared/fasta` directory, specifically in the `prokka` subdirectories.

# %% [markdown]
# ### C. *Generate FFN containing the genomes of RBPs and hypothetical proteins*

# %%
if not os.path.exists(f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.HYPOTHETICAL}/{constants.GENBANK}'):
    os.makedirs(f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.HYPOTHETICAL}/{constants.GENBANK}')
    
if not os.path.exists(f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.RBP}/{constants.GENBANK}'):
    os.makedirs(f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.RBP}/{constants.GENBANK}')

# %%
util.generate_rbp_hypothetical_nucleotide(f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.RBP}/{constants.GENBANK}',
                                          f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.HYPOTHETICAL}/{constants.GENBANK}', 
                                          lower_bound, upper_bound)
# Out:
# Processed 1000 records
# Processed 2000 records
# Processed 3000 records
# Processed 4000 records
# Processed 5000 records
# Processed 6000 records
# Processed 7000 records
# Processed 8000 records
# Processed 9000 records
# Processed 10000 records
# Processed 11000 records
# Processed 12000 records
# Processed 13000 records
# Processed 14000 records
# Processed 15000 records
# Processed 16000 records
# Processed 17000 records
# Processed 18000 records
# Processed 19000 records
# Processed 20000 records
# Processed 21000 records
# Processed 22000 records
# Processed 23000 records
# Processed 24000 records
# Processed 25000 records
# Processed 26000 records
# Processed 27000 records
# Processed 28000 records
# Processed 29000 records
# Processed 30000 records
# Processed 31000 records

# %% [markdown]
# The FFN files are stored in the `inphared/fasta/nucleotide` directory, specifically in the `genbank` subdirectories.

# %%
if not os.path.exists(f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.RBP}/{constants.PROKKA}'):
    os.makedirs(f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.RBP}/{constants.PROKKA}')
    
if not os.path.exists(f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.HYPOTHETICAL}/{constants.PROKKA}'):
    os.makedirs(f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.HYPOTHETICAL}/{constants.PROKKA}')

# %%
util.generate_rbp_hypothetical_nucleotide_prokka(constants.INPHARED_GENOME,
                                                 f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.RBP}/{constants.PROKKA}',
                                                 f'{constants.INPHARED}/{constants.FASTA}/{constants.NUCLEOTIDE}/{constants.HYPOTHETICAL}/{constants.PROKKA}', 
                                                 lower_bound, upper_bound)

# %% [markdown]
# The FFN files are stored in the `inphared/fasta/nucleotide` directory, specifically in the `prokka` subdirectories.
